# %% [markdown]
# **Capstone Project- Data Science IBM**
# by Abu Nayeem
#
# This notebook will be used exclusively to complete a capstone project

# %%
import pandas as pd
import numpy as np

print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
