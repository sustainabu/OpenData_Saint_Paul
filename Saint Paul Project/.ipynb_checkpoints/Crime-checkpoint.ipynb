# %%
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
# %matplotlib inline 
import matplotlib as mpl
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
import plotly
from pygeocoder import Geocoder

# %%
#Data Load
df_crash = pd.read_csv('Datasets/Pedestrian_And_Bike_Crash_Data_-_Dataset.csv')
df_crash.head()
# Out:
#    Crash Type Report Made?             Date / Time Case Number  \
# 0  Pedestrian          Yes  02/12/2016 05:43:00 AM   16-027595
# 1  Pedestrian          Yes  02/19/2016 07:31:00 PM   16-032425
# 2  Pedestrian          Yes  02/12/2016 07:08:00 AM   16-027607
# 3  Pedestrian          Yes  02/16/2016 03:49:00 PM   16-030290
# 4  Pedestrian          Yes  02/17/2016 06:22:00 PM   16-031102
#
#            District                 Crash Location Lanes Of Traffic  \
# 0  Central District            7th St W & Randolph              NaN
# 1  Western District  Snelling Ave S & St. Clair Av              NaN
# 2  Central District           5th St E & St. Peter              NaN
# 3  Central District          6th St E & Jackson St              NaN
# 4  Western District        Dale St N & St. Anthony              NaN
#
#   Signal Present?  Speed Limit Of Road (MPH) Road Type  ...   \
# 0             NaN                        NaN       NaN  ...
# 1             NaN                        NaN       NaN  ...
# 2             NaN                        NaN       NaN  ...
# 3             NaN                        NaN       NaN  ...
# 4             NaN                        NaN       NaN  ...
#
#   Driver City Of Residence Driver Zip Code Injury to Pedestrian?  \
# 0                 St. Paul           55102                   Yes
# 1                 St. Paul           55105                    No
# 2                 St. Paul           55117                   Yes
# 3                 St. Paul           55105                   Yes
# 4                 St. Paul           55104                   Yes
#
#    Level of Injury to Pedestrian Pedestrian to Hospital? Injury to Biker?  \
# 0         Suspected Minor Injury                     Yes              NaN
# 1                           None                      No              NaN
# 2         Suspected Minor Injury                     Yes              NaN
# 3         Suspected Minor Injury                      No              NaN
# 4         Suspected Minor Injury                     Yes              NaN
#
#   Level of Injury to Biker  Biker to Hospital?      Crash Lat/Long Location  \
# 0                      NaN                 NaN  (44.92683357, -93.12817034)
# 1                      NaN                 NaN      (44.934254, -93.167026)
# 2                      NaN                 NaN  (44.94520277, -93.09557134)
# 3                      NaN                 NaN    (44.9488967, -93.0901713)
# 4                      NaN                 NaN    (44.9521027, -93.1263367)
#
#   Count
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#
# [5 rows x 33 columns]

# %%
df_graf = pd.read_csv('Datasets/Parks_Graffiti_Report_-_Dataset.csv')
df_graf.head()
# Out:
#          Location Name Work Performed Date             Location Address  \
# 0          Bruce Vento          01/06/2013        293 Commercial Street
# 1             McMurray          01/07/2013   1155 Jessamine Avenue West
# 2  Martin Lurther King          01/07/2013             271 Mackubin St.
# 3        Como Regional          01/07/2013           1281 W. Como Blvd.
# 4       Lexington Pkwy          01/07/2013  350 Lexington Parkway North
#
#       Issue                                        Description  Labor Cost  \
# 0  Graffiti  Graffiti on benches along backside of 293 Comm...      120.70
# 1  Graffiti                   Graffiti on field house building       30.17
# 2  Graffiti      Graffiti on wall of building facingthe school      108.40
# 3  Graffiti      Graffiti on electrical pole near 850 Como Ave       54.20
# 4  Graffiti                       Graffiti in Lexington Tunnel       30.17
#
#    Material Cost  Total Cost             Location
# 0         106.62      227.32  (44.9528, -93.0733)
# 1          26.65       56.82   (44.9739, -93.149)
# 2          48.10      156.50  (44.9494, -93.1213)
# 3          14.05       68.25  (44.9776, -93.1539)
# 4          41.65       71.82  (44.9517, -93.1464)

# %%
df_crime = pd.read_csv('Datasets/Crime_Incident_Report_-_Dataset.csv')
#print(df_crime.head())

cols= ['Case','Date','Time','Code','IncType','Incident','Grid','NNum','Neighborhood','Block','CallDispCode','CallDisposition', 'Count']
df_crime.columns= cols

# %%
#df_crime.CallDisposition.unique()
df=df_crime.query('Grid in [87.0]')

# %%
df.head()
# Out:
#          Case        Date                     Time  Code  \
# 1    19057183  03/20/2019  2019-03-20T23:32:23.000  9954
# 42   19056972  03/20/2019  2019-03-20T18:34:29.000  9954
# 52   19056940  03/20/2019  2019-03-20T18:11:35.000  9954
# 74   19056863  03/20/2019  2019-03-20T16:58:07.000  9954
# 127  19056349  03/20/2019  2019-03-20T00:57:24.000  9954
#
#                     IncType                Incident  Grid  NNum  \
# 1    Proactive Police Visit  Proactive Police Visit  87.0     7
# 42   Proactive Police Visit  Proactive Police Visit  87.0     7
# 52   Proactive Police Visit  Proactive Police Visit  87.0     7
# 74   Proactive Police Visit  Proactive Police Visit  88.0     7
# 127  Proactive Police Visit  Proactive Police Visit  87.0     7
#
#                   Neighborhood                        Block CallDispCode  \
# 1    7 - Thomas/Dale(Frogtown)          98X UNIVERSITY AV W            A
# 42   7 - Thomas/Dale(Frogtown)          THOMAS AV  & MILTON            A
# 52   7 - Thomas/Dale(Frogtown)  LEXINGTON PA N & UNIVERSITY            A
# 74   7 - Thomas/Dale(Frogtown)            THOMAS AV  & DALE            A
# 127  7 - Thomas/Dale(Frogtown)          98X UNIVERSITY AV W            A
#
#     CallDisposition  Count
# 1       A - Advised      1
# 42      A - Advised      1
# 52      A - Advised      1
# 74      A - Advised      1
# 127     A - Advised      1

# %%
df['Date']= pd.to_datetime(df['Date'])
df['DayofWeek']=df['Date'].dt.dayofweek
df['Weekend'] = df['DayofWeek'].apply(lambda x: 1 if (x>4)  else 0)
df['Month'] = df['Date'].dt.month
df['Time']= pd.to_datetime(df['Time'])
df['Hour'] = df['Time'].dt.hour
df['LateNight'] = df['Hour'].apply(lambda x: 1 if (x>21 or x<5)  else 0)

# %%
df.head()
df.dtypes
# Out:
# Case                 int64
# Date                object
# Time                object
# Code                 int64
# IncType             object
# Incident            object
# Grid               float64
# NNum                 int64
# Neighborhood        object
# Block               object
# CallDispCode        object
# CallDisposition     object
# Count                int64
# dtype: object

# %%
#Add Time Variables
df['Date']= pd.to_datetime(df['Date'])
df['Year']= df['Date'].dt.year
df['DayofWeek']=df['Date'].dt.dayofweek
df['Weekend'] = df['DayofWeek'].apply(lambda x: 1 if (x>4)  else 0)
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['Hour'] = df['Date'].dt.hour
df['LateNight'] = df['Hour'].apply(lambda x: 1 if (x>21 or x<5)  else 0)

# %%
#Setting up the Coordinate Key

#Prep from appropiate key (note this process can be done in excel as well)
df_key= pd.read_csv('Datasets/FrogKey.csv')
df_key['Intersection1']= df_key['Intersection1'].str.lower()
df_key['Intersection2']= df_key['Intersection2'].str.lower()

A=df_key[['Intersection1','Intersection2', 'Clumped Coordinates']]
A['Key']= A['Intersection1']+ '_' + A['Intersection2']
A['Int2_1']= A['Intersection2']+ '_' + A['Intersection1']
H1=A[['Key','Clumped Coordinates']]
H2=A[['Int2_1','Clumped Coordinates']]
#Make H2 column name the same to merge
H2.columns= ['Key','Clumped Coordinates']
Cord_key=H1.append(H2, ignore_index=True)

# %%
df['Block']= df['Block'].str.lower()
df['Intersection'] = df['Block'].apply(lambda x: 1 if '&' in x else 0) #intersection


dfI=df.query('Intersection ==1')
new=dfI['Block'].str.split("&", n = 1, expand = True) 
dfI['Inter1']= new[0]
dfI['Inter2']= new[1].str[1:]

new2=dfI['Inter1'].str.split(" ", n = 1, expand = True)
dfI['Inter1']=new2[0]

dfI['Key']= dfI['Inter1']+ '_' + dfI['Inter2']
dfI.reset_index()
dfI=pd.merge(dfI, Cord_key, on='Key', how='left')


dfI
# Out:
#          Case        Date                     Time  Code  \
# 0    19056972  03/20/2019  2019-03-20T18:34:29.000  9954
# 1    19056940  03/20/2019  2019-03-20T18:11:35.000  9954
# 2    19055791  03/19/2019  2019-03-19T11:20:00.000  311
# 3    19052459  03/15/2019  2019-03-15T01:43:51.000  9954
# 4    19052326  03/14/2019  2019-03-14T20:43:00.000  2619
# 5    19050246  03/08/2019  2019-03-08T23:00:00.000  311
# 6    19046546  03/06/2019  2019-03-06T23:29:00.000  1812
# 7    19035258  02/18/2019  2019-02-18T23:40:55.000  9954
# 8    19033449  02/16/2019  2019-02-16T02:55:00.000  2619
# 9    19029825  02/11/2019  2019-02-11T11:00:00.000  710
# 10   19028421  02/09/2019  2019-02-09T12:28:39.000  9954
# 11   19028017  02/08/2019  2019-02-08T20:22:42.000  9954
# 12   19027253  02/07/2019  2019-02-07T20:18:42.000  9954
# 13   19026723  02/07/2019  2019-02-07T00:51:12.000  9954
# 14   19023317  02/02/2019  2019-02-02T10:55:25.000  9954
# 15   19023127  02/02/2019  2019-02-02T01:00:31.000  9954
# 16   19022806  02/01/2019  2019-02-01T18:23:49.000  9954
# 17   19022640  02/01/2019  2019-02-01T14:57:01.000  9954
# 18   19022039  01/31/2019  2019-01-31T18:33:44.000  9954
# 19   19800144  01/29/2019  2019-01-29T18:21:00.000  641
# 20   19020717  01/29/2019  2019-01-29T17:36:33.000  9954
# 21   19018633  01/26/2019  2019-01-26T14:38:26.000  9954
# 22   19017515  01/24/2019  2019-01-24T21:54:00.000  2619
# 23   19016367  01/23/2019  10:46                    9954
# 24   19014510  01/20/2019  13:26                    2619
# 25   19013411  01/18/2019  18:22                    9954
# 26   19011795  01/16/2019  18:18:00                 710
# 27   19006032  01/09/2019  09:52:48                 9954
# 28   19004559  01/07/2019  11:46:25                 9954
# 29   19000001  01/01/2019  00:00:02                 9954
# ..        ...         ...       ...                  ...
# 547  15050840  03/12/2015  18:33                    1800
# 548  15049606  03/11/2015  9:38                     630
# 549  15039946  02/25/2015  21:56                    1811
# 550  15032360  02/14/2015  18:28                    2619
# 551  15027765  02/07/2015  23:00                    710
# 552  15019830  01/28/2015  21:35                    1420
# 553  14279099  12/28/2014  17:29                    700
# 554  14274784  12/21/2014  19:16                    410
# 555  14265205  12/08/2014  10:24                    700
# 556  14265247  12/08/2014  11:34                    711
# 557  14263188  12/05/2014  13:56                    1855
# 558  14259726  12/01/2014  0:03                     1880
# 559  14245104  11/09/2014  20:20                    431
# 560  14237517  10/30/2014  20:31                    1811
# 561  14235159  10/27/2014  21:54                    2619
# 562  14219701  10/09/2014  5:35                     1800
# 563  14219497  10/08/2014  20:57                    1800
# 564  14219497  10/08/2014  20:57                    1800
# 565  14217336  10/06/2014  9:17                     1800
# 566  14217336  10/06/2014  9:17                     1800
# 567  14210007  09/27/2014  6:00                     420
# 568  14207532  09/24/2014  15:12                    1800
# 569  14199411  09/15/2014  9:20                     691
# 570  14193401  09/08/2014  9:02                     700
# 571  14190965  09/05/2014  13:30                    710
# 572  14183444  08/27/2014  21:50                    311
# 573  14181293  08/25/2014  14:31                    700
# 574  14179874  08/23/2014  18:18                    1800
# 575  14172269  08/15/2014  1:12                     314
# 576  14171903  08/14/2014  17:46                    1811
#
#                                                  IncType  \
# 0    Proactive Police Visit
# 1    Proactive Police Visit
# 2    Robbery, Highway, Firearm
# 3    Proactive Police Visit
# 4    Weapons, Discharging a Firearm in the City Limits
# 5    Robbery, Highway, Firearm
# 6    Narcotics, Possession of Heroin
# 7    Proactive Police Visit
# 8    Weapons, Discharging a Firearm in the City Limits
# 9    Motor Vehicle Theft, Automobile
# 10   Proactive Police Visit
# 11   Proactive Police Visit
# 12   Proactive Police Visit
# 13   Proactive Police Visit
# 14   Proactive Police Visit
# 15   Proactive Police Visit
# 16   Proactive Police Visit
# 17   Proactive Police Visit
# 18   Proactive Police Visit
# 19   Theft, From Auto, Under $500
# 20   Proactive Police Visit
# 21   Proactive Police Visit
# 22   Weapons, Discharging a Firearm in the City Limits
# 23   Proactive Police Visit
# 24   Weapons, Discharging a Firearm in the City Limits
# 25   Proactive Police Visit
# 26   Motor Vehicle Theft, Automobile
# 27   Proactive Police Visit
# 28   Proactive Police Visit
# 29   Proactive Police Visit
# ..                      ...
# 547  Narcotics
# 548  Theft, Shoplifting
# 549  Narcotics, Possession of Cocaine
# 550  Weapons, Discharging a Firearm in the City Limits
# 551  Motor Vehicle Theft, Automobile
# 552  Criminal Damage to Property (Gross Mis., $250-$500)
# 553  Motor Vehicle Theft
# 554  Aggravated Assault, Firearm
# 555  Motor Vehicle Theft
# 556  Motor Vehicle Theft, Trucks and Buses
# 557  Narcotics, Possession With Intent to Sell Marijuana
# 558  Narcotics, Possession of Narcotic Paraphernalia
# 559  Aggravated Assault, Domestic
# 560  Narcotics, Possession of Cocaine
# 561  Weapons, Discharging a Firearm in the City Limits
# 562  Narcotics
# 563  Narcotics
# 564  Narcotics
# 565  Narcotics
# 566  Narcotics
# 567  Aggravated Assault, Knife or Cutting Instrument
# 568  Narcotics
# 569  Theft, All Other, Under $500
# 570  Motor Vehicle Theft
# 571  Motor Vehicle Theft, Automobile
# 572  Robbery, Highway, Firearm
# 573  Motor Vehicle Theft
# 574  Narcotics
# 575  Robbery, Highway, By Strong Arm
# 576  Narcotics, Possession of Cocaine
#
#                    Incident  Grid  NNum               Neighborhood  \
# 0    Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 1    Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 2    Robbery                 87.0  7     7 - Thomas/Dale(Frogtown)
# 3    Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 4    Discharge               87.0  7     7 - Thomas/Dale(Frogtown)
# 5    Robbery                 87.0  11    11 - Hamline/Midway
# 6    Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 7    Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 8    Discharge               87.0  7     7 - Thomas/Dale(Frogtown)
# 9    Auto Theft              87.0  7     7 - Thomas/Dale(Frogtown)
# 10   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 11   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 12   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 13   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 14   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 15   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 16   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 17   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 18   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 19   Theft                   87.0  7     7 - Thomas/Dale(Frogtown)
# 20   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 21   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 22   Discharge               87.0  7     7 - Thomas/Dale(Frogtown)
# 23   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 24   Discharge               87.0  7     7 - Thomas/Dale(Frogtown)
# 25   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 26   Auto Theft              87.0  7     7 - Thomas/Dale(Frogtown)
# 27   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 28   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# 29   Proactive Police Visit  87.0  7     7 - Thomas/Dale(Frogtown)
# ..                      ...   ... ..                           ...
# 547  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 548  Theft                   87.0  7     7 - Thomas/Dale(Frogtown)
# 549  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 550  Discharge               87.0  7     7 - Thomas/Dale(Frogtown)
# 551  Auto Theft              87.0  7     7 - Thomas/Dale(Frogtown)
# 552  Vandalism               87.0  7     7 - Thomas/Dale(Frogtown)
# 553  Auto Theft              87.0  7     7 - Thomas/Dale(Frogtown)
# 554  Agg. Assault            87.0  7     7 - Thomas/Dale(Frogtown)
# 555  Auto Theft              87.0  7     7 - Thomas/Dale(Frogtown)
# 556  Auto Theft              87.0  7     7 - Thomas/Dale(Frogtown)
# 557  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 558  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 559  Agg. Assault Dom.       87.0  7     7 - Thomas/Dale(Frogtown)
# 560  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 561  Discharge               87.0  7     7 - Thomas/Dale(Frogtown)
# 562  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 563  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 564  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 565  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 566  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 567  Agg. Assault            87.0  7     7 - Thomas/Dale(Frogtown)
# 568  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 569  Theft                   87.0  7     7 - Thomas/Dale(Frogtown)
# 570  Auto Theft              87.0  7     7 - Thomas/Dale(Frogtown)
# 571  Auto Theft              87.0  7     7 - Thomas/Dale(Frogtown)
# 572  Robbery                 87.0  7     7 - Thomas/Dale(Frogtown)
# 573  Auto Theft              87.0  7     7 - Thomas/Dale(Frogtown)
# 574  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
# 575  Robbery                 87.0  7     7 - Thomas/Dale(Frogtown)
# 576  Narcotics               87.0  7     7 - Thomas/Dale(Frogtown)
#
#                             Block CallDispCode      CallDisposition  Count  \
# 0    thomas av  & milton           A            A - Advised          1
# 1    lexington pa n & university   A            A - Advised          1
# 2    milton st n & thomas          RR           RR - Report Written  1
# 3    chatsworth st n & university  A            A - Advised          1
# 4    edmund av  & victoria         RR           RR - Report Written  1
# 5    charles av  & lexington       RR           Report Written       1
# 6    charles av  & oxford          RR           Report Written       1
# 7    university av w & lexington   A            Advised              1
# 8    oxford st n & thomas          RR           Report Written       1
# 9    sherburne av  & victoria      RR           Report Written       1
# 10   thomas av  & milton           A            Advised              1
# 11   thomas av  & milton           A            Advised              1
# 12   milton st n & university      A            Advised              1
# 13   chatsworth st n & university  A            Advised              1
# 14   university av w & lexington   A            Advised              1
# 15   sherburne av  & chatsworth    A            Advised              1
# 16   university av w & chatsworth  A            Advised              1
# 17   lexington pa n & lafond       A            Advised              1
# 18   university av w & lexington   A            Advised              1
# 19   charles av  & victoria        RR           Report Written       1
# 20   university av w & lexington   A            Advised              1
# 21   lafond av  & milton           A            Advised              1
# 22   charles av  & milton          RR           Report Written       1
# 23   chatsworth st n & university  A            Advised              1
# 24   lexington pa n & university   RR           Report Written       1
# 25   university av w & chatsworth  A            Advised              1
# 26   chatsworth st n & thomas      RR           Report Written       1
# 27   sherburne av  & milton        A            Advised              1
# 28   university av w & chatsworth  A            Advised              1
# 29   chatsworth st n & sherburne   A            Advised              1
# ..                           ...  ..                ...             ..
# 547  chatsworth st n & lafond      G            Gone on Arrival      1
# 548  oxford st n & university      A            Advised              1
# 549  blair av  & victoria          RR           Report Written       1
# 550  lexington pa n & university   RR           Report Written       1
# 551  lafond av  & oxford           RR           Report Written       1
# 552  milton st n & sherburne       RR           Report Written       1
# 553  lexington pa n & sherburne    A            Advised              1
# 554  milton st n & university      RR           Report Written       1
# 555  university av  & chatsworth   G            Gone on Arrival      1
# 556  chatsworth st n & university  RR           Report Written       1
# 557  chatsworth st n & university  RR           Report Written       1
# 558  oxford st n & university      RR           Report Written       1
# 559  chatsworth st n & university  RR           Report Written       1
# 560  milton st n & university      RR           Report Written       1
# 561  lexington pa n & university   RR           Report Written       1
# 562  milton st n & university      G            Gone on Arrival      1
# 563  university av  & chatsworth   G            Gone on Arrival      1
# 564  university av  & chatsworth   G            Gone on Arrival      1
# 565  edmund av  & milton           G            Gone on Arrival      1
# 566  edmund av  & milton           G            Gone on Arrival      1
# 567  chatsworth st n & university  RR           Report Written       1
# 568  edmund av  & milton           G            Gone on Arrival      1
# 569  milton st n & university      RR           Report Written       1
# 570  milton st n & university      A            Advised              1
# 571  chatsworth st n & university  RR           Report Written       1
# 572  edmund av  & victoria         RR           Report Written       1
# 573  university av  & lexington    A            Advised              1
# 574  oxford st n & sherburne       A            Advised              1
# 575  lexington pa n & university   RR           Report Written       1
# 576  chatsworth st n & sherburne   RR           Report Written       1
#
#      Intersection  Inter      Inter1      Inter2                    Key  \
# 0    1             1      thomas      milton      thomas_milton
# 1    1             1      lexington   university  lexington_university
# 2    1             1      milton      thomas      milton_thomas
# 3    1             1      chatsworth  university  chatsworth_university
# 4    1             1      edmund      victoria    edmund_victoria
# 5    1             1      charles     lexington   charles_lexington
# 6    1             1      charles     oxford      charles_oxford
# 7    1             1      university  lexington   university_lexington
# 8    1             1      oxford      thomas      oxford_thomas
# 9    1             1      sherburne   victoria    sherburne_victoria
# 10   1             1      thomas      milton      thomas_milton
# 11   1             1      thomas      milton      thomas_milton
# 12   1             1      milton      university  milton_university
# 13   1             1      chatsworth  university  chatsworth_university
# 14   1             1      university  lexington   university_lexington
# 15   1             1      sherburne   chatsworth  sherburne_chatsworth
# 16   1             1      university  chatsworth  university_chatsworth
# 17   1             1      lexington   lafond      lexington_lafond
# 18   1             1      university  lexington   university_lexington
# 19   1             1      charles     victoria    charles_victoria
# 20   1             1      university  lexington   university_lexington
# 21   1             1      lafond      milton      lafond_milton
# 22   1             1      charles     milton      charles_milton
# 23   1             1      chatsworth  university  chatsworth_university
# 24   1             1      lexington   university  lexington_university
# 25   1             1      university  chatsworth  university_chatsworth
# 26   1             1      chatsworth  thomas      chatsworth_thomas
# 27   1             1      sherburne   milton      sherburne_milton
# 28   1             1      university  chatsworth  university_chatsworth
# 29   1             1      chatsworth  sherburne   chatsworth_sherburne
# ..  ..            ..             ...        ...                    ...
# 547  1             1      chatsworth  lafond      chatsworth_lafond
# 548  1             1      oxford      university  oxford_university
# 549  1             1      blair       victoria    blair_victoria
# 550  1             1      lexington   university  lexington_university
# 551  1             1      lafond      oxford      lafond_oxford
# 552  1             1      milton      sherburne   milton_sherburne
# 553  1             1      lexington   sherburne   lexington_sherburne
# 554  1             1      milton      university  milton_university
# 555  1             1      university  chatsworth  university_chatsworth
# 556  1             1      chatsworth  university  chatsworth_university
# 557  1             1      chatsworth  university  chatsworth_university
# 558  1             1      oxford      university  oxford_university
# 559  1             1      chatsworth  university  chatsworth_university
# 560  1             1      milton      university  milton_university
# 561  1             1      lexington   university  lexington_university
# 562  1             1      milton      university  milton_university
# 563  1             1      university  chatsworth  university_chatsworth
# 564  1             1      university  chatsworth  university_chatsworth
# 565  1             1      edmund      milton      edmund_milton
# 566  1             1      edmund      milton      edmund_milton
# 567  1             1      chatsworth  university  chatsworth_university
# 568  1             1      edmund      milton      edmund_milton
# 569  1             1      milton      university  milton_university
# 570  1             1      milton      university  milton_university
# 571  1             1      chatsworth  university  chatsworth_university
# 572  1             1      edmund      victoria    edmund_victoria
# 573  1             1      university  lexington   university_lexington
# 574  1             1      oxford      sherburne   oxford_sherburne
# 575  1             1      lexington   university  lexington_university
# 576  1             1      chatsworth  sherburne   chatsworth_sherburne
#
#        Clumped Coordinates
# 0    44.959361, -93.139031
# 1    44.955826, -93.146539
# 2    44.959361, -93.139031
# 3    44.955828, -93.141563
# 4    44.958449, -93.136487
# 5    44.957558, -93.146543
# 6    44.957553, -93.144087
# 7    44.955826, -93.146539
# 8    44.959368, -93.144091
# 9    44.956632, -93.136486
# 10   44.959361, -93.139031
# 11   44.959361, -93.139031
# 12   44.955831, -93.139018
# 13   44.955828, -93.141563
# 14   44.955826, -93.146539
# 15   44.956638, -93.141563
# 16   44.955828, -93.141563
# 17   44.960284, -93.146534
# 18   44.955826, -93.146539
# 19   44.957542, -93.136495
# 20   44.955826, -93.146539
# 21   44.960266, -93.139028
# 22   44.957543, -93.139026
# 23   44.955828, -93.141563
# 24   44.955826, -93.146539
# 25   44.955828, -93.141563
# 26   44.959365, -93.141564
# 27   44.956645, -93.139025
# 28   44.955828, -93.141563
# 29   44.956638, -93.141563
# ..                     ...
# 547  44.960268, -93.141565
# 548  44.955836, -93.144082
# 549  44.961174, -93.136490
# 550  44.955826, -93.146539
# 551  44.960278, -93.144086
# 552  44.956645, -93.139025
# 553  44.956644, -93.146545
# 554  44.955831, -93.139018
# 555  44.955828, -93.141563
# 556  44.955828, -93.141563
# 557  44.955828, -93.141563
# 558  44.955836, -93.144082
# 559  44.955828, -93.141563
# 560  44.955831, -93.139018
# 561  44.955826, -93.146539
# 562  44.955831, -93.139018
# 563  44.955828, -93.141563
# 564  44.955828, -93.141563
# 565  44.958450, -93.139026
# 566  44.958450, -93.139026
# 567  44.955828, -93.141563
# 568  44.958450, -93.139026
# 569  44.955831, -93.139018
# 570  44.955831, -93.139018
# 571  44.955828, -93.141563
# 572  44.958449, -93.136487
# 573  44.955826, -93.146539
# 574  44.956642, -93.144086
# 575  44.955826, -93.146539
# 576  44.956638, -93.141563
#
# [577 rows x 19 columns]

# %%
dfW=df.query('Intersection==0')
dfW


#dfW['Block1']= dfW.Block.str.replace(' w',' west')
#dfW['Block1']= dfW.Block.str.replace(' e',' east')
#dfW['Block1']= dfW.Block.str.replace(' n',' north')
#dfW['Block1']= dfW.Block.str.replace(' s',' south')
dfW['Block1']= dfW.Block.str.replace('xx','00')
dfW['Block1']= dfW.Block1.str.replace('x ','0 ')
#dfW['Block1']= dfW.Block1.str.replace(' pa ' ,' parkway ')
#dfW['Block1']= dfW.Block1.str.replace(' w',' west')
#dfW['Block1']= dfW.Block.str.replace(' e',' east')
#dfW['Block1']= dfW.Block.str.replace(' n',' north')
#dfW['Block1']= dfW.Block.str.replace(' s',' south')

# %%
dfW['Address']= dfW['Block1'] + ', Saint Paul, MN, 55104'
#print(dfW['Address'].unique())
#rint(dfW['Block1'].unique())

A=dfW[['Block','Block1','Address']].sort_values('Address')
#print(A)
A=A.groupby(['Address','Block']).count()
A=A.reset_index()
A.shape
B=A.loc[0:50,:]
C=A.loc[51:100,:]
D=A.loc[101:150,:]
E=A.loc[151:200,:]
F=A.loc[201:,]

# %%
#from geopy.geocoders import Nominatim
#nom=Nominatim()
#pd.set_option('display.max_colwidth', -1)

#get_google_results


import geocoder 
import requests
#geocoder.google("1022 edmund avenue west, St. Paul, MN, 55104", key=API_KEY)
#API_KEY = 'AIzaSyCvJaUnOOixAfRU0f9n8ZmceMDj-wRVrfw'
#RETURN_FULL_RESULTS = False
#b= get_google_results('1022 edmund avenue west, St. Paul, MN, 55104')
#b
#allows to display
#B['Coordinates']= B['Address'].apply(get_google_results)
C['Coordinates']= C['Address'].apply(get_google_results)
#D['Coordinates']= D['Address'].apply(nom.geocode)
#E['Coordinates']= E['Address'].apply(nom.geocode)
#F['Coordinates']= F['Address'].apply(nom.geocode)

#dfW.shape
#b['formatted_address']
#b['latitude']

# %%
B['For_Address'] = B['Coordinates'].apply(lambda x: x['formatted_address']) #intersection
B['Latitude'] = B['Coordinates'].apply(lambda x: x['latitude']) 
B['Longitude'] = B['Coordinates'].apply(lambda x: x['longitude']) 
#B[['For_Address', 'Address', ]]
# Out:
#                                       For_Address  \
# 0   1000 Blair Ave, St Paul, MN 55104, USA
# 1   1000 Charles Ave, St Paul, MN 55104, USA
# 2   1000 Edmund Ave W, St Paul, MN 55104, USA
# 3   1000 Lafond Ave, St Paul, MN 55104, USA
# 4   1000 Sherburne Ave, St Paul, MN 55104, USA
# 5   1000 Sherburne Ave, St Paul, MN 55104, USA
# 6   1000 Thomas Ave W, St Paul, MN 55104, USA
# 7   1000 Van Buren Ave, St Paul, MN 55104, USA
# 8   1010 Blair Ave, St Paul, MN 55104, USA
# 9   1010 Charles Ave, St Paul, MN 55104, USA
# 10  1010 Lafond Ave, St Paul, MN 55104, USA
# 11  1010 W Minnehaha Ave, St Paul, MN 55104, USA
# 12  1010 Sherburne Ave, St Paul, MN 55104, USA
# 13  1010 Thomas Ave W, St Paul, MN 55104, USA
# 14  1010 Van Buren Ave, St Paul, MN 55104, USA
# 15  1020 Charles Ave, St Paul, MN 55104, USA
# 16  1020 Edmund Ave W, St Paul, MN 55104, USA
# 17  1020 Lafond Ave, St Paul, MN 55104, USA
# 18  1020 W Minnehaha Ave, St Paul, MN 55104, USA
# 19  1020 Sherburne Ave, St Paul, MN 55104, USA
# 20  1020 Van Buren Ave, St Paul, MN 55104, USA
# 21  1030 Blair Ave, St Paul, MN 55104, USA
# 22  1030 Charles Ave, St Paul, MN 55104, USA
# 23  1030 Edmund Ave W, St Paul, MN 55104, USA
# 24  1030 Lafond Ave, St Paul, MN 55104, USA
# 25  1030 W Minnehaha Ave, St Paul, MN 55104, USA
# 26  1030 Thomas Ave W, St Paul, MN 55104, USA
# 27  1030 University Ave W, St Paul, MN 55104, USA
# 28  1030 Van Buren Ave, St Paul, MN 55104, USA
# 29  1040 Blair Ave, St Paul, MN 55104, USA
# 30  1040 Charles Ave, St Paul, MN 55104, USA
# 31  1040 Edmund Ave W, St Paul, MN 55104, USA
# 32  1040 Grand Ave, St Paul, MN 55105, USA
# 33  1040 Lafond Ave, St Paul, MN 55104, USA
# 34  1040 W Minnehaha Ave, St Paul, MN 55104, USA
# 35  1040 Sherburne Ave, St Paul, MN 55104, USA
# 36  1040 Thomas Ave W, St Paul, MN 55104, USA
# 37  1040 University Ave W, St Paul, MN 55104, USA
# 38  1040 Van Buren Ave, St Paul, MN 55104, USA
# 39  1050 Edmund Ave W, St Paul, MN 55104, USA
# 40  1050 Lafond Ave, St Paul, MN 55104, USA
# 41  1050 W Minnehaha Ave, St Paul, MN 55104, USA
# 42  1050 Sherburne Ave, St Paul, MN 55104, USA
# 43  1050 Van Buren Ave, St Paul, MN 55104, USA
# 44  1060 Blair Ave, St Paul, MN 55104, USA
# 45  1060 Charles Ave, St Paul, MN 55104, USA
# 46  1060 Edmund Ave W, St Paul, MN 55104, USA
# 47  1060 Lafond Ave, St Paul, MN 55104, USA
# 48  1060 W Minnehaha Ave, St Paul, MN 55104, USA
# 49  1060 Sherburne Ave, St Paul, MN 55104, USA
# 50  1060 Thomas Ave W, St Paul, MN 55104, USA
#
#                                         Address
# 0   1000 blair av, Saint Paul, MN, 55104
# 1   1000 charles av, Saint Paul, MN, 55104
# 2   1000 edmund av, Saint Paul, MN, 55104
# 3   1000 lafond av, Saint Paul, MN, 55104
# 4   1000 sherburne av, Saint Paul, MN, 55104
# 5   1000 sherburne av, Saint Paul, MN, 55104
# 6   1000 thomas av, Saint Paul, MN, 55104
# 7   1000 vanburen av, Saint Paul, MN, 55104
# 8   1010 blair av, Saint Paul, MN, 55104
# 9   1010 charles av, Saint Paul, MN, 55104
# 10  1010 lafond av, Saint Paul, MN, 55104
# 11  1010 minnehaha av w, Saint Paul, MN, 55104
# 12  1010 sherburne av, Saint Paul, MN, 55104
# 13  1010 thomas av, Saint Paul, MN, 55104
# 14  1010 vanburen av, Saint Paul, MN, 55104
# 15  1020 charles av, Saint Paul, MN, 55104
# 16  1020 edmund av, Saint Paul, MN, 55104
# 17  1020 lafond av, Saint Paul, MN, 55104
# 18  1020 minnehaha av w, Saint Paul, MN, 55104
# 19  1020 sherburne av, Saint Paul, MN, 55104
# 20  1020 vanburen av, Saint Paul, MN, 55104
# 21  1030 blair av, Saint Paul, MN, 55104
# 22  1030 charles av, Saint Paul, MN, 55104
# 23  1030 edmund av, Saint Paul, MN, 55104
# 24  1030 lafond av, Saint Paul, MN, 55104
# 25  1030 minnehaha av w, Saint Paul, MN, 55104
# 26  1030 thomas av, Saint Paul, MN, 55104
# 27  1030 university av w, Saint Paul, MN, 55104
# 28  1030 vanburen av, Saint Paul, MN, 55104
# 29  1040 blair av, Saint Paul, MN, 55104
# 30  1040 charles av, Saint Paul, MN, 55104
# 31  1040 edmund av, Saint Paul, MN, 55104
# 32  1040 grand av, Saint Paul, MN, 55104
# 33  1040 lafond av, Saint Paul, MN, 55104
# 34  1040 minnehaha av w, Saint Paul, MN, 55104
# 35  1040 sherburne av, Saint Paul, MN, 55104
# 36  1040 thomas av, Saint Paul, MN, 55104
# 37  1040 university av w, Saint Paul, MN, 55104
# 38  1040 vanburen av, Saint Paul, MN, 55104
# 39  1050 edmund av, Saint Paul, MN, 55104
# 40  1050 lafond av, Saint Paul, MN, 55104
# 41  1050 minnehaha av w, Saint Paul, MN, 55104
# 42  1050 sherburne av, Saint Paul, MN, 55104
# 43  1050 vanburen av, Saint Paul, MN, 55104
# 44  1060 blair av, Saint Paul, MN, 55104
# 45  1060 charles av, Saint Paul, MN, 55104
# 46  1060 edmund av, Saint Paul, MN, 55104
# 47  1060 lafond av, Saint Paul, MN, 55104
# 48  1060 minnehaha av w, Saint Paul, MN, 55104
# 49  1060 sherburne av, Saint Paul, MN, 55104
# 50  1060 thomas av, Saint Paul, MN, 55104

# %%
C['For_Address'] = C['Coordinates'].apply(lambda x: x['formatted_address']) #intersection
C['Latitude'] = C['Coordinates'].apply(lambda x: x['latitude']) 
C['Longitude'] = C['Coordinates'].apply(lambda x: x['longitude']) 
C[['For_Address', 'Address', ]]

# %%
#Address_Clean= pd.concat([B_Clean, C_Clean, D_Clean, E_Clean, F_Clean], ignore_index=True)
#Address_Clean
#Address_Mess= pd.concat([B_Mess, C_Mess, D_Mess, E_Mess, F_Mess], ignore_index=True)
#Address_Mess

# %%
#interation of numeric 1

M =Address_Mess
M['Block1']= M.Block.str.replace('xx','01')
M['Block1']= M.Block1.str.replace('x ','1 ')

M['Address']= M['Block1'] + ', Saint Paul, MN, 55104'
#print(dfW['Address'].unique())
#rint(dfW['Block1'].unique())

A=M[['Block','Block1','Address']].sort_values('Address')
#print(M)
A=A.groupby(['Address','Block']).count()
A=A.reset_index()
A.shape
B=A.loc[0:50,:]
C=A.loc[51:100,:]
D=A.loc[101:,:]
#E=A.loc[151:200,:]
#F=A.loc[201:,]

# %%
# Out:
# Location(1000, Sherburne Avenue, St. Paul, Ramsey County, Minnesota, 55104, USA, (44.956552, -93.144261, 0.0))

# %%
import geocoder 
API_KEY = 'AIzaSyCvJaUnOOixAfRU0f9n8ZmceMDj-wRVrfw'
RETURN_FULL_RESULTS = False

g = geocoder.google("1022 edmund avenue west, St. Paul, MN, 55104", key='AIzaSyCvJaUnOOixAfRU0f9n8ZmceMDj-wRVrfw')
#g = geocoder.google('Mountain View, CA', key='puting my key here')
#result = geocoder.geocode("7250 South Tucson Boulevard, Tucson, AZ 85756")

g.housenumber
# Out:
# '1022'

# %%
def get_google_results(address, api_key='AIzaSyCvJaUnOOixAfRU0f9n8ZmceMDj-wRVrfw', return_full_response=False):
    """
    Get geocode results from Google Maps Geocoding API.
    
    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.
    
    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google. 
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
#    results =results['formatted_address']
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng')
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
g.latlng
# Out:
# [44.9582163, -93.143256]
