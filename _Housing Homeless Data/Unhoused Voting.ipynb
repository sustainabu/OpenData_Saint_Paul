# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
import requests # library to handle requests
import folium
import seaborn as sns
import scipy.stats as stats #used to get correlation coefficient


MP_20 = pd.read_csv('Mpls_Unhouse1.csv')
MP_20
# Out:
#                  Precinct  Tot_People  Est_Vouchers  Sign_Vouchers  Progress  \
# 0     Minneapolis W-1 P-1          34             5              5      1.00
# 1     Minneapolis W-1 P-6         454            57              6      0.11
# 2     Minneapolis W-1 P-8          12             2              4      2.00
# 3     Minneapolis W-2 P-9          34             5              3      0.60
# 4     Minneapolis W-3 P-5          56             7              2      0.29
# 5     Minneapolis W-3 P-6          24             3              7      2.33
# 6    Minneapolis W-3 P-10          24             3              8      2.67
# 7    Minneapolis W-5 P-6C          90            12             10      0.83
# 8    Minneapolis W-7 P-10          26             4             14      3.50
# 9     Minneapolis W-9 P-4          34             5             12      2.40
# 10  Minneapolis W-12 P-11          15             2             10      5.00
#
#     Blah
# 0     10
# 1     20
# 2     30
# ...

# %%
sp_geo = r'Minneapolis_housing.json'
    
 # generate a new map
SP_map = folium.Map(location=[44.9766261,-93.2783891], zoom_start=13.25,tiles="OpenStreetMap")

SP_map.choropleth(
    geo_data=sp_geo,
    data=MP_20,
    columns=['Precinct','Blah'],
    key_on="feature.properties.Precinct1",
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='2020 Saint Paul Ballot Request%: 10/10/20',
    highlight= True
)
                          
# display map
SP_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sp_geo = r'Minneapolis_housing.json'
    
 # generate a new map
SP_map = folium.Map(location=[44.9766261,-93.2783891], zoom_start=12,tiles="OpenStreetMap")

SP_map.choropleth(
    geo_data=sp_geo,
    data=MP_20,
    columns=['Precinct','Tot_People'],
    key_on="feature.properties.Precinct",
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='2020 Saint Paul Ballot Request%: 10/10/20',
    highlight= True
)
                          
# display map
SP_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sp_geo = r'SaintPaul_VotingPrecincts.json'
    # generate a new map
SP_map = folium.Map(location=[44.953930, -93.096058], zoom_start=12,tiles="OpenStreetMap")

SP_map.choropleth(
    geo_data=sp_geo,
    data=Abs_20,
    columns=['PrecinctName','Ballot_Request'],
    key_on="feature.properties.Precinct1",
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='2020 Saint Paul Ballot Request%: 10/10/20',
    highlight= True
)
    #folium.LayerControl().add_to(SP_map)
                             
    # display map
SP_map

# %%
sp_geo = r'Minneapolis_housing.json'
sp_geo
# Out:
# 'Minneapolis_housing.json'

# %%
sp_geo = r'SaintPaul_VotingPrecincts.json'
    
 # generate a new map
SP_map = folium.Map(location=[44.9766261,-93.2783891], zoom_start=12,tiles="OpenStreetMap")
                          
# display map
SP_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
