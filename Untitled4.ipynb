# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import mpld3


mpld3.enable_notebook()

# %%
np.random.seed(0)
plt.plot(np.random.rand(10));

# %%
from mpld3 import plugins

fig, ax = plt.subplots()
points = ax.scatter(np.random.rand(40), np.random.rand(40),
                    s=300, alpha=0.3)

labels = ["Point {0}".format(i) for i in range(40)]
tooltip = plugins.PointLabelTooltip(points, labels)

plugins.connect(fig, tooltip)

# %%
import pandas as pd

# %%
from mpld3 import plugins

A=pd.read_csv('CC_Lex.csv')
x=A.index1.values.tolist()
y=A.Latitude.values.tolist()

fig, ax = plt.subplots()
points = ax.scatter(x,y,
                    s=50, alpha=0.3)

labels = ["Point {0}".format(i) for i in range(151)]
tooltip = plugins.PointLabelTooltip(points, labels)

plugins.connect(fig, tooltip)
