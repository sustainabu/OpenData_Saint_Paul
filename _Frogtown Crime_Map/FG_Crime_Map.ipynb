# %% [markdown]
# <p><img style="padding: 0 15px; float: left;" src="Images/FTLogo300.jpg" alt="FT Crusader Logo" Width='140' Height= '250'/></p>
# <p> <h2> Frogtown, MN, Crime Map 01/29/20</h2> <a name="tc"></a>
# <p> <h3> By Frogtown Crusader (Abu Nayeem)</h3>

# %% [markdown]
# ## Table of contents <a name="content"></a>
# * [Purpose](#purpose)
# * [Data](#data)
# * [Frogtown All Crime](#all_crime)
#     * [Graph: Frogtown Longitudinal Crime Uptodate](#fgd_crime)
#     * [Table: Frogtown Longitudinal Crime Uptodate by Month](#fgd_month)
#     * [Graph: Saint Paul Longitudinal Crime Uptodate](#sp_crime)
#     * [Map: Frogtown 2018 Crime Map](#2018map)
#     * [Map: Frogtown 2019 to Present Crime Map w/ Proactive visits](#2019map)
#     * [Map: Frogtown Violent Crime 2017 to Present Crime Map](#violent)
#     * [Map: Frogtown Multicrime Map](#multi)
# * [Frogtown Hotspots w/ map](#hotspot)
# * [Frogtown Shooting Report/ include Saint Paul](#discharge)
#     * [Map: Frogtown Longitudinal Discharge Map Uptodate](#fgd_dis)
#     * [Map: Frogtown Longitudinal Discharge Map on Daytime Uptodate](#fgd_day)
#     * [Map: Frogtown Longitudinal Annual Discharge Map](#fgd_ann)
#     * [Graph: Frogtown Longitudinal Firearms Uptodate](#firearm)
# * [Concluding Remarks](#conclude)
# * [Functions](#func)
# * [Functions_Run](#runall)

# %% [markdown]
# ### Purpose <a name="purpose"></a>
#
# As a Frogtown resident, it is important that residents are aware on what is happening around our community and how we address it. Every year, there is commotion about safety. Some community members feel that the community is getting worse, while others are saying its getting better. While the city and police department might be saying something totally different. In our current political climate, it's controversial to talk about crime given it's strong correlation with poverty. Unfortunately, this can disenfranchise some community members whom are victims of crime and live in heavy crime areas on a daily basis. These reports and graphs are met to just shed light on the issue and encourage community members to see and interact with the data themselves. Hopefully, the community and/or agencies will take action. **Note:** Parts of Midway, Rondo, and Union City are included.
#
# Some questions that you may consider:
# * What are vulnerable areas or hotspots in the community?
# * Are certain crimes more frequent in your area, and how should you or the community address it?
# * What are some trends in the your community?
# * What is the frequency of calling the police in nearby area? Is there over-reporting/ under-reporting?
# * How can we address these issues as a community (i.e. organizing; etc)?

# %% [markdown]
# ### Open Source Data Initiative
#
# It is important that data is accessible and provided to the public. This report and others will be available on Github allowing others to contribute, replicate, and use code for their own respective neighborhood. If anyone is interested in mapping out East Side, Payne Phalen, etc., please reach out to me.
#
# You can use the data provided by this report, but understand that I'm not an official agency and not liable for incorrect data.

# %% [markdown]
# ### About the Dataset: <a name="data"></a>
#
# The [Crime Incident Report - Dataset](https://information.stpaul.gov/Public-Safety/Crime-Incident-Report-Dataset/gppb-g9cg) was obtained from the Saint Paul Website. It is publicly available. The report contains incidents from Aug 14 2014 through the most recent date, as released by the Saint Paul Police Department.
#
# A few notes about the dataset:
# * The dataset have several human errors such as mis-categorizing addresses and address being designated to the wrong police grid.
# * The dataset **DOES NOT PROVIDE EXACT ADDRESSES/ GEO-COORDINATES**. However, I've constructed an algorithm that get a reliable proxy address for most entries.
#     * The process included entering coordinate manually; if any residents are interested in mapping out their own community please feel free to connect with me.
#     * Google Maps geocoder was used
#     * The algorithm **does not cover** the intersections of Capitol Heights and Mt. Airy region. Some data was excluded from region due to inadequate mapping. They have many intersections and curved streets; it would take time to geo-code it.
# * The analysis/algorithm is restricted near the Frogtown area.

# %% [markdown]
# ### Saint Paul Police grid w/ total crime numbers all years [excluding proactive visits] <a name="all_crime"></a>
#
# The dataset comprise this area.
#
# ![title](Images/gridnum1.jpg)

# %% [markdown]
# #### Display Total Incidents of all years
#
# **NOTE:** The following changes were made in the crime category to consolidate categories
# * Graffiti was combined into Vandalism
# * Violent Crimes combined the categories: Rape, Homicide, Aggressive Assault
# * Domestic Assault includes both Simple and Aggressive Assaults
# * Community Engagement Events and Proactive Police Visit are not crimes. Proactive Police Visit is not response to 911 call. They will be excluded for vast majority of the analysis

# %%
print('List of Events in Frogtown (nearby) from 2019 to Present')
fg.query('Year>=2019')['Incident'].value_counts()
# Out:
# List of Events in Frogtown (nearby) from 2019 to Present
# Proactive Police Visit        4417
# Theft                         1396
# Vandalism                      418
# Auto Theft                     401
# Narcotics                      281
# Domestic Assault               226
# Discharge                      225
# Burglary                       223
# Community Engagement Event     128
# Robbery                        101
# Violent                         86
# Arson                           14
# Name: Incident, dtype: int64

# %% [markdown]
# ### Frogtown Yearly Crime Comparison Up to Current Date <a name="fgd_crime"></a>
#
# How much crime is there so far in comparison to the previous year on this date? Are certain areas increasing or decreasing? **Note:** the function can choose any day prior to the current date.
#
# We choose the max date for the dataset. We can choose an earlier date if desired

# %%
plot_toDate_Year_Crime(Incident='All',Day=Max)
# Out:
# This graph maps All incidents up to 1/29/20XX

# %% [markdown]
# ### Frogtown Total Crimes toDate by Month <a name="fgd_month"></a>
#
# What are some monthly trends

# %%
table_toDate_Month_Crime(Incident='All',Day=Max)
# Out:
# This table maps All incidents up to Day 1/29/20XX
# Month                      1
# Year                    2018 2019 2020
# Community         Grid
# Midway            66.0     1    0    0
#                   86.0    25   14   14
# Summit-University 107.0   17   24   14
#                   108.0   10   23   19
#                   109.0    8    3    8
#                   110.0   19   17   11
# Thomas-Frogtown   67.0     9    6    9
#                   68.0     4    3    3
#                   87.0    24   19   23
#                   88.0    18   26   25
#                   89.0    47   31   41
#                   90.0    31   15   20
#                   91.0     6    3    3
#                   92.0     0    0    1
# Union Park        106.0   32   35   49

# %% [markdown]
# ### Saint Paul Yearly Crime Comparison Up to Current Date <a name="sp_crime"></a>
#
# How do we compare to our neighbors and what are some trends?

# %%
plot_toDate_Year_SPCrime(Incident='All',Day=Max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ba2613de9668> in <module>
# ----> 1 plot_toDate_Year_SPCrime(Incident='All',Day=Max)
#
# NameError: name 'plot_toDate_Year_SPCrime' is not defined

# %% [markdown]
# ## Frogtown Annual Crime Map (Default 2020) <a name="2018map"></a>
# At least four crimes must occur in one location to be displayed
#
# **NOTE: It's interactive, click on the circles for more details on the total number and type of crimes committed**

# %%
plot_Frogtown_year(2020)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Frogtown Violent Crimes Map from 2018 to Present  <a name="violent"></a>
#
# Violent crimes are less salient or apparent to community members. We can see which areas/ blocks are safer.
#
# * Orange= 2018
# * Green= 2019
# * Purple= 2020

# %%
plot_Frogtown_long_crime('Violent')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Frogtown 2020 Multi-Crime Map  <a name="multi"></a>
#
# * Purple= Discharge
# * Green= Autotheft
# * Orange= Theft
# * Blue= Burglary
# * Brown= Narcotics
# * Red= Vandalism

# %%
plot_multicrime_byYear(2020)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Hotspots near Frogtown from 2019 to present <a name="hotspot"></a>
#
# Notice the address codes are masked and count is limited to 15

# %%
B=fgc.query('Year in [2019,2020]')
B=B[['Block','Count']].groupby(['Block']).sum().reset_index()
B.columns=['Block_Intersection','Count']
B.query('Count>14').sort_values(['Count'], ascending=False)
# Out:
#        Block_Intersection  Count
# 143  130x university av w    490
# 114  123x university av w     54
# 200    27x lexington pa n     53
# 491           62x rice st     48
# 271    39x lexington pa n     38
# 844    95x lexington pa n     33
# 161        17x charles av     26
# 971    hamline_university     25
# 120     124x stanthony av     23
# 642       75x milton st n     23
# 929       dale_university     22
# 376           50x rice st     20
# 872   98x university av w     20
# 343         46x dale st n     19
# 51   107x university av w     18
# 163         19x edmund av     16
# 483         62x aurora av     15

# %% [markdown]
# ### Frogtown Hotspot Interactive map from 2019 to present <a name="hotspot"></a>
#
# * The bubbles are **not to scale** across the different categories to make this map more accessible. You  may need to zoom in to distinguish points
# * The graph is **Interactive**; if you click on a point, it will list the number and  type of incidents in that area
# * Legend
#     * Orange: Number of Incidents greater than 10 and less than 20
#     * Green: Number of Incidents greater than 20 and less than 50
#     * Purple: Number of Incident greater than 50

# %%
plot_Frogtown_hot_spot()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Frogtown Gun Discharge Reports<a name="discharge"></a>
#
#
# We hear it **all** the time from many people that our awareness of shootings is based on connection to social media and officials suggesting it is safer now than years prior. Is this true? Well, let's find out. It's worth noting that weather conditions can influence the frequency of when shootings occur. Finally, the discharge category excludes a firearm being used to assist in another crime.
#
# **Why focus on shootings?**
#
# Shootings can harm innocent bystanders and creates a significant sense of fear because it can be heard from a distance. It is one of the more salient crimes.
#
# First let's construct graph a table showing the total number of shootings up to current date in comparison to previous years. Notice that many grids are experiencing different trends, so it can be true that some neighbors are exposed to more shootings this year and others less.

# %%
plot_toDate_Year_Crime(Incident='Discharge',Day=Max)
# Out:
# This graph maps Discharge incidents up to 1/29/20XX

# %% [markdown]
# What are some trends at the city-wide level?

# %%
plot_toDate_Year_SPCrime(Incident='Discharge',Day=Max)
# Out:
# This graph maps Discharge incidents of Saint Paul neighborhoods up to 1/29/20XX

# %% [markdown]
# The table below displays the number of shootings by grid in Frogtown broken by month over the last two years

# %%
table_toDate_Month_Crime(Incident='Discharge',Day=Max)
# Out:
# This table maps Discharge incidents up to Day 1/29/20XX
# Month                      1
# Year                    2018 2019 2020
# Community         Grid
# Midway            86.0     0    1    1
# Summit-University 107.0    1    2    3
#                   108.0    0    2    5
#                   110.0    1    0    1
# Thomas-Frogtown   68.0     1    0    1
#                   87.0     1    3    3
#                   88.0     2    3    3
#                   89.0     6    1    9
# Union Park        106.0    1    0    0

# %% [markdown]
# ### Frogtown UptoDate gun discharge map  2020 to Present (interactive) <a name="fgd_dis"></a>
#
# A police Grid can cover a lot of area. From the map we can spot parts of the community that are currently vulnerable and those in the past.
#
# * Orange= 2018
# * Green= 2019
# * Purple= 2020

# %%
plot_Frogtown_long_crime_todate(Incident='Discharge',Day=Max)
# Out:
# This map displays Discharge incidents up to 1/29/20XX
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Frogtown UptoDate Daytime Discharge Map <a name="fgd_day"></a>
#
# Daytime shooting are particularly concerning to our community as there as there are greater frequency of innocent bystanders being harmed and can influence community members behavior to go outside or parents decision to let their kids play.
#
# * Orange= 2018
# * Green= 2019
# * Purple= 2020

# %%
plot_Frogtown_long_crime_daytime_todate(Incident='Discharge',Day=Max)
# Out:
# This map displays Discharge incidents up to 1/29/20XX from 7AM to 8PM
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Frogtown yearly gun discharge from 2018 to Present  <a name="fgd_ann"></a>
#
# * Orange= 2018
# * Green= 2019
# * Purple= 2020

# %%
plot_Frogtown_long_crime(Incident='Discharge')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Firearm Usage (Any crime involving it) <a name="firearm"></a>
#
# Often firearms are used when committing another crime, but does not need to be fired.

# %%
print('The total crimes involving firearms in Frogtown Area')
fgc_fire['Incident'].value_counts()
# Out:
# The total crimes involving firearms in Frogtown Area
# Discharge    1099
# Robbery       257
# Violent       231
# Name: Incident, dtype: int64

# %%
plot_toDate_Year_Firearm(Day=Max)
# Out:
# This graph maps Firearm incidents up to 1/29/20XX

# %%
plot_toDate_Year_SPFirearm()
# Out:
# This graph maps Firearm incidents of Saint Paul neighborhoods up to 1/29/20XX

# %% [markdown]
# ## Concluding Remarks <a name="conclude"></a>
#
# From the data above, we can visually spot sections in the community and specific locations where crime is more frequent. It is important that we have a community discussion before taking any further action. Several agencies have already done some analysis and reports on crime data. If you have any question in regards to visualization and other things, please feel free to reach out to me.

# %% [markdown]
# ## Functions <a name="func"></a>

# %% [markdown]
# #### Plot Multiple Crimes by Year

# %%
def plot_multicrime_byYear(Year=2019):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge']

    T=B.query('Theft==1')
    T=T[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    V=B.query('Vandalism==1')
    V=V[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    N=B.query('Narcotics==1')
    N=N[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    A=B.query('Incident=="Auto Theft"')
    A=A[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    D=B.query('Discharge==1')
    D=D[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    Br=B.query('Burglary==1')
    Br=Br[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

#Create Frogtown GeoMap
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")

    for index, row in T.iterrows(): 
        popup_text = "Address: {}<br> total theft incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)

    for index, row in V.iterrows(): 
        popup_text = "Address: {}<br> total vandalism incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color="#FF0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    

    for index, row in N.iterrows(): 
        popup_text = "Address: {}<br> total narcotics incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Narcotics']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Narcotics'] + 3,
                            color="#654321",
                            popup=popup_text,
                            fill=True).add_to(FG_map)     

    for index, row in A.iterrows(): 
        popup_text = "Address: {}<br> total autotheft incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color='#007849',
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    for index, row in D.iterrows(): 
        popup_text = "Address: {}<br> total discharge incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    

    for index, row in Br.iterrows(): 
        popup_text = "Address: {}<br> total burglary incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    return FG_map

# %% [markdown]
# #### Plot Crime Map by Year

# %%
def plot_Frogtown_year(Year=2018):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    B=B.query('Count>3')
    
    # for each row in the data, add a cicle marker
    for index, row in B.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    return FG_map

# %%
#interact(plot_Frogtown_year, Year=widgets.IntSlider(min=2014,max=2019,step=1,value=2018));

# %% [markdown]
# #### Plot Crime Map by Year w/ proactive visits

# %%
def plot_Frogtown_year_proactive(Year=2018):
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    B= fgc[(fgc['Year'] == Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    
    A= fgp[(fgp['Year'] == Year)]
    A= A.groupby(['Block','Latitude','Longitude']).size().reset_index()
    A.columns=['Block','Latitude','Longitude','Count'] 
    
    for index, row in B.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)

    for index, row in A.iterrows(): 
        popup_text = "Address: {}<br> total proactive calls: {}"
        popup_text = popup_text.format(row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
        
    return FG_map

# %% [markdown]
# #### Plot Longitudinal Crime Compared by Year

# %%
def plot_Frogtown_long_crime(Incident='Discharge'):
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson','Year']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    B= fgc[(fgc['Incident'] == Incident)]
    B17=B.query('Year == 2017')
    B17=B17[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B18=B.query('Year == 2018')
    B18=B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B19=B.query('Year == 2019')
    B19=B19[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()

    for index, row in B17.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B18.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"], row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B19.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
    
    return FG_map

# %%
#interact(plot_Frogtown_long_crime, Incident=['Discharge','Violent','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Robbery','Domestic Assault','Arson'])

# %% [markdown]
# #### Plot Longitudinal Crime Map Compared by Year; todate

# %%
def plot_Frogtown_long_crime_todate(Incident='All',Day=Max):
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson','Year']

    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    B17=B.query('Year == 2017')
    B17=B17[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B18=B.query('Year == 2018')
    B18=B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B19=B.query('Year == 2019')
    B19=B19[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    print('This map displays {} incidents up to {}20XX'.format(Incident,Date))
    for index, row in B17.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B18.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"], row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B19.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
    
    return FG_map

# %% [markdown]
# #### Plot Longitudinal Daytime Crime Map Compared by Year; todate

# %%
def plot_Frogtown_long_crime_daytime_todate(Incident='All',Day=Max):
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson','Year']

    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    B= B.query('Hour >= 6 and Hour <20')
    B17=B.query('Year == 2017')
    B17=B17[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B18=B.query('Year == 2018')
    B18=B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B19=B.query('Year == 2019')
    B19=B19[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    print('This map displays {} incidents up to {}20XX from 7AM to 8PM'.format(Incident,Date))
    for index, row in B17.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B18.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"], row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B19.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
    
    return FG_map

# %% [markdown]
# #### Crime Table toDate by Month

# %%
#convert MOnth
def Convert_Month(num):
    Months= ['January','February','March','April','May','June','July','August','September','October','November','December']
    for i in range(12):
        if num==(i+1):
            Xi=Months[i]
    return Xi 

def table_toDate_Month_Crime(Incident='All',Day=Max):
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    B=B.query('Year >= 2017')
    Index= ['Year','Grid','Count','Month']
    C= B[Index].groupby(['Year','Grid','Month']).sum().reset_index()
    C['Month_Name']= C.Month.apply(Convert_Month) 
    C['Community']= C.Grid.apply(commun)
    print('This table maps {} incidents up to Day {}20XX'.format(Incident,Date))
    return pd.pivot_table(C, values='Count', index=['Community','Grid'], columns=['Month', 'Year'], fill_value=0)

# %% [markdown]
# #### Crime Graph  toDate by Year

# %%
#Crime Plot
import matplotlib.pyplot as plt
import seaborn as sns


def plot_toDate_Year_Crime(Incident='All',Day=Max):
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B=B.query('Year >= 2017')
    B= B[(B['DayYear'] <= Day)]
    Index= ['Year','Grid','Count']
    C= B[Index].groupby(['Year','Grid']).sum().reset_index()
    C['Community']= C.Grid.apply(commun) 
    print('This graph maps {} incidents up to {}20XX'.format(Incident,Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community','Grid'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= Incident + ' Yearly Total Incidents UptoDate: '+ str(Date)+'20XX')
    return plt.show()

# Firearm Plot
def plot_toDate_Year_Firearm(Day=Max):
    B= fgc_fire[(fgc_fire['DayYear'] <= Day)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B.query('Year>2016')
    Index= ['Year','Grid','Count']
    C= B[Index].groupby(['Year','Grid']).sum().reset_index()
    C['Community']= C.Grid.apply(commun) 
    print('This graph maps Firearm incidents up to {}20XX'.format(Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community','Grid'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= 'Firearm Yearly Total Incidents UptoDate: ' + str(Date)+'20XX')
    return plt.show()

# %% [markdown]
# #### Latenight Crime Plot by Year

# %%
def plot_Frogtown_year_Latenight(Year=2018):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']
    BM=B.query('LateNight ==0')
    BM=BM[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    BM=BM.query('Count>2')
    BL=B.query('LateNight ==1')
    BL=BL[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    BL=BL.query('Count>2')
    
    # for each row in the data, add a cicle marker
    for index, row in BM.iterrows(): 
        popup_text = "Year: {} Non-late<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)

    for index, row in BL.iterrows(): 
        popup_text = "Year: {} Late<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)        
    return FG_map

# %%
#plot_Frogtown_year_Latenight(2018)

# %% [markdown]
# #### Frogtown  Plot by Year and month

# %%
def plot_Frogtown_yearmonth(Year=2018,Month=1):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    B= B[(B['Month'] == Month)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    

    # for each row in the data, add a cicle marker
    for index, row in B.iterrows(): 
        Other= row['Count'] - row['Theft'] - row['Vandalism'] - row['Narcotics'] -row['Auto Theft'] - row['Burglary'] - row['Discharge']
        popup_text = "Year: {} Month: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Other: {}"
        popup_text = popup_text.format(str(Year), str(Month),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Narcotics'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], Other) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    return FG_map

# %%
#plot_Frogtown_yearmonth(2018,1)
interact(plot_Frogtown_yearmonth, Year=widgets.IntSlider(min=2014,max=2019,step=1,value=2018),\
         Month=[('January', 1), ('February', 2), ('March',3), ('April',4), ('May',5) ,('June',6),('July',7)]);
# Out:
# interactive(children=(IntSlider(value=2018, description='Year', max=2019, min=2014), Dropdown(description='Mon…

# %% [markdown]
# #### Frogtown plot by year and hour

# %%
def plot_Frogtown_yearhour(Year=2018,Hour=0):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    B= B[(B['Hour'] == Hour)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    

    # for each row in the data, add a cicle marker
    for index, row in B.iterrows(): 
        Other= row['Count'] - row['Theft'] - row['Vandalism'] - row['Narcotics'] -row['Auto Theft'] - row['Burglary'] - row['Discharge']
        popup_text = "Year: {} Hour: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Other: {}"
        popup_text = popup_text.format(str(Year), str(Hour),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Narcotics'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], Other) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    return FG_map

# %% [markdown]
# #### Frogtown Hotspot Map

# %%
def plot_Frogtown_hot_spot(Year=2018):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] >= Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    C=B.query('Count>9 and Count < 21')
    D=B.query('Count>20 and Count < 51')
    E=B.query('Count>50')
    
    # for each row in the data, add a cicle marker
    for index, row in C.iterrows(): 
        popup_text = "Year: 2018/19<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
 
    for index, row in D.iterrows(): 
        popup_text = "Year: 2018/19<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']/5,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    for index, row in E.iterrows(): 
        popup_text = "Year: 2018/19<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']/9,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)        

    return FG_map

# %% [markdown]
# #### Saint Paul Data Load and Crimetable to Date

# %%
#Read Data
df = pd.read_csv('Datasets/Crime_Incident_Report_-_Dataset.csv')
cols= ['Case','Date','Time','Code','IncType','Incident','Grid','NNum','Neighborhood','Block','CallDispCode','CallDisposition', 'Count']
df.columns= cols

#Add Time Variables
df= df[df.Case != 18254093] #messed up time variable
df['Date']= pd.to_datetime(df['Date'])
df['Year']= df['Date'].dt.year
df=df.query('Year > 2016')
df['DayYear'] = df['Date'].dt.dayofyear
df['Community']= df['Grid'].apply(commun)
df= df.query('Code not in [9954,9959] and Community !="NaN"')

def plot_toDate_Year_SPCrime(Incident='All',Day=Max):
    if Incident=='All':
        B= df
    else: 
        B= df[(df['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    Index= ['Year','Community','Count']
    C= B[Index].groupby(['Year','Community']).sum().reset_index()
    print('This graph maps {} incidents of Saint Paul neighborhoods up to {}20XX'.format(Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= Incident + ' Yearly UptoDate Total Incidents')
    return plt.show()

# %% [markdown]
# ## Functions all <a name="runall"></a>
#
# Run to activate all functions

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import pandas as pd
import numpy as np
# %matplotlib inline 
import folium
import warnings
warnings.filterwarnings('ignore')

#Upload Data
fg = pd.read_csv('Datasets\FGCrime_Final.csv')

#Set max limit for uptodate function
Max= fg.loc[1,'Day_Max']

# Set a friendly Date variable
fg['FDate']=fg['Month'].astype(str) + '/' + fg['Day'].astype(str) + '/'

fgp= fg.query('Code in [9954]') # Specify proactive calls
fgc= fg.query('Code not in [9954,9959]') #specify all crime related police visits
fgc_Date= fgc[(fgc['DayYear'] <= Max)] #this specifies to date df
fgc_fire=fgc[fgc['IncType'].str.contains("Firearm")] #specifies all firearm

def plot_multicrime_byYear(Year=2019):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge']

    T=B.query('Theft==1')
    T=T[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    V=B.query('Vandalism==1')
    V=V[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    N=B.query('Narcotics==1')
    N=N[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    A=B.query('Incident=="Auto Theft"')
    A=A[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    D=B.query('Discharge==1')
    D=D[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

    Br=B.query('Burglary==1')
    Br=Br[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()

#Create Frogtown GeoMap
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")

    for index, row in T.iterrows(): 
        popup_text = "Address: {}<br> total theft incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)

    for index, row in V.iterrows(): 
        popup_text = "Address: {}<br> total vandalism incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color="#FF0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    

    for index, row in N.iterrows(): 
        popup_text = "Address: {}<br> total narcotics incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Narcotics']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Narcotics'] + 3,
                            color="#654321",
                            popup=popup_text,
                            fill=True).add_to(FG_map)     

    for index, row in A.iterrows(): 
        popup_text = "Address: {}<br> total autotheft incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color='#007849',
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    for index, row in D.iterrows(): 
        popup_text = "Address: {}<br> total discharge incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    

    for index, row in Br.iterrows(): 
        popup_text = "Address: {}<br> total burglary incidents: {}"
        popup_text = popup_text.format(row["Block"],row['Count']) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count'] +3,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    return FG_map

def plot_Frogtown_year(Year=2018):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    B=B.query('Count>3')
    
    # for each row in the data, add a cicle marker
    for index, row in B.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    return FG_map


def plot_Frogtown_year_proactive(Year=2018):
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    B= fgc[(fgc['Year'] == Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    
    A= fgp[(fgp['Year'] == Year)]
    A= A.groupby(['Block','Latitude','Longitude']).size().reset_index()
    A.columns=['Block','Latitude','Longitude','Count'] 
    
    for index, row in B.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)

    for index, row in A.iterrows(): 
        popup_text = "Address: {}<br> total proactive calls: {}"
        popup_text = popup_text.format(row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
        
    return FG_map

def plot_Frogtown_long_crime(Incident='Discharge'):
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson','Year']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    B= fgc[(fgc['Incident'] == Incident)]
    B17=B.query('Year == 2018')
    B17=B17[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B18=B.query('Year == 2019')
    B18=B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B19=B.query('Year == 2020')
    B19=B19[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()

    for index, row in B17.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B18.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"], row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B19.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
    
    return FG_map

def plot_Frogtown_long_crime_todate(Incident='All',Day=Max):
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson','Year']

    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    B17=B.query('Year == 2018')
    B17=B17[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B18=B.query('Year == 2019')
    B18=B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B19=B.query('Year == 2020')
    B19=B19[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    print('This map displays {} incidents up to {}20XX'.format(Incident,Date))
    for index, row in B17.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B18.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"], row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B19.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
    
    return FG_map

#convert MOnth
def Convert_Month(num):
    Months= ['January','February','March','April','May','June','July','August','September','October','November','December']
    for i in range(12):
        if num==(i+1):
            Xi=Months[i]
    return Xi

#Community function
def commun(x): 
    if x in [67,68,87,88,89,90,91,92]:
        return 'Thomas-Frogtown'
    elif x in [5,6,7,8,25,26,27,28,45,46,47,48]:
        return 'Como'
    elif x in [107, 108, 109, 110,127,128,129,130]: 
        return 'Summit-University'
    elif x in [101,102,103,104,105,106,122,123,124,125,126]: 
        return 'Union Park'
    elif x in [63,64,65,66,83,84,85,86]: 
        return 'Midway' 
    elif x in [142,143,144,145,146,162,163,164,165,166]:
        return 'Macalester_Groveland'
    elif x in [182,183,184,185,186,202,203,204,205,206,223,224,225,242,243,244,245,246]:
        return 'Highland Park'
    elif x in [147,148,149,167,168]:
        return 'Summit Hill'
    elif x in [1,2,21,22,43,44,61,62,81,82]:
        return 'St. Anthony'
    elif x in [226,207,187,188,189,267,268,169,170,171,249,150,151,230]:
        return 'West 7th'
    elif x in [209,210,211,212,213,214,215,192,193,194,195,172,173,174,175]:
        return 'West Side'
    elif x in [111,112,131,132,133,152,153]:
        return 'Capital_River'
    elif x in [98,99,100,118,119,119,120,137,138,139,140,160,197,180,200,240,280]:
        return 'Battle_Creek'
    elif x in [76,95,96,97,115,116,117,138,114,136]:
        return 'Dayton Bluff' 
    elif x in [9,10,11,12,29,30,31,32,49,50,51,52,269,69,70,71,72]:
        return 'North End'
    elif x in [13,14,15,16,33,34,35,36,53,54,55,56,73,74,75,93,94]:
        return 'Payne-Phalen'
    elif x in [17,18,19,20,37,38,39,40,56,57,58,59,60,77,78,79,80]:
        return 'Greater East Side'
    else: 
        return 'NaN'

def table_toDate_Month_Crime(Incident='All',Day=Max):
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    B=B.query('Year >= 2018')
    Index= ['Year','Grid','Count','Month']
    C= B[Index].groupby(['Year','Grid','Month']).sum().reset_index()
    C['Month_Name']= C.Month.apply(Convert_Month) 
    C['Community']= C.Grid.apply(commun)
    print('This table maps {} incidents up to Day {}20XX'.format(Incident,Date))
    return pd.pivot_table(C, values='Count', index=['Community','Grid'], columns=['Month', 'Year'], fill_value=0)


import matplotlib.pyplot as plt
import seaborn as sns


def plot_toDate_Year_Crime(Incident='All',Day=Max):
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B=B.query('Year >= 2018')
    B= B[(B['DayYear'] <= Day)]
    Index= ['Year','Grid','Count']
    C= B[Index].groupby(['Year','Grid']).sum().reset_index()
    C['Community']= C.Grid.apply(commun) 
    print('This graph maps {} incidents up to {}20XX'.format(Incident,Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community','Grid'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= Incident + ' Yearly Total Incidents UptoDate: '+ str(Date)+'20XX')
    return plt.show()

# Firearm Plot
def plot_toDate_Year_Firearm(Day=Max):
    B= fgc_fire[(fgc_fire['DayYear'] <= Day)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B.query('Year>2017')
    Index= ['Year','Grid','Count']
    C= B[Index].groupby(['Year','Grid']).sum().reset_index()
    C['Community']= C.Grid.apply(commun) 
    print('This graph maps Firearm incidents up to {}20XX'.format(Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community','Grid'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= 'Firearm Yearly Total Incidents UptoDate: ' + str(Date)+'20XX')
    return plt.show()

#4
def plot_toDate_Year_Firearm(Day=Max):
    B= fgc_fire[(fgc_fire['DayYear'] <= Day)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B.query('Year>2017')
    Index= ['Year','Grid','Count']
    C= B[Index].groupby(['Year','Grid']).sum().reset_index()
    C['Community']= C.Grid.apply(commun) 
    print('This graph maps Firearm incidents up to {}20XX'.format(Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community','Grid'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= 'Firearm Yearly Total Incidents UptoDate: ' + str(Date)+'20XX')
    return plt.show()


def plot_Frogtown_year_Latenight(Year=2018):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']
    BM=B.query('LateNight ==0')
    BM=BM[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    BM=BM.query('Count>2')
    BL=B.query('LateNight ==1')
    BL=BL[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    BL=BL.query('Count>2')
    
    # for each row in the data, add a cicle marker
    for index, row in BM.iterrows(): 
        popup_text = "Year: {} Non-late<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)

    for index, row in BL.iterrows(): 
        popup_text = "Year: {} Late<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)        
    return FG_map


def plot_Frogtown_yearmonth(Year=2018,Month=1):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    B= B[(B['Month'] == Month)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    

    # for each row in the data, add a cicle marker
    for index, row in B.iterrows(): 
        Other= row['Count'] - row['Theft'] - row['Vandalism'] - row['Narcotics'] -row['Auto Theft'] - row['Burglary'] - row['Discharge']
        popup_text = "Year: {} Month: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Other: {}"
        popup_text = popup_text.format(str(Year), str(Month),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Narcotics'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], Other) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    return FG_map


def plot_Frogtown_yearhour(Year=2018,Hour=0):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] == Year)]
    B= B[(B['Hour'] == Hour)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    

    # for each row in the data, add a cicle marker
    for index, row in B.iterrows(): 
        Other= row['Count'] - row['Theft'] - row['Vandalism'] - row['Narcotics'] -row['Auto Theft'] - row['Burglary'] - row['Discharge']
        popup_text = "Year: {} Hour: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Other: {}"
        popup_text = popup_text.format(str(Year), str(Hour),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Narcotics'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], Other) 
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    return FG_map


def plot_Frogtown_long_crime_daytime_todate(Incident='All',Day=Max):
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson','Year']

    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    B= B.query('Hour >= 6 and Hour <20')
    B17=B.query('Year == 2018')
    B17=B17[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B18=B.query('Year == 2019')
    B18=B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B19=B.query('Year == 2020')
    B19=B19[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    print('This map displays {} incidents up to {}20XX from 7AM to 8PM'.format(Incident,Date))
    for index, row in B17.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B18.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"], row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B19.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
    
    return FG_map

#hotspot map

def plot_Frogtown_hot_spot(Year=2019):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    B= fgc[(fgc['Year'] >= Year)]
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']
    B=B[Index].groupby(['Block','Latitude','Longitude']).sum().reset_index()
    C=B.query('Count>9 and Count < 21')
    D=B.query('Count>20 and Count < 51')
    E=B.query('Count>50')
    
    # for each row in the data, add a cicle marker
    for index, row in C.iterrows(): 
        popup_text = "Year: 2019/20<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
 
    for index, row in D.iterrows(): 
        popup_text = "Year: 2019/20<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']/5,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    for index, row in E.iterrows(): 
        popup_text = "Year: 2019/20<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(str(Year),row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']/9,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)        

    return FG_map



#Saint Paul Data

#Socarata upload Method
from sodapy import Socrata

#New Upload Method Get Information from Socrata API
client = Socrata("information.stpaul.gov", None)
#Easier to bulk upload
results = client.get("gppb-g9cg", limit=1000000)
df = pd.DataFrame.from_records(results)

#rename columns [Note the order of Columns have changed]
cols= ['Block','CallDispCode','CallDisposition','Case','Code', 'Count','Date','Grid','Incident','IncType','Neighborhood','NNum','Time']
df.columns= cols
df = df.astype({"Case": int, "Code": int, "Grid":float, "NNum":int,"Count":int})

#Read Data
#df = pd.read_csv('Datasets/Crime_Incident_Report_-_Dataset.csv')
#cols= ['Case','Date','Time','Code','IncType','Incident','Grid','NNum','Neighborhood','Block','CallDispCode','CallDisposition', 'Count']
#df.columns= cols

#Add Time Variables
df= df[df.Case != 18254093] #messed up time variable
df['Date']= pd.to_datetime(df['Date'])
df['Year']= df['Date'].dt.year
df=df.query('Year > 2017')
df['DayYear'] = df['Date'].dt.dayofyear
df['Community']= df['Grid'].apply(commun)
df= df.query('Code not in [9954,9959] and Community !="NaN"')
df_fire=df[df['IncType'].str.contains("Firearm")]

def plot_toDate_Days_SPCrime(Incident='All',Day=1):
    if Incident=='All':
        B= df
    else: 
        B= df[(df['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    Bd= Max-Day
    B= B[(B['DayYear'] >= Bd)]
    B= B[(B['DayYear'] <= Max)]
    Index= ['Year','Community','Count']
    C= B[Index].groupby(['Year','Community']).sum().reset_index()
    print('This graph maps {} incidents of Saint Paul neighborhoods within {} days from date {}20XX'.format(Incident,Day,Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= Incident + ' Yearly UptoDate Total Incidents')
    return plt.show()


#Firearm

df_fire=df[df['IncType'].str.contains("Firearm")]
def plot_toDate_Year_SPFirearm(Day=Max):
    B= df_fire
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    Index= ['Year','Community','Count']
    C= B[Index].groupby(['Year','Community']).sum().reset_index()
    print('This graph maps Firearm incidents of Saint Paul neighborhoods up to {}20XX'.format(Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= 'Firearm Yearly UptoDate Total Incidents')
    return plt.show()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
tu= df.query('Grid in (64,65,66,67,84,85,86,87,104,105,106,107) and Year in (2020,2019)').sort_values(['Grid','Date'], ascending=False)
t1= tu.query('DayYear> 334 and Year ==2019')
t2= tu.query('Year ==2020')             
t3=pd.concat([t1,t2]).sort_values(['Grid','Date'], ascending=False)
t3
# Out:
#                             Block CallDispCode  CallDisposition      Case  \
# 33             44X LEXINGTON PA N            G  Gone on Arrival  20020537
# 694               101X CARROLL AV           RR   Report Written  20017446
# 802               97X IGLEHART AV            G  Gone on Arrival  20016928
# 1589             86X CENTRAL AV W           RR   Report Written  20013829
# 7952  1410      1 2019-12-10 08:00:00   65.0            Vandalism
# 8152   861      1 2019-12-08 19:00:00   65.0  Simple Asasult Dom.
# 9127   710      1 2019-12-01 23:34:00   65.0           Auto Theft
# 538   2619      1 2020-01-26 19:05:00   64.0            Discharge
# 1816   691      1 2020-01-19 10:30:00   64.0                Theft
# 2839   641      1 2020-01-11 23:00:00   64.0                Theft
# 4047   541      1 2020-01-04 06:16:00   64.0             Burglary
# 4651   710      1 2020-01-01 08:00:00   64.0           Auto Theft
# 5077   691      1 2019-12-29 07:38:00   64.0                Theft
# 5584   640      1 2019-12-26 09:29:41   64.0                Theft
# 6117   640      1 2019-12-22 10:50:31   64.0                Theft
# 6655  1835      1 2019-12-18 20:54:00   64.0            Narcotics
# 7125  1410      1 2019-12-15 23:55:00   64.0            Vandalism
# 7505   431      1 2019-12-13 10:30:00   64.0    Agg. Assault Dom.
# 8373   710      1 2019-12-06 20:00:00   64.0           Auto Theft
#
#                                                 IncType  \
# 33                                  Motor Vehicle Theft
# 694   Criminal Damage to Property (Misdemeanor, Unde...
# 802   Weapons, Discharging a Firearm in the City Limits
# 1589            Motor Vehicle Theft, All Other Vehicles
# 1843                                Motor Vehicle Theft
# 1965                           Theft, Except Auto Theft
# 2711              Motor Vehicle Theft, Trucks and Buses
# 2942                       Theft, From Auto, Under $500
# 3951  Weapons, Discharging a Firearm in the City Limits
# 3972                           Theft, Except Auto Theft
# 4237                                              Arson
# 4442            Motor Vehicle Theft, All Other Vehicles
# 4459  Weapons, Discharging a Firearm in the City Limits
# 4556                   Narcotics, Possession of Cocaine
# 4721                    Motor Vehicle Theft, Automobile
# 4879                    Motor Vehicle Theft, Automobile
# 5086                                          Narcotics
# 5413                    Motor Vehicle Theft, Automobile
# 6319  Criminal Damage to Property (Gross Mis., $250-...
# 7109  Burglary, Forced Entry, Night, Residence, Occu...
# 7116           Burglary, Forced Entry, Night, Residence
# 7217                       Theft, All Other, Under $500
# 7538                               Theft - Mail/Package
# 7908                           Theft, Except Auto Theft
# 8109                    Motor Vehicle Theft, Automobile
# 8254                                Motor Vehicle Theft
# 8381                    Assault, Domestic, Opposite Sex
# 8644                       Theft, All Other, Over $1000
# 8905                    Assault, Domestic, Opposite Sex
# 9044                    Motor Vehicle Theft, Automobile
# ...                                                 ...
# 593                  Narcotics, Possession of Marijuana
# 817   Weapons, Discharging a Firearm in the City Limits
# 1252                                   Theft, From Auto
# 1364                    Motor Vehicle Theft, Automobile
# 3081                    Motor Vehicle Theft, Automobile
# 3118                                   Theft, From Auto
# 3919              Burglary, Forced Entry, Night, Garage
# 5717                    Motor Vehicle Theft, Automobile
# 6334                   Narcotics, Possession of Cocaine
# 6891                        Criminal Damage to Property
# 6917                                   Theft, From Auto
# 6977                       Theft, All Other, Under $500
# 7325                       Theft, All Other, Under $500
# 7522                       Theft, All Other, Under $500
# 7681                    Motor Vehicle Theft, Automobile
# 7952  Criminal Damage to Property (Misdemeanor, Unde...
# 8152                    Assault, Domestic, Opposite Sex
# 4047             Midway
# 4651             Midway
# 5077             Midway
# 5584             Midway
# 6117             Midway
# 6655             Midway
# 7125             Midway
# 7505             Midway
# 8373             Midway
#
# [488 rows x 16 columns]

# %%
tu
# Out:
#                            Block CallDispCode  CallDisposition      Case  \
# 33            44X LEXINGTON PA N            G  Gone on Arrival  20020537
# 694              101X CARROLL AV           RR   Report Written  20017446
# 802              97X IGLEHART AV            G  Gone on Arrival  20016928
# 1589            86X CENTRAL AV W           RR   Report Written  20013829
# 1843            91X CENTRAL AV W            A          Advised  20012660
# 1965               90X AURORA AV            A          Advised  20012151
# 2711              97X CARROLL AV           RR   Report Written  20008583
# 2942          27X LEXINGTON PA N           RR   Report Written  20007514
# 3951         97X UNIVERSITY AV W            A          Advised  20002778
# 3972          44X LEXINGTON PA N            A          Advised  20002708
# 4237         96X UNIVERSITY AV W            R   Report Written  20001567
# 4442              99X CARROLL AV           RR   Report Written  20000847
# 4459               87X FULLER AV            A          Advised  20000767
# 4556    CONCORDIA AV  & VICTORIA           RR   Report Written  20000507
# 4721               86X AURORA AV           RR   Report Written  19288930
# 4879               90X FULLER AV           RR   Report Written  19287942
# 5086               98X FULLER AV            A          Advised  19287215
# 5413         94X UNIVERSITY AV W           RR   Report Written  19285986
# 6319             42X OXFORD ST N           RR   Report Written  19282233
# 7109               90X FULLER AV           RR   Report Written  19278328
# 7116            93X CONCORDIA AV           RR   Report Written  19279260
# 7217          37X LEXINGTON PA N           RR   Report Written  19277917
# 7538            93X CONCORDIA AV           RR   Report Written  19279282
# 7908         97X UNIVERSITY AV W            A          Advised  19274345
# 8109               95X AURORA AV           RR   Report Written  19273459
# 8254   LEXINGTON PA N & MARSHALL            A          Advised  19272403
# 8381             100X CARROLL AV           RR   Report Written  19271661
# 8644          37X LEXINGTON PA N           RR   Report Written  19270216
# 8905             101X CARROLL AV           RR   Report Written  19268967
# 9044               95X FULLER AV           RR   Report Written  19268246
# ...                          ...          ...              ...       ...
# 40759   ENGLEWOOD AV  & SNELLING           RR   Report Written  19801115
# 40798          181X ENGLEWOOD AV           RR   Report Written  19120694
# 41703          181X ENGLEWOOD AV            A          Advised  19116439
# 42048          181X ENGLEWOOD AV            A          Advised  19114925
# 42794             175X HEWITT AV            G  Gone on Arrival  19111457
# 44881   ENGLEWOOD AV  & FAIRVIEW           RR   Report Written  19101843
# 44911             165X TAYLOR AV            A          Advised  19101709
# 45939           FRY ST  & HEWITT            A          Advised  19096797
# 45973          75X SNELLING AV N            A          Advised  19096612
# 46586      WHEELER ST N & HEWITT            G  Gone on Arrival  19093856
# 46744      HEWITT AV  & SNELLING           RR   Report Written  19093039
# 46755          87X SNELLING AV N           RR   Report Written  19800844
# 49065          90X SNELLING AV N           RR   Report Written  19081875
# 49100        175X MINNEHAHA AV W            G  Gone on Arrival  19080937
# 49186          90X SNELLING AV N            A          Advised  19080339
# 50765                 91X FRY ST           RR   Report Written  19072161
# 50796           91X CHARLOTTE ST           RR   Report Written  19071984
# 52640             165X TAYLOR AV           RR   Report Written  19062750
# 44881  1410      1 2019-05-16 21:27:00   64.0            Vandalism
# 44911   600      1 2019-05-16 18:24:59   64.0                Theft
# 45939  1400      1 2019-05-10 15:14:49   64.0            Vandalism
# 45973   600      1 2019-05-10 10:30:50   64.0                Theft
# 46586  1800      1 2019-05-06 19:30:03   64.0            Narcotics
# 46744  2619      1 2019-05-05 21:20:00   64.0            Discharge
# 46755   661      1 2019-05-05 20:05:00   64.0                Theft
# 49065  1420      1 2019-04-21 01:00:00   64.0            Vandalism
# 49100  1800      1 2019-04-20 21:13:47   64.0            Narcotics
# 49186  1800      1 2019-04-20 01:45:19   64.0            Narcotics
# 50765   642      1 2019-04-08 22:00:00   64.0                Theft
# 50796   710      1 2019-04-08 19:00:00   64.0           Auto Theft
# 52640   541      1 2019-03-28 08:34:00   64.0             Burglary
# 52888   640      1 2019-03-26 06:38:49   64.0                Theft
# 54928  1835      1 2019-03-09 01:30:24   64.0            Narcotics
# 55006   614      1 2019-03-08 12:25:00   64.0                Theft
# 55931   861      1 2019-03-01 11:05:00   64.0  Simple Asasult Dom.
# 56173   640      1 2019-02-27 14:22:58   64.0                Theft
# 56739   641      1 2019-02-22 17:30:00   64.0                Theft
# 57653   861      1 2019-02-15 15:50:00   64.0  Simple Asasult Dom.
# 61113   691      1 2019-01-21 00:00:00   64.0                Theft
# 61590   711      1 2019-01-17 00:00:00   64.0           Auto Theft
# 62377   710      1 2019-01-12 00:00:00   64.0           Auto Theft
# 62378   710      1 2019-01-12 00:00:00   64.0           Auto Theft
# 63705   540      1 2019-01-03 00:00:00   64.0             Burglary
#
#                                                  IncType  \
# 33                                   Motor Vehicle Theft
# 694    Criminal Damage to Property (Misdemeanor, Unde...
# 802    Weapons, Discharging a Firearm in the City Limits
# 1589             Motor Vehicle Theft, All Other Vehicles
# 1843                                 Motor Vehicle Theft
# 1965                            Theft, Except Auto Theft
# 2711               Motor Vehicle Theft, Trucks and Buses
# 2942                        Theft, From Auto, Under $500
# 3951   Weapons, Discharging a Firearm in the City Limits
# 3972                            Theft, Except Auto Theft
# 4237                                               Arson
# 4442             Motor Vehicle Theft, All Other Vehicles
# 4459   Weapons, Discharging a Firearm in the City Limits
# 4556                    Narcotics, Possession of Cocaine
# 4721                     Motor Vehicle Theft, Automobile
# 4879                     Motor Vehicle Theft, Automobile
# 5086                                           Narcotics
# 5413                     Motor Vehicle Theft, Automobile
# 6319   Criminal Damage to Property (Gross Mis., $250-...
# 7109   Burglary, Forced Entry, Night, Residence, Occu...
# 7116            Burglary, Forced Entry, Night, Residence
# 7217                        Theft, All Other, Under $500
# 7538                                Theft - Mail/Package
# 7908                            Theft, Except Auto Theft
# 8109                     Motor Vehicle Theft, Automobile
# 8254                                 Motor Vehicle Theft
# 8381                     Assault, Domestic, Opposite Sex
# 8644                        Theft, All Other, Over $1000
# 8905                     Assault, Domestic, Opposite Sex
# 9044                     Motor Vehicle Theft, Automobile
# ...                                                  ...
# 40759  Criminal Damage to Property (Misdemeanor, Unde...
# 40798                 Narcotics, Possession of Marijuana
# 41703                                          Narcotics
# 42048                                          Narcotics
# 8381   Summit-University
# 8644   Summit-University
# 8905   Summit-University
# 9044   Summit-University
# ...                  ...
# 40759             Midway
# 40798             Midway
# 41703             Midway
# 42048             Midway
# 42794             Midway
# 44881             Midway
# 44911             Midway
# 45939             Midway
# 45973             Midway
# 46586             Midway
# 46744             Midway
# 46755             Midway
# 49065             Midway
# 49100             Midway
# 49186             Midway
# 50765             Midway
# 50796             Midway
# 52640             Midway
# 52888             Midway
# 54928             Midway
# 55006             Midway
# 55931             Midway
# 56173             Midway
# 56739             Midway
# 57653             Midway
# 61113             Midway
# 61590             Midway
# 62377             Midway
# 62378             Midway
# 63705             Midway
#
# [3813 rows x 16 columns]

# %%
#Saint Paul Data

#Socarata upload Method
from sodapy import Socrata

#New Upload Method Get Information from Socrata API
client = Socrata("information.stpaul.gov", None)
#Easier to bulk upload
results = client.get("gppb-g9cg", limit=1000000)
df = pd.DataFrame.from_records(results)

#rename columns [Note the order of Columns have changed]
cols= ['Block','CallDispCode','CallDisposition','Case','Code', 'Count','Date','Grid','Incident','IncType','Neighborhood','NNum','Time']
df.columns= cols
df = df.astype({"Case": int, "Code": int, "Grid":float, "NNum":int,"Count":int})

#Read Data
#df = pd.read_csv('Datasets/Crime_Incident_Report_-_Dataset.csv')
#ols= ['Case','Date','Time','Code','IncType','Incident','Grid','NNum','Neighborhood','Block','CallDispCode','CallDisposition', 'Count']
#df.columns= cols

#Add Time Variables
df= df[df.Case != 18254093] #messed up time variable
df['Date']= pd.to_datetime(df['Date'])
df['Year']= df['Date'].dt.year
df=df.query('Year > 2017')
df['DayYear'] = df['Date'].dt.dayofyear
df['Community']= df['Grid'].apply(commun)
df= df.query('Code not in [9954,9959] and Community !="NaN"')

def plot_toDate_Year_SPCrime(Incident='All',Day=Max):
    if Incident=='All':
        B= df
    else: 
        B= df[(df['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    Index= ['Year','Community','Count']
    C= B[Index].groupby(['Year','Community']).sum().reset_index()
    print('This graph maps {} incidents of Saint Paul neighborhoods up to {}20XX'.format(Incident,Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= Incident + ' Yearly UptoDate Total Incidents')
    return plt.show()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# ## [Link to runall](#content)

# %%
df.Year.value_counts()
df17=df.query('Year==2017')
df18=df.query('Year==2018')
df19=df.query('Year==2019')
#df.Year.value_counts()
df17R=df17.query('CallDispCode in ("RR","R","G","A")')

# %%
df19.query('Incident=="Discharge"').IncType.value_counts()
# Out:
# Weapons, Discharging a Firearm in the City Limits    614
# Name: IncType, dtype: int64

# %%
df.query('Year==2019')
# Out:
#                                 Block CallDispCode  CallDisposition      Case  \
# 0                    55X CENTRAL AV W            A          Advised  19205620
# 2          MCKNIGHT RD N & LARPENTEUR            A          Advised  19205615
# 7                 7 ST E & BIRMINGHAM           RR   Report Written  19205610
# 9                       73X THOMAS AV            G  Gone on Arrival  19205595
# 14                     163X MARION ST            A          Advised  19205578
# 17                 44X LAFAYETTE RD S            A          Advised  19205572
# 18               HOYT AV E & WINTHROP           RR   Report Written  19205573
# 20                ETNA ST  & MECHANIC           RR   Report Written  19205569
# 27            WABASHA ST N & EXCHANGE            G  Gone on Arrival  19205544
# 31                      19X EDMUND AV           RR   Report Written  19205533
# 38          CUMBERLAND ST  & MARYLAND           RR   Report Written  19205517
# 43                   3X FAIRVIEW AV S            A          Advised  19205524
# 55                26X UNIVERSITY AV E            A          Advised  19205471
# 56                       80X BERRY ST           RR   Report Written  19205434
# 57                      15X MOUNDS BD            A          Advised  19205461
# 63               146X UNIVERSITY AV W            R   Report Written  19205428
# 65               130X UNIVERSITY AV W            A          Advised  19205410
# 66                    115X CUSHING CR            R   Report Written  19205393
# 67                       24X GRAND AV           RR   Report Written  19205411
# 68                      67X EDMUND AV            A          Advised  19205401
# 69                146X MINNEHAHA AV E           RR   Report Written  19205383
# 76                   EARL ST  & BEECH            A          Advised  19205363
# 83                    115X CUSHING CR            R   Report Written  19205353
# 95                     48X PRIOR AV N            A          Advised  19205306
# 97                    115X CUSHING CR           RR   Report Written  19205387
# 103                  49X SHERBURNE AV            R   Report Written  19205298
# 107               ARCADE ST  & PHALEN           RR   Report Written  19205238
# 113              144X UNIVERSITY AV W            R   Report Written  19205202
# 114              130X UNIVERSITY AV W           RR   Report Written  19205204
# 116                      14X MARIA AV            A          Advised  19205271
# ...                               ...          ...              ...       ...
# 40879                      38X 7 ST E           RR   Report Written  19000086
# 40884                    109X BUSH AV           RR   Report Written  19000125
# 40886                    131X PARK ST            A          Advised  19000222
# 40887             128X MINNEHAHA AV E           RR   Report Written  19000231
# 40888               26X GERANIUM AV W            G  Gone on Arrival  19000247
# 40889                184X NEVADA AV E            A          Advised  19000148
# 40892                 82X ATLANTIC ST           RR   Report Written  19000252
# 40893              159X MARYLAND AV E            A          Advised  19000233
# 40894               123X ALBEMARLE ST            G  Gone on Arrival  19000347
# 40897               123X ALBEMARLE ST            A          Advised  19000374
# 40914                  96X FREMONT AV            A          Advised  19000440
# 40921                   29X RAVOUX ST           RR   Report Written  19000141
# 40923                    36X GROVE ST           RR   Report Written  19000183
# 40928               173X OLDHUDSON RD           RR   Report Written  19000325
# 40932              8X CESAR CHAVEZ ST           RR   Report Written  19000423
# 40935            144X UNIVERSITY AV W            A          Advised  19000495
# 40939               43X DOROTHYDAY PL            A          Advised  19000421
# 40943          STALBANS ST N & LAFOND            A          Advised  19000016
# 40944            137X UNIVERSITY AV W           RR   Report Written  19000444
# 40945               43X DOROTHYDAY PL            A          Advised  19000308
# 40949                  106X FULLER AV           RR   Report Written  19000256
# 40950  STCLAIR AV  & MISSISSIPPIRIVER            A          Advised  19000319
# 40952                  153X WILSON AV           RR   Report Written  19800004
# 40953            CARROLL AV  & MILTON            A          Advised  19000349
# 40955                   156X HAGUE AV           RR   Report Written  19000337
# 40958                208X HIGHWOOD AV           RR   Report Written  19000633
# 40959                 215X MAILAND RD            A          Advised  19000551
# 40960                     71X COMO AV           RR   Report Written  19000234
# 40962               219X OLDHUDSON RD           RR   Report Written  19000486
# 40963            145X UNIVERSITY AV W            A          Advised  19000322
#
#        Code  Count                Date   Grid             Incident  \
# 0      2619      1 2019-09-11 23:44:14  109.0            Discharge
# 2      2619      1 2019-09-11 23:34:50   20.0            Discharge
# 7       710      1 2019-09-11 23:11:00   77.0           Auto Theft
# 40950   640      1 2019-01-01 00:00:00  142.0                Theft
# 40952   642      1 2019-01-01 00:00:00  118.0                Theft
# 40953  1800      1 2019-01-01 00:00:00  107.0            Narcotics
# 40955   691      1 2019-01-01 00:00:00  125.0                Theft
# 40958   691      1 2019-01-01 00:00:00  240.0                Theft
# 40959  1400      1 2019-01-01 00:00:00  200.0            Vandalism
# 40960  1410      1 2019-01-01 00:00:00   48.0            Vandalism
# 40962   691      1 2019-01-01 00:00:00  120.0                Theft
# 40963   630      1 2019-01-01 00:00:00  105.0                Theft
#
#                                                  IncType  \
# 0      Weapons, Discharging a Firearm in the City Limits
# 2      Weapons, Discharging a Firearm in the City Limits
# 7                        Motor Vehicle Theft, Automobile
# 9                               Theft, Except Auto Theft
# 14                                             Narcotics
# 17                           Criminal Damage to Property
# 18                               Robbery, Misc., Firearm
# 20                       Motor Vehicle Theft, Automobile
# 27                                             Narcotics
# 31                      Narcotics, Possession of Cocaine
# 38     Narcotics, Possession With Intent to Sell Mari...
# 43                              Theft, Except Auto Theft
# 55                              Theft, Except Auto Theft
# 56                               Robbery, Misc., Firearm
# 57                                             Narcotics
# 63                              Theft, Except Auto Theft
# 65                              Theft, Except Auto Theft
# 66                                      Theft, From Auto
# 67     Criminal Damage to Property (Misdemeanor, Unde...
# 68                           Criminal Damage to Property
# 69                       Assault, Domestic, Opposite Sex
# 76                                   Motor Vehicle Theft
# 83                                      Theft, From Auto
# 95                              Theft, Except Auto Theft
# 97                Burglary, No Forced Entry, Day, Garage
# 103                             Theft, Except Auto Theft
# 107    Criminal Damage to Property (Misdemeanor, Unde...
# 113                             Theft, Except Auto Theft
# 114                       Theft, Shoplifting, Under $500
# 116                             Theft, Except Auto Theft
# ...                                                  ...
# 40879     Att. Burglary, Forced Entry, Night, Commercial
# 40884                       Aggravated Assault, Domestic
# 40886                           Theft, Except Auto Theft
# 40887                    Assault, Domestic, Family/Child
# 40888                                          Narcotics
# 40889                                Motor Vehicle Theft
# 40892  Weapons, Discharging a Firearm in the City Limits
# 40893                        Criminal Damage to Property
# 40894                                          Narcotics
# 40897                        Criminal Damage to Property
# 40914                           Theft, Except Auto Theft
# 40921    Criminal Damage to Property (Felony, Over $500)
# 40923    Aggravated Assault, Knife or Cutting Instrument
# 40928                    Assault, Domestic, Opposite Sex
# 40932                    Assault, Domestic, Opposite Sex
# 40935                                 Theft, Shoplifting
# 40939                           Theft, Except Auto Theft
# 40943  Weapons, Discharging a Firearm in the City Limits
# 40944                    Motor Vehicle Theft, Automobile
# 40945                                Motor Vehicle Theft
# 40949                    Motor Vehicle Theft, Automobile
# 40950                                   Theft, From Auto
# 40952                    Theft, From Auto, $501 to $1000
# 40953                                          Narcotics
# 40955                       Theft, All Other, Under $500
# 40958                       Theft, All Other, Under $500
# 40959                        Criminal Damage to Property
# 40960  Criminal Damage to Property (Misdemeanor, Unde...
# 40962                       Theft, All Other, Under $500
# 40963                                 Theft, Shoplifting
#
#                           Neighborhood  NNum                     Time  Year  \
# 0                                  NaN     8  2019-09-11T23:44:14.000  2019
# 40953            8 - Summit/University     8                 16:42:20  2019
# 40955                  13 - Union Park    13                 16:33:00  2019
# 40958  1 - Conway/Battlecreek/Highwood     1                 23:11:00  2019
# 40959  1 - Conway/Battlecreek/Highwood     1                 22:21:57  2019
# 40960                        10 - Como    10                 04:00:00  2019
# 40962  1 - Conway/Battlecreek/Highwood     1                 19:58:00  2019
# 40963                  13 - Union Park    13                 15:57:43  2019
#
#        DayYear             Community
# 0          254     Summit-University
# 2          254     Greater East Side
# 7          254     Greater East Side
# 9          254       Thomas-Frogtown
# 14         254             North End
# 17         254             West Side
# 18         254     Greater East Side
# 20         254     Greater East Side
# 27         254         Capital_River
# 31         254       Thomas-Frogtown
# 38         254             North End
# 43         254  Macalester_Groveland
# 55         254       Thomas-Frogtown
# 56         254           St. Anthony
# 57         254          Dayton Bluff
# 63         254            Union Park
# 65         254            Union Park
# 66         254                  Como
# 67         254              West 7th
# 68         254       Thomas-Frogtown
# 69         254     Greater East Side
# 76         254          Dayton Bluff
# 83         254                  Como
# 95         254            Union Park
# 97         254                  Como
# 103        254       Thomas-Frogtown
# 107        254          Payne-Phalen
# 113        254            Union Park
# 114        254            Union Park
# 116        254          Dayton Bluff
# ...        ...                   ...
# 40879        1         Capital_River
# 40884        1          Dayton Bluff
# 40886        1             North End
# 40887        1          Dayton Bluff
# 40888        1             North End
# 40889        1     Greater East Side
# 40892        1          Dayton Bluff
# 40893        1     Greater East Side
# 40894        1             North End
# 40897        1             North End
# 40914        1          Dayton Bluff
# 40921        1     Summit-University
# 40923        1         Capital_River
# 40928        1          Battle_Creek
# 40932        1             West Side
# 40935        1            Union Park
# 40939        1         Capital_River
# 40943        1       Thomas-Frogtown
# 40944        1            Union Park
# 40945        1         Capital_River
# 40949        1     Summit-University
# 40950        1  Macalester_Groveland
# 40952        1          Battle_Creek
# 40953        1     Summit-University
# 40955        1            Union Park
# 40958        1          Battle_Creek
# 40959        1          Battle_Creek
# 40960        1                  Como
# 40962        1          Battle_Creek
# 40963        1            Union Park
#
# [16226 rows x 16 columns]

# %%
df17.Incident.value_counts()
# Out:
# Theft                  8796
# Vandalism              2596
# Narcotics              2149
# Auto Theft             2137
# Burglary               2044
# Discharge              1181
# Simple Asasult Dom.     961
# Robbery                 654
# Agg. Assault            393
# Agg. Assault Dom.       371
# Graffiti                151
# Rape                    141
# Arson                   103
# Simple Assault Dom.      16
# Homicide                  6
# Name: Incident, dtype: int64

# %%
#df17A=df17.query('Incident=="Arson"')
df17.Incident.value_counts()
# Out:
# Theft                  8796
# Vandalism              2596
# Narcotics              2149
# Auto Theft             2137
# Burglary               2044
# Discharge              1181
# Simple Asasult Dom.     961
# Robbery                 654
# Agg. Assault            393
# Agg. Assault Dom.       371
# Graffiti                151
# Rape                    141
# Arson                   103
# Simple Assault Dom.      16
# Homicide                  6
# Name: Incident, dtype: int64

# %%
df.Year.value_counts()
df.query("Year==2020")
# Out:
#                              Block CallDispCode  CallDisposition      Case  \
# 1                   23X CHARLES AV            A          Advised  20005617
# 8              116X MINNEHAHA AV W           RR   Report Written  20005605
# 21                  47X JACKSON ST            A          Advised  20005553
# 22                   51X SIBLEY ST           RR   Report Written  20005579
# 26              8X CESAR CHAVEZ ST           RR   Report Written  20005548
# 27            130X UNIVERSITY AV W           RR   Report Written  20005558
# 37                  18X WAYZATA ST            A          Advised  20005500
# 41                  127X WILSON AV           RR   Report Written  20005495
# 44                 45X ROBERT ST S           RR   Report Written  20005489
# 47              188X MARYLAND AV E           RR   Report Written  20005503
# 58                  69X BRADLEY ST            A          Advised  20005443
# 60                     37X SIMS AV           RR   Report Written  20005427
# 64                  28X SMITH AV N            R   Report Written  20005414
# 65                   67X DAYTON AV            A          Advised  20005387
# 72            130X UNIVERSITY AV W           RR   Report Written  20005364
# 74                 11X ISABEL ST W           RR   Report Written  20005378
# 83                    165X CASE AV            R   Report Written  20005309
# 84                 130X OSCEOLA AV            R   Report Written  20005356
# 85                  150X DALE ST N            R   Report Written  20005326
# 86                90X SHERBURNE AV            A          Advised  20005310
# 87                    149X RICE ST            A          Advised  20005271
# 88                 85X DELAWARE AV            A          Advised  20005279
# 89                    42X ROY ST N           RR   Report Written  20005270
# 90            144X UNIVERSITY AV W           RR   Report Written  20005267
# 91                      82X 5 ST E            R   Report Written  20005293
# 92                     95X RICE ST            R   Report Written  20005281
# 93                    85X BLAIR AV            A          Advised  20005277
# 98                    35X LARCH ST            R   Report Written  20005237
# 100               106X GOODRICH AV            A          Advised  20005257
# 101                  3X BAKER ST E            A          Advised  20005216
# ...                            ...          ...              ...       ...
# 1309               EARL ST  & YORK            G  Gone on Arrival  20000157
# 1310              104X MARGARET ST           RR   Report Written  20000160
# 1311                7X LAWSON AV W           RR   Report Written  20000373
# 1312                 191X BURNS AV           RR   Report Written  20000134
# 1313            COMO AV  & WESTERN           RR   Report Written  20000115
# 1314        DUNLAP ST S & GOODRICH           RR   Report Written  20800011
# 1315                157X EDMUND AV           RR   Report Written  20000252
# 1316           61X CALIFORNIA AV E           RR   Report Written  20000099
# 1317         141X HUNTINGVALLEY RD           RR   Report Written  20800024
# 1318                163X MARION ST            R   Report Written  20000087
# 1320             136X WESTERN AV N            G  Gone on Arrival  20000067
# 1321          BAKER ST W & BIDWELL            A          Advised  20000080
# 1322                 101X FRONT AV           RR   Report Written  20800010
# 1323          196X UNIVERSITY AV W           RR   Report Written  20000336
# 1324                   96X EARL ST           RR   Report Written  20000193
# 1325               EARL ST  & YORK            A          Advised  20000056
# 1326           119X HAWTHORNE AV E            A          Advised  20000053
# 1327                110X DULUTH ST            A          Advised  20000050
# 1328                   188X 7 ST E            A          Advised  20000040
# 1329  UNIVERSITY AV W & CHATSWORTH            A          Advised  20000054
# 1330             126X SHERBURNE AV           RR   Report Written  20000024
# 1331                64X JACKSON ST           RR   Report Written  20000009
# 1332                 58X GORMAN AV           RR   Report Written  20000014
# 1333             FOREST ST  & ROSE            A          Advised  20000011
# 1334           MANITOBA AV  & RICE            G  Gone on Arrival  20000005
# 1335          MENDOTA ST  & CONWAY            A          Advised  20000025
# 1336             98X STALBANS ST N            A          Advised  20000004

# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bfc16c5a2564> in <module>
# ----> 1 df17.query('Case==17266087')
#
# NameError: name 'df17' is not defined

# %%
df.to_csv('Datasets/SaintPaul_All_Pre.csv', encoding='utf-8', index=False)

# %%
def plot_toDate_Year_SPCityCrime(Incident='All',Day=Max):
    if Incident=='All':
        B= df
    else: 
        B= df[(df['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    Index= ['Year','Count']
    C= B[Index].groupby(['Year']).sum().reset_index()
    print('This graph maps {} annual incidents incidents of Saint Paul  up to {}20XX'.format(Incident,Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(6,4),title= Incident + ' Annual Total Incidents')
    return plt.show()

# %%
plot_toDate_Year_SPCityCrime()
# Out:
# This graph maps All annual incidents incidents of Saint Paul  up to 1/29/20XX

# %%
def plot_toDate_Year_Crime(Incident='All',Day=Max):
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B=B.query('Year >= 2017')
    B= B[(B['DayYear'] <= Day)]
    Index= ['Year','Grid','Count']
    C= B[Index].groupby(['Year','Grid']).sum().reset_index()
    C['Community']= C.Grid.apply(commun) 
    print('This graph maps {} incidents up to {}20XX'.format(Incident,Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community','Grid'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= Incident + ' Yearly Total Incidents UptoDate: '+ str(Date)+'20XX')
    return plt.show()

# %%
fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-41e347bdcd0d> in <module>
# ----> 1 fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
#
# NameError: name 'Day' is not defined

# %%
#fgc['DayYear'] == Max
fgc['DayYear'] ==247
#fgc
fgc.query('DayYear==247')
# Out:
#                       Block CallDispCode  CallDisposition      Case  Code  \
# 1943        dale_university            G  Gone on Arrival  18202313   600
# 1944           carroll_avon           RR   Report Written  18201924  2619
# 3368         western_edmund            G  Gone on Arrival  17209056   300
# 3369        dale_university           RR   Report Written  17209681   314
# 4709      chatsworth_fuller           RR   Report Written  16178764   311
# 4710      chatsworth_fuller           RR   Report Written  16178764   311
# 5689      chatsworth_aurora           RR   Report Written  14190424  1815
# 5690      chatsworth_fuller           RR   Report Written  14189731  1835
# 5691      grotto_university           RR   Report Written  14190428  2619
# 5726    64x chatsworth st n            R   Report Written  19199861  2619
# 5728     93x minnehaha av w            G  Gone on Arrival  19199818   600
# 5729     39x lexington pa n            G  Gone on Arrival  19199784  1800
# 5730   130x university av w           RR   Report Written  19199763   631
# 5731   130x university av w            A          Advised  19199762   630
# 5733    88x university av w           RR   Report Written  19199129   711
# 10719        105x edmund av           RR   Report Written  18202454   861
# 10722      44x sherburne av            R   Report Written  18202636   600
# 10728         46x dale st n           RR   Report Written  18202643  1835
# 10730  130x university av w           RR   Report Written  18202697   633
# 10731         73x edmund av            A          Advised  18202704  2619
# 10732        108x thomas av           RR   Report Written  18202141   710
# 10735    3xx lexington pa n           RR   Report Written  18202211   220
# 15752   92x university av w            A          Advised  17209000   600
# 15753       52x vanburen av           RR   Report Written  17209057   862
# 15754           42x rice st           RR   Report Written  17209083   633
# 15755      43x sherburne av           RR   Report Written  17801675   691
# 15756        97x charles av           RR   Report Written  17210136   530
# 15757         28x dale st n           RR   Report Written  17209029  1410
# 20141           53x kent st            A          Advised  16179075   600
# 20142           53x kent st            A          Advised  16179075   600
# 20143         79x lafond av           RR   Report Written  16178914  1410
# 20144         79x lafond av           RR   Report Written  16178914  1410
# 20145         39x edmund av           RR   Report Written  16179259  1410
# 20146         39x edmund av           RR   Report Written  16179259  1410
# 20147           42x rice st           RR   Report Written  16179260   631
# 20148           42x rice st           RR   Report Written  16179260   631
# 20149   95x university av w            R   Report Written  16178849   900
# 20150   95x university av w            R   Report Written  16178849   900
# 20151           42x rice st           RR   Report Written  16179020   633
# 20152           42x rice st           RR   Report Written  16179020   633
# 22934  130x university av w            A          Advised  15192083   600
# 22935  130x university av w           RR   Report Written  15191639   631
# 22936  130x university av w           RR   Report Written  15191722   631
# 22937         33x fuller av            G  Gone on Arrival  15192187  1800
# 22938           42x rice st           RR   Report Written  15192022   632
# 22939   59x university av w           RR   Report Written  15191912   631
# 25656        17x charles av           RR   Report Written  14190045   312
# 25657       126x charles av            G  Gone on Arrival  14190557   700
# 25658      68x stanthony av            G  Gone on Arrival  14190383  1800
# 25659   31x university av w            G  Gone on Arrival  14190299   600
# 25660      128x vanburen av            A          Advised  14189817   500
# 25661       26x oxford st n           RR   Report Written  14190004   691
# 25662        102x lafond av           RR   Report Written  14190155   651
# 25663           42x rice st           RR   Report Written  14190043   631
# 25664      50x sherburne av           RR   Report Written  14189685   861
# 25665         82x lafond av            A          Advised  14190123   600
#
#                  Coordinates  Count                     Date  \
# 1943   44.955828, -93.126376      1  2018-09-04T00:00:00.000
# 1944   44.950346, -93.133213      1  2018-09-04T00:00:00.000
# 3368   44.958481, -93.116175      1  2017-09-04T00:00:00.000
# 3369   44.955828, -93.126376      1  2017-09-04T00:00:00.000
# 4709   44.953945, -93.141544      1  2016-09-03T00:00:00.000
# 4710   44.953945, -93.141544      1  2016-09-03T00:00:00.000
# 5689   44.954835, -93.141553      1  2014-09-04T00:00:00.000
# 5690   44.953945, -93.141544      1  2014-09-04T00:00:00.000
# 5691   44.955823, -93.131420      1  2014-09-04T00:00:00.000
# 5726                     NaN      1  2019-09-04T23:46:38.000
# 5728                     NaN      1  2019-09-04T21:37:44.000
# 5729                     NaN      1  2019-09-04T21:35:35.000
# 5730                     NaN      1  2019-09-04T21:07:00.000
# 5731                     NaN      1  2019-09-04T21:05:11.000
# 5733                     NaN      1  2019-09-04T08:19:00.000
# 10719                    NaN      1  2018-09-04T00:00:00.000
# 10722                    NaN      1  2018-09-04T00:00:00.000
# 10728                    NaN      1  2018-09-04T00:00:00.000
# 10730                    NaN      1  2018-09-04T00:00:00.000
# 10731                    NaN      1  2018-09-04T00:00:00.000
# 10732                    NaN      1  2018-09-04T00:00:00.000
# 10735                    NaN      1  2018-09-04T00:00:00.000
# 15752                    NaN      1  2017-09-04T00:00:00.000
# 15753                    NaN      1  2017-09-04T00:00:00.000
# 15754                    NaN      1  2017-09-04T00:00:00.000
# 15755                    NaN      1  2017-09-04T00:00:00.000
# 15756                    NaN      1  2017-09-04T00:00:00.000
# 22934        0      1          0       0       1               0
# 22935        0      1          0       0       0               0
# 22936        0      1          0       0       0               0
# 22937        0      0          0       0       0               1
# 22938        0      1          0       0       0               0
# 22939        0      1          0       0       0               0
# 25656        1      0          0       0       0               0
# 25657        0      0          0       0       0               1
# 25658        0      0          0       0       0               1
# 25659        0      1          0       0       0               1
# 25660        0      0          0       0       1               0
# 25661        0      1          0       0       0               0
# 25662        0      1          0       0       0               0
# 25663        0      1          0       0       0               0
# 25664        0      0          0       0       0               0
# 25665        0      1          0       0       1               0
#
#       Report Written FDate
# 1943               0  9/4/
# 1944               1  9/4/
# 3368               0  9/4/
# 3369               1  9/4/
# 4709               1  9/3/
# 4710               1  9/3/
# 5689               1  9/4/
# 5690               1  9/4/
# 5691               1  9/4/
# 5726               1  9/4/
# 5728               0  9/4/
# 5729               0  9/4/
# 5730               1  9/4/
# 5731               0  9/4/
# 5733               1  9/4/
# 10719              1  9/4/
# 10722              1  9/4/
# 10728              1  9/4/
# 10730              1  9/4/
# 10731              0  9/4/
# 10732              1  9/4/
# 10735              1  9/4/
# 15752              0  9/4/
# 15753              1  9/4/
# 15754              1  9/4/
# 15755              1  9/4/
# 15756              1  9/4/
# 15757              1  9/4/
# 20141              0  9/3/
# 20142              0  9/3/
# 20143              1  9/3/
# 20144              1  9/3/
# 20145              1  9/3/
# 20146              1  9/3/
# 20147              1  9/3/
# 20148              1  9/3/
# 20149              1  9/3/
# 20150              1  9/3/
# 20151              1  9/3/
# 20152              1  9/3/
# 22934              0  9/4/
# 22935              1  9/4/
# 22936              1  9/4/
# 22937              0  9/4/
# 22938              1  9/4/
# 22939              1  9/4/
# 25656              1  9/4/
# 25657              0  9/4/
# 25658              0  9/4/
# 25659              0  9/4/
# 25660              0  9/4/
# 25661              1  9/4/
# 25662              1  9/4/
# 25663              1  9/4/
# 25664              1  9/4/
# 25665              0  9/4/
#
# [56 rows x 48 columns]

# %%
def plot_toDate_Days_SPCrime(Incident='All',Day=1):
    if Incident=='All':
        B= df
    else: 
        B= df[(df['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Max)]['FDate'][0:1].iloc[0,]
    Bd= Max-Day
    B= B[(B['DayYear'] >= Bd)]
    B= B[(B['DayYear'] <= Max)]
    Index= ['Year','Community','Count']
    C= B[Index].groupby(['Year','Community']).sum().reset_index()
    print('This graph displays total {} incidents of Saint Paul neighborhoods within {} days from date {}20XX'.format(Incident,Day,Date))
    sns.set()
    pd.pivot_table(C, values='Count', index=['Community'], columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(12,10),title= Incident + ' Yearly UptoDate Total Incidents')
    return plt.show()

# %%
plot_toDate_Days_SPCrime(Incident='Discharge',Day=29)
# Out:
# This graph displays total Discharge incidents of Saint Paul neighborhoods within 29 days from date 1/29/20XX

# %%
def plot_Frogtown_recent_crime_todate(Incident='All',Day=Max):
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson','Year']

    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Max)]['FDate'][0:1].iloc[0,]
    Bd= Max-Day
    B= B[(B['DayYear'] >= Bd)]
    B= B[(B['DayYear'] <= Max)]    
    B19=B.query('Year == 2019')
    B19=B19[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    print('This map displays {} incidents within {} days from {}2019'.format(Incident,Day,Date))
    for index, row in B19.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+6,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
    
    return FG_map

# %%
plot_Frogtown_recent_crime_todate(Incident='Discharge',Day=16)
# Out:
# This map displays Discharge incidents within 16 days from 10/16/2019
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def plot_toDate_Days_SPCrimeAll(Incident='All',Day=1):
    if Incident=='All':
        B= df
    else: 
        B= df[(df['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Max)]['FDate'][0:1].iloc[0,]
    Bd= Max-Day
    B= B[(B['DayYear'] >= Bd)]
    B= B[(B['DayYear'] <= Max)]
    Index= ['Year','Count']
    C= B[Index].groupby(['Year']).sum().reset_index()
    print('This graph maps {} incidents of Saint Paul neighborhoods within {} days from date {}20XX'.format(Incident,Day,Date))
    sns.set()
    pd.pivot_table(C, values='Count', columns=['Year'], 
                          fill_value=0).plot(kind= 'barh', 
                                             figsize=(6,4),title= Incident + ' Yearly UptoDate Total Incidents')
    return plt.show()

# %%
plot_toDate_Days_SPCrimeAll(Incident='Discharge',Day=43)
# Out:
# This graph maps Discharge incidents of Saint Paul neighborhoods within 43 days from date 11/13/20XX

# %%
df.query('Incident=="Discharge" and Year==2019')
# Out:
#                           Block CallDispCode                  CallDisposition  \
# 1            CASE AV  & JACKSON            G                    6 - North End
# 26                91X EUCLID ST           RR               4 - Dayton's Bluff
# 147               99X OMABAN ST            A            2 - Greater East Side
# 149               99X OMABAN ST            A            2 - Greater East Side
# 441               95X JESSIE ST           RR                 5 - Payne/Phalen
# 518                51X BLAIR AV           RR        7 - Thomas/Dale(Frogtown)
# 541            43X SHERBURNE AV            A        7 - Thomas/Dale(Frogtown)
# 602     CLARENCE ST  & MARYLAND           RR            2 - Greater East Side
# 634             BUSH AV  & RUTH            A            2 - Greater East Side
# 652            77X STANTHONY AV           RR            8 - Summit/University
# 658               34X FULLER AV           RR            8 - Summit/University
# 669                70X HAGUE AV           RR            8 - Summit/University
# 692                 117X 7 ST E           RR               4 - Dayton's Bluff
# 858               73X CONWAY ST           RR               4 - Dayton's Bluff
# 1006              12X BIGLOW LA            A                    6 - North End
# 1021           47X SHERBURNE AV           RR        7 - Thomas/Dale(Frogtown)
# 1027             41X VANDYKE ST           RR  1 - Conway/Battlecreek/Highwood
# 1030       MARION ST  & CHARLES            R        7 - Thomas/Dale(Frogtown)
# 1137           206X SHERWOOD AV           RR            2 - Greater East Side
# 1155         73X JESSAMINE AV E            A                 5 - Payne/Phalen
# 1165       ALBERT ST S & SUMMIT           RR        14 - Macalester-Groveland
# 1203       CARROLL AV  & MILTON           RR            8 - Summit/University
# 1308         219X LOWERAFTON RD            A  1 - Conway/Battlecreek/Highwood
# 1316     KING ST E & LIVINGSTON           RR                    3 - West Side
# 1335        OTTO AV  & VICTORIA           RR                 9 - West Seventh
# 1349         111X FARRINGTON ST            A                    6 - North End
# 1473           156X WHEELOCK LA           RR                    6 - North End
# 1503          CASE AV  & JESSIE           RR                 5 - Payne/Phalen
# 1539            13X WINNIPEG AV            A                    6 - North End
# 1582     MARGARET ST  & CYPRESS            A               4 - Dayton's Bluff
# ...                         ...          ...                              ...
# 50172         98X GERANIUM AV E            A                          Advised
# 50174              98X IVY AV E            A                          Advised
# 50179    BARCLAY ST  & MAGNOLIA           RR                   Report Written
# 50183              150X ETNA ST           RR                   Report Written
# 50184          216X NORTONIA AV            A                          Advised
#
#        DayYear             Community
# 1          317             North End
# 26         317          Dayton Bluff
# 147        317     Greater East Side
# 149        317     Greater East Side
# 441        315          Payne-Phalen
# 518        314       Thomas-Frogtown
# 541        314       Thomas-Frogtown
# 602        313     Greater East Side
# 634        313     Greater East Side
# 652        312     Summit-University
# 658        312     Summit-University
# 669        312     Summit-University
# 692        312          Dayton Bluff
# 858        311          Dayton Bluff
# 1006       310             North End
# 1021       310       Thomas-Frogtown
# 1027       310          Battle_Creek
# 1030       310       Thomas-Frogtown
# 1137       309     Greater East Side
# 1155       309          Payne-Phalen
# 1165       309  Macalester_Groveland
# 1203       309     Summit-University
# 1308       308          Battle_Creek
# 1316       308             West Side
# 1335       308              West 7th
# 1349       308             North End
# 1473       307             North End
# 1503       307          Payne-Phalen
# 1539       307             North End
# 1582       306          Dayton Bluff
# ...        ...                   ...
# 50172       13          Payne-Phalen
# 50174       13          Payne-Phalen
# 50179       13     Greater East Side
# 50183       13     Greater East Side
# 50184       13     Greater East Side
# 50219       13             North End
# 50245       13          Payne-Phalen
# 50266       13     Summit-University
# 50272       13                  Como
# 50300       12     Summit-University
# 50471       11          Payne-Phalen
# 50472       11          Payne-Phalen
# 50708       10          Dayton Bluff
# 50819        9     Greater East Side
# 50836        9          Payne-Phalen
# 50882        9       Thomas-Frogtown
# 51291        5     Greater East Side
# 51297        5     Greater East Side
# 51298        5          Battle_Creek
# 51304        5          Payne-Phalen
# 51316        5          Payne-Phalen
# 51334        5             North End
# 51344        5             North End
# 51345        5             North End
# 51580        4              West 7th
# 51697        3             North End
# 51721        3     Greater East Side
# 51817        2              West 7th
# 51939        1       Thomas-Frogtown
# 51975        1          Dayton Bluff
#
# [885 rows x 16 columns]

# %%
tu= df.query('Grid in (64,65,66,67,84,85,86,87,104,105,106,107) and Year in (2020,2019)').sort_values(['Grid','Date'], ascending=False)
t1= tu.query('DayYear> 334 and Year ==2019')
t2= tu.query('Year ==2020')             
t3=pd.concat([t1,t2]).sort_values(['Grid','Date'], ascending=False)

t3.columns
Features= ['Grid','Date','Block','CallDisposition','Incident','IncType','Neighborhood']#,'Longitude', 'Latitude']
t4=t3[Features]

#Features= ['Block','Longitude', 'Latitude']
#fg1= fg[Features]
t4.Block = t4.Block.astype(str) #first change the type to string
t4['Block']= t4['Block'].str.lower() #lowercase string to create uniformity

#t5=pd.merge(t4, fg1, on='Block', how='left')
#t5

#fg1

#Features= ['Grid','DateTime','Block','CallDisposition','Incident','IncType','Neighborhood']#,'Longitude', 'Latitude']

t4.to_csv('Datasets/SaintPaul_Request1.csv', encoding='utf-8', index=False)

#t4[t4['IncType'].str.contains("Firearm")] #specifies all firearm

#t4.Grid.value_counts()


#t4.to_csv('Datasets/SaintPaul_Request.csv', encoding='utf-8', index=False)

# %%
def plot_Frogtown2_year(Incident='All'):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")

    
    #setup
    if Incident=='All':
        B= fg
    else: 
        B= fg[(fg['Incident'] == Incident)]
    Index =['Block', 'Year','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']        
    B17=B.query('DayYear > 334 and Year == 2019')
    B17=B17[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B18=B.query('DayYear <35 and Year ==2020')
    B18=B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    print('This map displays {} incidents for December/January'.format(Incident))    

    
    # for each row in the data, add a cicle marker
    for index, row in B17.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(row['Year'],row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)

    # for each row in the data, add a cicle marker
    for index, row in B18.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(row['Year'],row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    return FG_map

plot_Frogtown2_year()
# Out:
# This map displays All incidents for December/January
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def plot_Frogtown2_year(Incident='All'):
    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")

    
    #setup
    if Incident=='All':
        B= fg
    else: 
        B= fg[(fg['Incident'] == Incident)]
    Index =['Block', 'Year','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson']        
    B18=B.query('DayYear <35 and Year ==2020')
    B18=B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    print('This map displays {} incidents for December/January'.format(Incident))    


    # for each row in the data, add a cicle marker
    for index, row in B18.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}<br> Theft: {}<br> Vandalism: {}\
                            <br> Narcotics: {}<br> Auto Theft: {}<br> Burglary: {}<br> Discharge: {}<br> Robbery: {}\
                            <br> Domestic Assault: {}<br> Violent: {}<br> Arson: {}"
        popup_text = popup_text.format(row['Year'],row["Block"], row['Count'], row['Theft'], row['Vandalism'], row['Robbery'],\
                            row['Auto Theft'], row['Burglary'], row['Discharge'], row['Domestic Assault'],\
                                  row['Domestic Assault'],row['Violent'],row['Arson'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
        
    return FG_map

]
# Out:
# This map displays All incidents for December/January
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def plot_Frogtown_long_crime_todate(Incident='All',Day=Max):
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson','Year']

    # generate a new map
    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=14,tiles="OpenStreetMap")
    
    #setup
    if Incident=='All':
        B= fgc
    else: 
        B= fgc[(fgc['Incident'] == Incident)]
    Date= fgc[(fgc['DayYear'] == Day)]['FDate'][0:1].iloc[0,]
    B= B[(B['DayYear'] <= Day)]
    B17=B.query('Year == 2018')
    B17=B17[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B18=B.query('Year == 2019')
    B18=B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    B19=B.query('Year == 2020')
    B19=B19[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
    print('This map displays {} incidents up to {}20XX'.format(Incident,Date))
    for index, row in B17.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B18.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"], row["Longitude"]),
                            radius=row['Count']+3,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B19.iterrows(): 
        popup_text = "Year: {}<br> Address: {}<br> total incidents: {}"
        popup_text = popup_text.format(row["Year"],row["Block"], row['Count'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Count']+3,
                            color="#800080",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
    
    return FG_map

# %%
    Index =['Block','Latitude','Longitude', 'Count','Theft','Vandalism','Narcotics','Auto Theft','Burglary','Discharge'\
            ,'Robbery','Domestic Assault','Violent','Arson','Year']
B18=fg.query('DayYear <35 and Year ==2020')
B18[Index].groupby(['Year','Block','Latitude','Longitude']).sum().reset_index()
# Out:
#      Year                 Block   Latitude  Longitude  Count  Theft  \
# 0    2020       101x carroll av  44.950058 -93.142896      1      0
# 1    2020       103x charles av  44.957331 -93.143594      1      0
# 2    2020        103x lafond av  44.960051 -93.143589      1      1
# 3    2020        103x thomas av  44.959158 -93.143601      1      0
# 4    2020       104x charles av  44.957554 -93.144085      2      0
# 5    2020        104x lafond av  44.960277 -93.144123      1      0
# 6    2020       106x charles av  44.957337 -93.144978      1      0
# 7    2020        106x edmund av  44.958264 -93.145052      1      0
# 8    2020  107x piercebutler rd  44.966474 -93.145402      1      1
# 9    2020  107x university av w  44.955626 -93.145205      1      0
# 10   2020        108x thomas av  44.959187 -93.145702      1      0
# 11   2020     109x stanthony av  44.952175 -93.146800      1      0
# 12   2020         10x empire dr  44.961717 -93.105415      1      0
# 13   2020  110x university av w  44.955627 -93.146414      1      1
