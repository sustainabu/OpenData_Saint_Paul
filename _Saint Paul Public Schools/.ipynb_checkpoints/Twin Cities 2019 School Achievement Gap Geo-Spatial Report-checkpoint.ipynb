# %% [markdown]
# <p><img style="padding: 0 15px; float: left;" src="Graphs/FTLogo300.jpg" alt="FT Crusader Logo" Width='140' Height= '250'/></p>
# <p> <h2> Twin Cities 2019 School Achievement Gap Geo-Spatial Report; 12/19/19</h2> <a name="tc"></a>
# <p> <h3> By Abu Nayeem (Frogtown Crusader)</h3>

# %% [markdown]
# ## Purpose
#
# The goal of this data report is to provide insight on the student achievement gap within the Twin Cities, and, the respective audience, i..e educators, teachers, and citizens to take action. This report will be using interactive maps to view academic disparities in a geo-spatial dimension. You can click on the icons to view the name of the school, and the disparity gap. In addition, we can compare the representation of the School Board vote election to see if it follows to proficiency.

# %% [markdown]
# # Table of contents <a name="content"></a>
#
# **Note**: The schools L'Etoile Du Nord French Immersion U and  Mississippi Creative Arts Elementary are excluded from the interactive map due to some unknown programming error (i.e. caused the program to crash). With given time-constraints it was best to exclude.
#
# * [Brief Introduction](#intro)
# * [About Saint Paul Open Data Initiative](#opendata)
# * [About the Data](#data)
#     * [Math](#math)
#     * [Reading](#reading)
#     * [Science](#science)
# * [SPPS Interactive Proficiency Maps by Demographics (Legend)](#map)
#     * [Math](#mathmap)
#     * [Reading](#readingmap)
#     * [Science](#sciencemap)
# * In Depth Demographic Analysis
#     * [Interactive Map: Twin Cities Homeless Students Breakdown](#homeless)
#     * [Race by Poverty Achievement Gap Analysis](#depth)
# * Tables: District & Individual School Proficiency/Enrollment by Grade
#     * [Elementary School](#elem)
#     * [Middle School](#int)
#     * [High School](#high)
# * [Concluding Thoughts](#conclusion)
# * [Run Code](#code)

# %% [markdown]
# # Saint Paul Open Data Initiative <a name="opendata"></a>
#
# This initiative focuses on taking public information/data from municipalities and organizations to create interactive reports and analysis to better inform and assist community members to take action. This is an open-source project, meaning that all coding is accessible to everyone, and thus there is transparency on the results. It is currently all python-based. As always, I encourage other programmers and developers to participate in making this more accessible. You can learn more information on the project [Github](https://github.com/sustainabu/OpenData_Saint_Paul) page as well as accessing documents. The supporting data workbook for this report can be accessed [here]()

# %% [markdown]
# # About the Data <a name="data"></a>
#
# **Note:** For all maps, the schools, L'Etoile Du Nord French Immersion U and  Mississippi Creative Arts Elementary was excluded because it caused the map software to crash. Also high schoolers were excluded entirely.
#
# **About the Data:**
#
# The primary assessments datasets are also retrieved from MDE [Data Reporting Web Portal](https://public.education.mn.gov/MDEAnalytics/DataTopic.jsp?TOPICID=1). I selected the following specifications "All accountability tests, which lists the three files for each respective subjects: Math, Reading, and Science. These reports combine both the Minnesota Comprehensive Assessment (MCA) and Minnesota Test of Academic Skills (MTAS). The MCA is the standardized test of Minnesota and has to follow both federal and state guidelines. The MTAS is an alternate assessment based on alternate achievement standards for students with the most significant cognitive disabilities. The subject testing grade breakdown is below, notice Science High School test can be taken at any grade level, and the subject tests are taken only once in high school.
#
# ![title](Graphs/TestSubjects.png)
#
# Personally, I would not give much weight on the high school tests because it is not mandatory to pass for graduation, which is supported by the data as participation rate for the high school exams are the lowest in comparison to the other grade levels.  In addition, high schoolers will likely place more effort on college entrance examinations such as the American College Testing (ACT). In this analysis, I will be excluding MCA testing at the high school level. Depending on time availability, I may consider to use the ACT data to perform a similar analysis for high schools.
#
#
# **Data Methodology:** For this analysis, I aggregated the total proficiency for each elementary to middle school. The demographic percentages is based on the students that have taken a standardized exam. The percentage of students in a category has become the normalized scale. The scale is the same for all achievement gap groups to assure to visually see the difference in individual school make-up. In addition, I created **quartile rank** to help distinguish performance for each school. The basic approach was to district average as the mid-point of school performance, and there is bandwidth for each category. The bandwidths were determined arbitrarily to get some variation. The ranking specifications and their respective color identifications on shading is below.
#
# ![title](Graphs/TCWeight.png)
#
# The maps are displayed by the same subject matter to make it easier for the viewer to read the data and see the impact of demographic variation.

# %% [markdown]
# ## Math <a name="math"></a>

# %%
plot_School_White()
# Out:
# This map displays 2019 Math Proficiency under normalized White%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Black()
# Out:
# This map displays 2019 Math Proficiency under normalized Black%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Asian()
# Out:
# This map displays 2019 Math Proficiency under normalized Asian%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_ELL()
# Out:
# This map displays 2019 Math Proficiency under normalized English Language Learners (ELL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_SPED()
# Out:
# This map displays 2019 Math Proficiency under normalized special needs students (SPED%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_FRPL()
# Out:
# This map displays 2019 Math Proficiency under normalized Free and Reduced Lunch (FRPL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Reading <a name="reading"></a>

# %%
plot_School_White('Reading')
# Out:
# This map displays 2019 Reading Proficiency under normalized White%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Black('Reading')
# Out:
# This map displays 2019 Reading Proficiency under normalized Black%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Asian('Reading')

# %%
plot_School_ELL('Reading')

# %%
plot_School_SPED('Reading')

# %%
plot_School_FRPL('Reading')

# %% [markdown]
# ## Science <a name="science"></a>

# %%
plot_School_White('Science')
# Out:
# This map displays 2019 Science Proficiency under normalized White%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Black('Science')
# Out:
# This map displays 2019 Science Proficiency under normalized Black%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Asian('Science')
# Out:
# This map displays 2019 Science Proficiency under normalized Asian%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_ELL('Science')
# Out:
# This map displays 2019 Science Proficiency under normalized English Language Learners (ELL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_SPED('Science')
# Out:
# This map displays 2019 Science Proficiency under normalized special needs students (SPED%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_FRPL('Science')
# Out:
# This map displays 2019 Science Proficiency under normalized Free and Reduced Lunch (FRPL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Saint Paul School Board Election Representation <a name="board"></a>
#
# In 2019, Saint Paul had a school board election, where voters can select four candidates on the ballot out of 10 candidates running. Every candidate is running for the same opening of seats. The four highest voted candidates win the election. All the candidates that were DFL, 3 for 3, endorsed won their their election. The following map below displays voting rate per precinct, notice the precincts with better performing schools are also voting more. How can we engage parents and communities in struggling schools to participate?

# %%
map_2019_SP_SchoolRepresentation_byPrecinct()
# Out:
# This map displays the voting percentage of registered voters by voting precint for the 2019 Saint Paul SchoolBoard Election
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Code <a name="code"></a>

# %%
B= School[(School['Subject'] == "Reading")]
    
B=B.query('City == "Minneapolis"')
B
# Out:
#                                    School  School_Num  Grade  Total_Tested  \
# 200               Adams Magnet Elementary      1230.0   12.0         265.0
# 201         American Indian Magnet School      3474.0   33.0         392.0
# 202        Battle Creek Elementary School      1266.0   12.0         203.0
# 203                   Battle Creek Middle       930.0   21.0         731.0
# 204                Benjamin E Mays Magnet      1272.0   12.0         181.0
# 217    18.0  ...   78.0              29.02      78.0                 43.88
# 218    42.0  ...   80.0              13.33      80.0                 22.22
# 219    25.0  ...   84.0              24.50      84.0                 28.21
# 220    39.0  ...   73.0              13.46      73.0                  0.00
# 221    30.0  ...   50.0              34.74      50.0                 77.66
# 222    54.0  ...   71.0              26.60      71.0                 48.72
# 223    46.0  ...   89.0              20.00      89.0                 27.08
# 224    48.0  ...   63.0              25.81      63.0                 72.60
# 225    19.0  ...   47.0              31.30      47.0                 77.48
# 226    53.0  ...   88.0              21.21      88.0                  0.00
# 227    10.0  ...   19.0              39.47      19.0                 85.44
# 228    27.0  ...   86.0              21.36      86.0                 30.16
# 229    27.0  ...   86.0              18.75      86.0                  0.00
# 230     4.0  ...   20.0               0.00      20.0                 92.19
# 231    26.0  ...   37.0              25.00      37.0                 69.07
# 232    43.0  ...   89.0              19.42      89.0                  0.00
# 233    20.0  ...   69.0              18.35      69.0                 77.08
# 234    33.0  ...   66.0              27.51      66.0                 73.91
# 235    69.0  ...   82.0              16.67      82.0                  0.00
# 236    24.0  ...   58.0              30.08      58.0                 67.96
# 237    11.0  ...   60.0              26.25      60.0                 55.56
# 238    13.0  ...   55.0              26.98      55.0                 51.92
# 239    73.0  ...   88.0              17.09      88.0                  0.00
# 240    10.0  ...   31.0              37.10      31.0                 76.09
# 241    22.0  ...   76.0              27.24      76.0                 37.00
# 242    20.0  ...   85.0              20.81      85.0                 55.00
# 243     3.0  ...   83.0              31.65      83.0                 38.00
# 244    44.0  ...   63.0              22.55      63.0                 67.01
# 245    13.0  ...   32.0              54.41      32.0                 86.99
# 246    22.0  ...   75.0              18.11      75.0                 21.43
# 247    22.0  ...   90.0              29.60      90.0                 38.71
# 248    12.0  ...   26.0              37.10      26.0                 77.97
# 249    28.0  ...   70.0              20.39      70.0                 31.82
# 250    27.0  ...   88.0              25.92      88.0                 43.33
#
#      Ranking                                   Address   Latitude  Longitude  \
# 200        4    615 S Chatsworth St, St Paul, MN 55102  44.923751 -93.143046
# 201        1          1075 3rd St E, St Paul, MN 55106  44.957364 -93.054959
# 202        2           60 Ruth St S, St Paul, MN 55119  44.939724 -93.013897
# 203        1         2121 N Park Dr, St Paul, MN 55119  44.945684 -93.011786
# 204        1      560 Concordia Ave, St Paul, MN 55103  44.950302 -93.122300
# 205        1         409 Case Ave E, St Paul, MN 55130  44.970897 -93.082901
# 206        4      560 Concordia Ave, St Paul, MN 55103  44.950302 -93.122300
# 207        4          1557 Huron St, St Paul, MN 55108  44.987963 -93.156008
# 208        1      694 S Charlton St, St Paul, MN 55107  44.925156 -93.095431
# 209        3    780 W Wheelock Pkwy, St Paul, MN 55117  44.978208 -93.133177
# 210        2      65 E Kellogg Blvd, St Paul, MN 55101  44.945128 -93.090919
# 211        3          543 Front Ave, St Paul, MN 55117  44.970910 -93.122748
# 212        2          543 Front Ave, St Paul, MN 55117  44.970910 -93.122748
# 213        1          262 Bates Ave, St Paul, MN 55106  44.954667 -93.066688
# 214        1       2001 Margaret St, St Paul, MN 55119  44.961587 -93.016614
# 215        4         540 Warwick St, St Paul, MN 55116  44.925180 -93.162172
# 215  Reading  Minneapolis
# 216  Reading  Minneapolis
# 217  Reading  Minneapolis
# 218  Reading  Minneapolis
# 219  Reading  Minneapolis
# 220  Reading  Minneapolis
# 221  Reading  Minneapolis
# 222  Reading  Minneapolis
# 223  Reading  Minneapolis
# 224  Reading  Minneapolis
# 225  Reading  Minneapolis
# 226  Reading  Minneapolis
# 227  Reading  Minneapolis
# 228  Reading  Minneapolis
# 229  Reading  Minneapolis
# 230  Reading  Minneapolis
# 231  Reading  Minneapolis
# 232  Reading  Minneapolis
# 233  Reading  Minneapolis
# 234  Reading  Minneapolis
# 235  Reading  Minneapolis
# 236  Reading  Minneapolis
# 237  Reading  Minneapolis
# 238  Reading  Minneapolis
# 239  Reading  Minneapolis
# 240  Reading  Minneapolis
# 241  Reading  Minneapolis
# 242  Reading  Minneapolis
# 243  Reading  Minneapolis
# 244  Reading  Minneapolis
# 245  Reading  Minneapolis
# 246  Reading  Minneapolis
# 247  Reading  Minneapolis
# 248  Reading  Minneapolis
# 249  Reading  Minneapolis
# 250  Reading  Minneapolis
#
# [51 rows x 23 columns]

# %%
School.query('Subject=="Reading"')

#Black
def plot_School_Black3(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','Black%', 'Black_Proficiency%','White_Proficiency%' ]

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    
    B= School[(School['Subject'] == Subject)]
    
    B=B.query('City == "Minneapolis"')
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Black%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}<br> White_Proficiency%: {}<br> Black_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'], row['White_Proficiency%'], row['Black_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    return FG_map

plot_School_Black3('Reading')
# Out:
# This map displays 2019 Reading Proficiency under normalized Black%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Run Code
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
import requests # library to handle requests
import folium
import seaborn as sns
import scipy.stats as stats #used to get correlation coefficient

School= pd.read_csv('Data/SchoolProf1.csv')
School=School.query('School_Num!=0')



def plot_School_White(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','White%','White_Proficiency%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized White%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}<br> White_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'], row['White_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}<br> White_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'], row['White_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}<br> White_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'], row['White_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}<br> White_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'], row['White_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#Black
def plot_School_Black(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','Black%', 'Black_Proficiency%','White_Proficiency%' ]

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Black%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}<br> White_Proficiency%: {}<br> Black_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'], row['White_Proficiency%'], row['Black_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}<br> White_Proficiency%: {}<br> Black_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'], row['White_Proficiency%'], row['Black_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}<br> White_Proficiency%: {}<br> Black_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'], row['White_Proficiency%'], row['Black_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}<br> White_Proficiency%: {}<br> Black_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'], row['White_Proficiency%'], row['Black_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#Asian
def plot_School_Asian(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','Asian%','Asian_Proficiency%','White_Proficiency%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Asian%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}<br> White_Proficiency%: {}<br> Asian_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'], row['White_Proficiency%'], row['Asian_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}<br> White_Proficiency%: {}<br> Asian_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'], row['White_Proficiency%'], row['Asian_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}<br> White_Proficiency%: {}<br> Asian_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'], row['White_Proficiency%'], row['Asian_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}<br> White_Proficiency%: {}<br> Asian_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'], row['White_Proficiency%'], row['Asian_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#ELL
def plot_School_ELL(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','ELL%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized English Language Learners (ELL%)'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#SPED
def plot_School_SPED(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','SPED%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized special needs students (SPED%)'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map


#FRPL
def plot_School_FRPL(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','FRPL%','FRPL_Proficiency%','NonFRPL_Proficiency%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Free and Reduced Lunch (FRPL%)'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}<br> FRPL_Proficiency%: {}<br> NonFRPL_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'], row['FRPL_Proficiency%'],row['NonFRPL_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}<br> FRPL_Proficiency%: {}<br> NonFRPL_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'], row['FRPL_Proficiency%'],row['NonFRPL_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}<br> FRPL_Proficiency%: {}<br> NonFRPL_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'], row['FRPL_Proficiency%'],row['NonFRPL_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}<br> FRPL_Proficiency%: {}<br> NonFRPL_Proficiency%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'], row['FRPL_Proficiency%'],row['NonFRPL_Proficiency%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map


############### Voting Records

P_19= pd.read_csv('Data/SaintPaul_2019_Ward_Precinct.csv')

P_19['C_Projected_Weight']= round(P_19['Reg_Vote_11/7/19'] / 165509, 4) *100
P_19['S_Actual_Weight']= round(P_19.SchoolBoard_Vote / 34894, 4) *100
P_19['S_Representation']= P_19.S_Actual_Weight - P_19.C_Projected_Weight


def map_2019_SP_SchoolRepresentation_byPrecinct(Ward=0):
    #setup
    sp_geo = r'SaintPaul_VotingPrecincts.json'
    
    
    
    if Ward==0:
        B=P_19
        A='City'
        zo= 12
    else: 
        B= P_19[(P_19['Ward'] == Ward)]
        A= 'Ward ' + str(Ward) +' '
        zo=13
    
    
    #Set up Variable Zoom Locations
    data = [[0, [44.948530, -93.096058]], [1, [44.958326, -93.122926]], [2, [44.933159, -93.115535]], [3, [44.918270, -93.176131]], [4, [44.961494, -93.176991]], [5, [44.978117, -93.106602]], [6, [44.978945, -93.047281]], [7, [44.942040, -93.033178]]] 

    #44.951655, -93.096323
    
    # Create the pandas DataFrame 
    Loc = pd.DataFrame(data, columns = ['Ward', 'Location']) 
    Loc.iloc[Ward,1:]
    
    
    # generate a new map
    SP_map = folium.Map(location=Loc.iloc[Ward,1], zoom_start=zo,tiles='OpenStreetMap') #tiles="OpenStreetMap")

    print('This map displays the voting percentage of registered voters by voting precint for the 2019 Saint Paul SchoolBoard Election')    
    SP_map.choropleth(
        geo_data=sp_geo,
        data=B,
        columns=['Precinct','SchoolBoard_RawVote%'],
        key_on="feature.properties.Precinct",
        fill_color='YlOrRd', 
        fill_opacity=0.7, 
        line_opacity=0.2,
        legend_name='2019 Saint Paul ' + A +' School Board Vote%',
        highlight= True
    )
                             
    # display map
    return SP_map


def map_2019_SP_SchoolRepresentation_byPrecinct1(Ward=0):
    #setup
    sp_geo = r'SaintPaul_VotingPrecincts.json'
    
    
    
    if Ward==0:
        B=P_19
        A='City'
        zo= 12
    else: 
        B= P_19[(P_19['Ward'] == Ward)]
        A= 'Ward ' + str(Ward) +' '
        zo=13
    
    
    #Set up Variable Zoom Locations
    data = [[0, [44.948530, -93.096058]], [1, [44.958326, -93.122926]], [2, [44.933159, -93.115535]], [3, [44.918270, -93.176131]], [4, [44.961494, -93.176991]], [5, [44.978117, -93.106602]], [6, [44.978945, -93.047281]], [7, [44.942040, -93.033178]]] 

    #44.951655, -93.096323
    
    # Create the pandas DataFrame 
    Loc = pd.DataFrame(data, columns = ['Ward', 'Location']) 
    Loc.iloc[Ward,1:]
    
    
    # generate a new map
    SP_map = folium.Map(location=Loc.iloc[Ward,1], zoom_start=zo,tiles='OpenStreetMap') #tiles="OpenStreetMap")

    print('This map displays the voting percentage of registered voters by voting precint for the 2019 Saint Paul SchoolBoard Election')    
    SP_map.choropleth(
        geo_data=sp_geo,
        data=B,
        columns=['Precinct','S_Representation'],
        key_on="feature.properties.Precinct",
        fill_color='YlOrRd', 
        fill_opacity=0.7, 
        line_opacity=0.2,
        legend_name='2019 Saint Paul ' + A +' School Board Vote%',
        highlight= True
    )
                             
    # display map
    return SP_map

# %%
map_2019_SP_SchoolRepresentation_byPrecinct()
# Out:
# This map displays the voting percentage of registered voters by voting precint for the 2019 Saint Paul SchoolBoard Election
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_2019_SP_SchoolRepresentation_byPrecinct1()
# Out:
# This map displays the voting percentage of registered voters by voting precint for the 2019 Saint Paul SchoolBoard Election
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
