# %% [markdown]
# <p><img style="padding: 0 15px; float: left;" src="Graphs/FTLogo300.jpg" alt="FT Crusader Logo" Width='140' Height= '250'/></p>
# <p> <h2> Saint Paul Public Schools 2019 Standardized Assessment Data Report; 12/17/19</h2> <a name="tc"></a>
# <p> <h3> By Frogtown Crusader (Abu Nayeem)</h3>

# %% [markdown]
# # Table of contents <a name="content"></a>
#
# **Note**: The schools L'Etoile Du Nord French Immersion U and  Mississippi Creative Arts Elementary are excluded from the interactive map due to some unknown programming error (i.e. caused the program to crash). With given time-constraints it was best to exclude.
#
# **Note**: Click on interactive maps to get more information on datapoints
#
# * [Brief Introduction](#intro)
# * [About Saint Paul Open Data Initiative](#opendata)
# * [About Me: Personal Opinion of an Education Data Analyst](#analyst)
# * [About Data](#aboutdata)
# * SPPS District/State Level Achievement Gap Analysis
#     * [Math](#math)
#     * [Reading](#reading)
#     * [Science](#science)
# * [SPPS Interactive Proficiency Maps by Demographics (Legend)](#map)
#     * [Math](#mathmap)
#     * [Reading](#readingmap)
#     * [Science](#sciencemap)
# * In Depth Demographic Analysis
#     * [Interactive Map: Twin Cities Homeless Students Breakdown](#homeless)
#     * [Race by Poverty Achievement Gap Analysis](#depth)
# * Tables: District & Individual School Proficiency/Enrollment by Grade
#     * [Elementary School](#elem)
#     * [Middle School](#int)
#     * [High School](#high)
# * [Concluding Thoughts](#conclusion)
# * [Run Code](#code)

# %% [markdown]
# ## Brief Introduction <a name="intro"></a>
#
# In this report, I will be primarily using state assessment data obtained from the Minnesota Department of Education (MDE) to assess how Saint Paul Public Schools (SPPS) is performing with respect to the state, and identify achievement gaps and larger trends. Due to data privacy restrictions, this is a diagnostic/ exploratory report and not an instructional report.
#
# Prior to writing this report, I have looked through the SPPS website in the Research, Evaluation, and Assessment (REA) section, I found that most of the material assessing state testing was inadequate and/or not updated. There were no documents that can help citizens/parents assess and evaluate  the performance of the school district, and the individual schools as a whole. To SPSS defense, as a former employee at a REA department, it is **strongly discouraged** for qualified staff to share information to the general public. Aside data privacy concerns; the primary concern is that with greater transparency, there is more accountability and scrutiny toward upper management by educators, parents, and residents alike. The dilemma outlined is a perfect example on why an Open Data Initiative run by independent citizens is strongly encouraged for any city/township. It can be used to inform the public, hold the district accountable, more objective analysis, and not be subjected by the influence/responsibility of working with an institution.
#
# The report is primarily structured as follows:
#
# * A broad overview of Minnesota standardized testing data to understand general state trends and the report itself
# * A district level breakdown for all subject matter; including several achievement gaps.
# * District level interactive proficiency maps with ranking based on Demographics [Excludes high school]
# * A district and school level proficiency breakdown by Grade
#
# This report took much longer than expected in preparing the code, and to display data intuitively for a wider audience; the interactive maps provide a lot of value. I'm proud of it.

# %% [markdown]
# ## Saint Paul Open Data Initiative <a name="opendata"></a>
#
# This initiative focuses on taking public information/data from municipalities and organizations to create interactive reports and analysis to better inform and assist community members to take action. This is an open-source project, meaning that all coding is accessible to everyone, and thus there is transparency on the results. It is currently all python-based. As always, I encourage other programmers and developers to participate in making this more accessible. You can learn more information on the project [Github](https://github.com/sustainabu/OpenData_Saint_Paul) page as well as accessing documents. The supporting data workbook for this report can be accessed [here]()

# %% [markdown]
# ## About Me: Opinion from a former Education Data Analyst <a name="analyst"></a>
#
# In 2015, I was the Education Data Analyst for South Washington County Schools for over two years, and it was the third largest school district in the state. I have some knowledge on assessment and standardized testing, and in my personal opinion MDE places too much emphasis on standardized testing. I can list several reasons on how standardized testing is inequitable and how the state evaluation methods is systematically unjust, though it can still be a valuable tool. State testing matters as it can influence people's decision in choosing schools, determine how state funding and resources are distributed, and can place additional burden on educators. For these reasons, this is why the report is valuable. I'll be replicating some of the diagnostic reports that I have implemented in the past for South Washington County schools. Sadly, my analysis will only provide a **static picture** of student assessment, which is not conducive is creating proactive change, and better accountability tools. I'll share some of my recommendations on the concluding section.
#
# Here are several things to keep in mind to keep you curious and able to process alarming data:
#
# * How can we address the challenges right NOW?
# * If standardized testing is not working for our city/communities, what are some existing alternatives? Or do we create, inclusively, a different curriculum/ academic standard that is aligned to community needs
# * How does charter schools influence SPPS? (I will not evaluate this)
# * What is the role of citizens in influencing SPPS policies, and state/federal policies?
# * What is the role of parents/students influencing SPPS?
# * What do local educators have to say about this?
# * Where are we spending our money, and how do we spend it on things that matter?

# %% [markdown]
# ## About the Data <a name="aboutdata"></a>
#
# The secondary dataset, [School Enrollment](https://public.education.mn.gov/MDEAnalytics/DataTopic.jsp?TOPICID=2) is from the MDE Data Center web portal. In the file, enrollment is taken at October 1st.  The primary assessments datasets are also retrieved from MDE [Data Reporting Web Portal](https://public.education.mn.gov/MDEAnalytics/DataTopic.jsp?TOPICID=1). I selected the following specifications "All accountability tests, which lists the three files for each respective subjects: Math, Reading, and Science. These reports combine both the Minnesota Comprehensive Assessment (MCA) and Minnesota Test of Academic Skills (MTAS). The MCA is the standardized test of Minnesota and has to follow both federal and state guidelines. The MTAS is an alternate assessment based on alternate achievement standards for students with the most significant cognitive disabilities. The subject testing grade breakdown is below, notice Science High School test can be taken at any grade level, and the subject tests are taken only once in high school.
#
# ![title](Graphs/TestSubjects.png)
#
# Personally, I would not give much weight on the high school tests because it is not mandatory to pass for  graduation, which is supported by the data as participation rate for the high school exams are the lowest in comparison to the other grade levels.  In addition, high schoolers will likely place more effort on college entrance examinations such as the American College Testing (ACT). On the SPPS website, you can view the ACT results through an [interactive report.](https://www.spps.org/Page/28069)
#
# The standardized tests place students into either four categories: Does Not Meet, Partially Meet, Meet, and Exceed Standards. Proficiency is the percentage of combined students in the Meet and Exceed category. This analysis will just use proficiency. Upon recently, parents and students can option out from taking the MCA, which influences the aggregate results, and may have some financial consequences for certain districts and schools.
#
# Furthermore, the federal/state government aims to reduce several achievement gaps across different demographic categories. The table describes it in more detail and I highlighted the categories of interest..
#
# ![title](Graphs/AchivementGapsList.png)
#
# For SPED and ELL standardized testing might not be the best metric for progress, because non-SPED students are categorically different than SPED students and for ELL students, this is a temporary status, and by construction, will perform poorly in comparison to non-EL counterparts. In general, Minnesota performs fairly well in standardized testing among other states; however it has a large racial equity gap (White vs Black) in academic testing performance ranging within the bottom five states. I will go over this under the in-depth achievement gap section.
#
# **Interpretation Disclaimer:** The MCA data only provides a **static picture** of student assessment, and does not consider the respective cohorts. We can use the state trend to determine if SPPS is considerably different compared to their peers.
#
# ### Saint Paul Public School District Data
#
# Saint Paul Public Schools (SPPS) is the largest school district, based on total enrollment, in Minnesota with 36,844 students enrolled and with over 44 elementary schools, 6 intermediate schools, 4 secondary schools, and 5 high schools. This is roughly 4.14% of total enrollment of the entire state, while Minneapolis has 4% enrollment. Due to the vast number of schools, and inadequate software it is hard to evaluate the individual schools in respect to achievement gaps. I will be comparing SPSS district data with state data, and the Minneapolis Public Schools (MPS). Note: The participation rate for MPS is around 91.3% and for Saint Paul it is 96.3%, which is near the state participation rate. The enrollment data is below. Notice there is more black and white students in Minneapolis, while there is more asian students and ELL students in Saint Paul. In comparison to state level, there is more poverty and people of color (POC) in the twin-cities compared to the state.
#
#
# ![title](Graphs/DisEnroll.png)

# %% [markdown]
# # Saint Paul District/State Analysis

# %% [markdown]
# ## Standardized Testing Math  <a name="math"></a>
#
# **NOTE**: there is no Math MCA testing for 9th and 10th grade.
#
# ### Proficiency
#
# ![title](Graphs/M_Prof.png)
#
# From the data, we see there is a steep decline in proficiency in 5th-6th grade, and at high school. It is hard for students to transition into middle school as instruction and environment is different. Both MPS and SPPS is far below the state average. At 11th grade, MPS and SPPS intersect, and this is more likely to do with the participation rate of each district. For SPPS, the participation rate is 76.8%, for MPS its 46.4%, and for state it's 88%. The discussion around high school testing is that well-off students are more likely not to take the exam, negatively impacting overall efficiency
#
# ### Gender Gap
#
# ![title](Graphs/M_Gender.png)
#
# The stereotype is that boys are better in math than girls, as the graphs show that they are fairly equal (though research have shown that boys assessment has more fatter tails, where as there is greater concentration of boys that excel in math and boys that do poorly in math.) Girls do better than boys by 8th grade.
#
# ### Racial Gap
#
# ![title](Graphs/M_Racial1.jpg)
#
# I've created the category of people of color (POC) to capture all non-White people. I've color coded the endpoints to make the comparison easier to spot visually. First, we find that white student perform better than state average, and there is no gap between the state and SPSS. In comparison, the other racial groups are below the state proficiency, and the gap between the state and SPSS is steady at 10% points. By 8th grade, in SPPS, white students  perform 50% points greater than black students.
#
# ### Economic Gap
#
# ![title](Graphs/M_Economic.png)
#
# As expected, students with less economic burden will be more proficient than their counterparts. For SPPS NonFRPL students, they perform as good as the state average. Lower income students in SPSS have lower proficiency rates compared to state counterparts, though the gap declined from 15% to 10% at 8th grade.

# %% [markdown]
# ## Standardized Testing Reading <a name="reading"></a>
#
# **NOTE**: there is no MCA Reading testing for 9th grade.
#
# ### Proficiency
#
# ![title](Graphs/R_Prof.png)
#
# Don't let the scale trick you. SPPS is roughly 20% points less than the state average up to 8th grade, and 15% at 10th grade. Interestingly, MPS continued to decline proficiency from 7th grade to 10th grade with SPPS doing better at 10th grade. For SPPS, the participation rate is 86.9%, for MPS its 52.9%, and for state it's 88%. The drop in proficiency for MPS at 19th grade might be due to low participation rate.
#
#
# ### Gender Gap
#
# ![title](Graphs/R_Gender.png)
#
# The stereotype is that girls are better in reading than boys, which is confirmed by the graph. At the state level, the gender gap expands being around 15% at 8th grade. From 7th to 8th grade, proficiency of boys declined, while for girls it has increased. On other hand, for SPPS boys proficiency has increased at from 7th to 8th grade with a difference around 5% points.
#
# ### Racial Gap
#
# ![title](Graphs/R_Racial1.jpg)
#
# I've color coded the endpoints to make the comparison easier to spot visually. First, we find that white student perform better than state average, and SPPS white students **perform 10% points greater** than the state by 8th grade on an upward trend. In comparison, the other racial groups are below the state proficiency, and the gap between the state and SPSS is steady at 10% points. By 8th grade, in SPPS, white students perform 50% points greater than black students, same as mathematics.
#
# ### Economic Gap
#
# ![title](Graphs/R_Economic.png)
#
# As expected, students with less economic burden will be more proficient than their counterparts. For SPPS NonFRPL students, they perform better than the state average, but less than their state counterparts. Lower income students in SPPS have lower proficiency rates compared to state counterparts, though the gap declined from 13% to 10% at 8th grade.

# %% [markdown]
# ## Standardized Testing  Science <a name="science"></a>
#
# **NOTE**: there is MCA Science testing for 5th, 8th, and anytime within high school
#
# ### Proficiency
#
# ![title](Graphs/S_Prof.png)
#
# From 5th to 8th grade, MPS and state scores sharply declined in proficiency. SPPS is roughly 18% points less than the state average at 8th grade and at high school level. Interestingly, MPS stagnated from 8th grade to high school level with SPPS doing better. For SPPS, the participation rate is 78.2%, for MPS its 41.7%, and for state it's 87.3%. The drop in proficiency for MPS at the high school level might be due to low participation rate.
#
#
# ### Gender Gap
#
# ![title](Graphs/S_Gender.png)
#
# At the state level, the slight gender gap closes by high school. While SPPS, the gender gap expands with boys performing 4% points better than girls. At the state level, the gender gap expands being around 15% at 8th grade. From 7th to 8th grade, proficiency of boys declined, while for girls it has increased. On other hand, for SPPS boys proficiency has increased at from 7th to 8th grade with a difference around 5% points.
#
# ### Racial Gap
#
# ![title](Graphs/S_Racial1.jpg)
#
# I've color coded the endpoints to make the comparison easier to spot visually. First, we find that white student perform better than state average, and SPPS white students **perform 10% points greater** than the state by 8th grade and 5% by high school level. In comparison, the other racial groups are below the state proficiency, and the gap between the state and SPPS is steady at 5-8% points. At high school level, in SPPS, white students perform 50% points greater than black students, which is true for all the other subjects.
#
# ### Economic Gap
#
# ![title](Graphs/S_Economic.png)
#
# As expected, students with less economic burden will be more proficient than their counterparts. For SPPS NonFRPL students, they perform at the state average, but less than their state counterparts by around 5% points. Lower income students in SPPS have lower proficiency rates compared to state counterparts, though the gap declined from 15% to 10% at the high school level.

# %% [markdown]
# # District-Wide Interactive Maps on Achievement Gaps <a name="map"></a>
#
# **Note:** For all maps, the schools, L'Etoile Du Nord French Immersion U and  Mississippi Creative Arts Elementary was excluded because it caused the map software to crash. Also high schoolers were excluded entirely.
#
# **Data Methodology:** For this analysis, I aggregated the total proficiency for each elementary to middle school. The demographic percentages is based on the students that have taken a standardized exam. The percentage of students in a category has become the normalized scale. The scale is the same for all achievement gap groups to assure to visually see the difference in individual school make-up. In addition, I created **ranking system** to help distinguish performance for each school. The basic approach was to district average as the mid-point of school performance, and there is bandwidth for each category. The bandwidths were determined arbritarily to get some variation. The ranking specifications and their respective color identifications on shading is below.
#
# ![title](Graphs/CategoryRank.png)
#
# The maps are displayed by the same subject matter to make it easier for the viewer to read the data and see the impact of demographic variation.

# %% [markdown]
# ## SPPS Interactive Maps: Math <a name="mathmap"></a>
#
# ### Achievement Gap White

# %%
plot_School_White()
# Out:
# This map displays 2019 Math Proficiency under normalized White%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Black()
# Out:
# This map displays 2019 Math Proficiency under normalized Black%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Asian()
# Out:
# This map displays 2019 Math Proficiency under normalized Asian%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_ELL()
# Out:
# This map displays 2019 Math Proficiency under normalized English Language Learners (ELL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_SPED()
# Out:
# This map displays 2019 Math Proficiency under normalized special needs students (SPED%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_FRPL()
# Out:
# This map displays 2019 Math Proficiency under normalized Free and Reduced Lunch (FRPL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## SPPS Interactive Maps: Reading <a name="readingmap"></a>
#
# ### Achievement Gap White

# %%
plot_School_White("Reading")
# Out:
# This map displays 2019 Reading Proficiency under normalized White%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Black("Reading")
# Out:
# This map displays 2019 Reading Proficiency under normalized Black%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Asian("Reading")
# Out:
# This map displays 2019 Reading Proficiency under normalized Asian%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_ELL("Reading")
# Out:
# This map displays 2019 Reading Proficiency under normalized English Language Learners (ELL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_SPED("Reading")
# Out:
# This map displays 2019 Reading Proficiency under normalized special needs students (SPED%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_FRPL("Reading")
# Out:
# This map displays 2019 Reading Proficiency under normalized Free and Reduced Lunch (FRPL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## SPPS Interactive Maps: Science <a name="sciencemap"></a>
#
# ### Achievement Gap White

# %%
plot_School_White("Science")
# Out:
# This map displays 2019 Science Proficiency under normalized White%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Black('Science')
# Out:
# This map displays 2019 Science Proficiency under normalized Black%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_Asian("Science")
# Out:
# This map displays 2019 Science Proficiency under normalized Asian%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_ELL("Science")
# Out:
# This map displays 2019 Science Proficiency under normalized English Language Learners (ELL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_SPED("Science")
# Out:
# This map displays 2019 Science Proficiency under normalized special needs students (SPED%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_School_FRPL("Science")
# Out:
# This map displays 2019 Science Proficiency under normalized Free and Reduced Lunch (FRPL%)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # In Depth Demographic Breakdown

# %% [markdown]
#  ## Interactive Map Twin Cities Homeless Students <a name="homeless"></a>
#
# In Saint Paul, there is over 643 homeless students, and it makes up around 8% of the homeless student population in the state. According to the numbers tested for Reading, around 61% of the homeless student population is Black. The following map below show the schools with highest number of homeless. **Note:** the map is interactive, clicking on the circle will display the school and other information.

# %%
plot_Homeless()
# Out:
# This map displays 2019 Homeless Student Count > 3 from October 1st,2019 Enrollment
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Race by Poverty Achievement Gap Analysis <a name="depth"></a>
#
# With all these different achievement gaps, how do we address closing these inequities, and which factors matter the most, is it race, gender, and/or income status. From the earlier graphs above, for SPPS there is 50% points between white and black students across all subject testings, but for economic it's around 30% points. However, several Minnesota researchers stated that poverty (FRPL designation) has the greatest influence on state proficiency. This might not be too intuitive at first to many. The simple explanation is that poverty is highly correlated with race in SPPS; i.e. most black students are in the FRPL category in comparison to their counterparts. To highlight this, I break down the sub category demographics in respect to race and poverty for the state level and SPPS district for MCA Reading testing. The data was manually entered through the [Minnesota Report Card](https://rc.education.mn.gov/#assessmentsParticipation/orgId--10625000000__groupType--district__test--allAccount__subject--S__accountabilityFlg--FOC_NONE__year--2019__grade--HS__p--1e7) Note: I did not include MPS because of the low participation rate. First, let's explore the state-level data. Also the data is restricted from 3rd to 8th Grade and 10th Grade.
#
# ![title](Graphs/StateRaceEconomic1.png)
#
# This is a bit confusing to read so let's break down the first row. For the Exceed proficiency, 3,429 black students achieved this with 2,196 students having FRPL status, which makes 64.04% of the group. In comparison, only 11.60% of White students that are in the Exceed category have FRPL status. In the "Total row", **for the state 82% of all black students are receiving FRPL status**, with 22% for white students and nearly 50% of Asian students. The last row shows the proficiency percentage for each category with the shaded cell indicating the gap between proficiency. For example, for all black students, 34.68% were proficient and for black FRPL students 30.91% were proficient, which is a gap around 3.7%.  The gap is smaller compared to other groups because majority of black students have FRPL status, though black students in the nonFRPL category do not have considerably high proficiency rate. Notice, that for both for white and asian students the gap is higher though notice proficiency difference between Asian students of income status, non-FRPL students do considerably better. The SPPS picture looks quite different.
#
# ![title](Graphs/SPRaceEconomic.png)
#
# For Saint Paul, the percentage of black students with FRPL status is even higher at 85.66% with a respective 2% gap. Though student proficiency is lower than compared to non-urban counterparts. For white NonFRPL students, they perform better than their state counterparts because most of the state is rural which consist primarily of white people and there are wealthy white families in Saint Paul. Thus the White_FRPL proficiency gap is even larger than compared to the state. In Saint Paul, **around 80% of asian students have FRPL status** and have respectfully a small proficiency gap. Notice the Asian_NonFRPL students do not perform as well their out of city counterparts. This could possibly be explained that new immigrant communities leave Saint Paul when they get more wealth, and there is a population of highly skilled professionals in the suburbs. In this table, there is an additional row, "% of State", which indicates the percentage of the total population that lives in Saint Paul. For example, 9.42% of all black students live in Saint Paul. Likewise, only 1.2% of white students live in Saint Paul. For Asian students, Saint Paul comprises 17% of the total population and around 27% of FRPL students. In addition, notice that Asian_NonFRPL only consist around 7% of the population, suggesting that wealthier asians do not live in Saint Paul.
#
#
# In summary, we see how prevalent poverty is in SPSS, though even controlling for FRPL status, achievement gaps still exist across racial lines. In the next section, I will be displaying the summary proficiency results of the elementary and middle schools.

# %% [markdown]
# # District/State Proficiency Level by Grade

# %% [markdown]
# ## Elementary Schools <a name="elem"></a>
#
# #### Enroll Data

# %%
Enroll.query('Num in (410.0,415.0,422.0,424.0,425.0,428.0,431.0,433.0,435.0,449.0,452.0,458.0,460.0,462.0,464.0,465.0,466.0,578.0,579.0,552.0,557.0,558.0,467.0,476.0,482.0,483.0,488.0,489.0,491.0,493.0,494.0,496.0,500.0,510.0,518.0,524.0,527.0,533.0,534.0,541.0,545.0,551.0)').sort_values(by=['School'])
# Out:
#       Num                                School  Tot_Enroll  Male%  White%  \
# 16  410.0               Adams Magnet Elementary       616.0  49.19   26.46
# 59  579.0         American Indian Magnet School       642.0  51.56    5.14
# 18  422.0        Battle Creek Elementary School       472.0  54.24    7.20
# 19  424.0                Benjamin E Mays Magnet       406.0  57.64    3.69
# 25  449.0              Bruce F Vento Elementary       514.0  49.81    3.31
# 42  494.0             Capitol Hill Magnet/Rondo      1254.0  53.03   38.28
# 20  425.0            Chelsea Heights Elementary       445.0  52.36   45.62
# 21  428.0    Cherokee Heights Elementary School       215.0  51.63   18.60
# 22  431.0                  Como Park Elementary       451.0  53.66   11.75
# 32  465.0                 Crossroads Montessori       259.0  49.81   18.15
# 33  466.0            Crossroads Science Program       290.0  51.72    9.66
# 23  433.0              Daytons Bluff Elementary       328.0  53.05   10.06
# 26  452.0            Eastern Heights Elementary       334.0  54.19   10.18
# 24  435.0    Expo For Excellence Elementary Sch       663.0  54.75   58.37
# 27  458.0            Farnsworth Aerospace Lower       479.0  53.24    6.89
# 28  460.0               Four Seasons Elementary       462.0  47.19   12.77
# 31  464.0          Frost Lake Elementary School       535.0  51.59    5.98
# 34  467.0             Galtier Elementary School       196.0  51.02   27.55
# 35  476.0             Groveland Park Elementary       402.0  48.51   44.28
# 36  482.0             Hamline Elementary School       284.0  54.58   17.96
# 39  489.0        Hazel Park Preparatory Academy       588.0  51.87    5.27
# 40  491.0              Highland Park Elementary       385.0  53.77   27.01
# 43  496.0             Highwood Hills Elementary       283.0  49.82    3.53
# 46  518.0                    Horace Mann School       432.0  49.07   66.90
# 44  500.0        Jackson Preparatory Elementary       311.0  54.34    1.93
# 37  483.0   Jie Ming Mandarin Immersion Academy       293.0  47.10   30.03
# 41  493.0                    Jj Hill Montessori       406.0  50.00   48.03
# 17  415.0  John A. Johnson Achievement Plus El.       375.0  46.93    7.73
# 29  462.0   L'Etoile Du Nord French Immersion U       304.0  39.80   53.62
# 45  510.0        Linwood Monroe Arts Plus Lower       396.0  50.51   29.29
# 47  524.0            Maxfield Elementary School       282.0  48.94    5.32
# 48  527.0  Mississippi Creative Arts Elementary       619.0  50.89    7.59
# 50  533.0       Nokomis Montessori North Campus       362.0  51.10   22.65
# 51  534.0       Nokomis Montessori South Campus       267.0  56.55   25.84
# 58  578.0     Obama Service Learning Elementary       367.0  54.50    6.27
# 55  552.0    Paul & Sheila Wellstone Elementary       537.0  51.96    5.03
# 52  541.0      Phalen Lake Hmong Studies Magnet       651.0  52.23    0.92
# 53  545.0           Randolph Heights Elementary       447.0  51.68   64.65
# 54  551.0   Riverview West School Of Excellence       391.0  51.41    7.67
# 57  558.0              Saint Paul Music Academy       637.0  48.19    3.45
# 56  557.0           St. Anthony Park Elementary       515.0  50.87   60.97
# 38  488.0          The Heights Community School       462.0  56.93    9.09
#
#     Black%  Asian%   FRPL%    ELL%   SPED% Homeless%
# 16   15.26    0.32  48.86%  22.08%   6.66%     0.81%
# 59   17.29   26.79  81.93%  28.50%  18.85%     3.74%
# 18   28.81   43.01  73.31%  41.31%  18.01%     1.27%
# 19   66.75   14.29  80.54%  24.63%  20.94%     3.94%
# 25   25.49   57.39  89.30%  54.86%  11.48%     3.70%
# 42   22.65   24.96  41.87%  10.53%   5.50%     0.32%
# 20   22.47   12.13  45.17%  19.33%   9.44%     1.35%
# 21   21.86    7.44  71.16%  30.23%  20.93%     3.72%
# 22   25.50   44.35  77.83%  44.79%  22.84%     1.33%
# 32   30.12   21.24  69.88%  22.01%  10.81%     1.93%
# 33   44.83   26.90  76.21%  29.66%  15.17%     1.03%
# 23   38.72   26.22  81.71%  28.66%  17.07%     6.40%
# 26   24.55   41.62  74.55%  46.41%  18.26%     2.40%
# 24   23.98    3.92  33.63%  12.97%  11.16%     1.06%
# 27   11.69   68.68  72.86%  58.25%   8.35%     1.25%
# 28   45.67   16.02  80.09%  34.85%  16.88%     3.46%
# 31   22.06   52.52  76.64%  53.08%  14.77%     0.93%
# 34   33.67    7.65  67.35%  16.84%  11.73%     5.10%
# 35   27.86    5.72  51.24%  16.17%  10.95%     0.25%
# 36   50.70   11.27  73.94%  21.83%  13.03%     3.87%
# 39   42.86   31.12  87.41%  24.49%  13.61%     4.42%
# 40   49.87    8.05  66.23%  34.29%   7.27%     1.04%
# 43   62.90   21.55  82.69%  57.24%   8.13%     1.77%
# 46   13.19    3.47  21.53%   9.03%   9.95%     0.46%
# 44   26.05   61.74  80.39%  59.49%  10.29%     0.64%
# 37    8.19   31.06  25.60%  26.62%   3.07%     0.00%
# 41   23.65    7.64  34.48%  21.18%  10.59%     0.00%
# 17   42.40   27.20  86.13%  31.73%  13.87%     6.93%
# 29   19.41    3.62  30.26%  12.50%   4.61%     0.00%
# 45   20.20   24.49  66.41%  39.14%  19.44%     1.77%
# 47   62.77    6.74  81.21%   9.57%  15.60%    13.12%
# 48   21.32   53.96  85.95%  54.93%  13.41%     2.58%
# 50    8.56   52.49  58.84%  41.71%  10.77%     1.10%
# 51   11.99   41.20  55.81%  34.83%  15.36%     0.00%
# 58   69.21    8.17  84.20%  14.17%  15.80%     7.08%
# 55   21.97   16.95  81.94%  59.03%  17.13%     1.86%
# 52    3.84   87.86  80.49%  70.05%   6.91%     0.15%
# 53   13.20    6.26  28.41%  12.30%   5.15%     0.45%
# 54   20.20    3.58  76.73%  50.38%  12.02%     1.28%
# 57   21.19   57.30  88.38%  58.24%  13.50%     1.26%
# 56   11.46   11.07  25.44%  16.50%   9.51%     0.00%
# 38   24.46   38.74  69.91%  40.69%  18.40%     1.95%

# %% [markdown]
# #### Reading Data [Grade 3 to 5]

# %%
Reading.query('Grade==3').sort_values(by=['Prof'], ascending=False)
# Out:
#                                    School    Num  Grade    Prof  White_Prof  \
# 106   Jie Ming Mandarin Immersion Academy  483.0    3.0  0.8065         NaN
# 138                    Horace Mann School  518.0    3.0  0.7544      0.8372
# 160           Randolph Heights Elementary  545.0    3.0  0.7179      0.8269
# 124             Capitol Hill Magnet/Rondo  494.0    3.0  0.7059      0.8621
# 71     Expo For Excellence Elementary Sch  435.0    3.0  0.6346      0.7667
# 169           St. Anthony Park Elementary  557.0    3.0  0.6265      0.7111
# 85    L'Etoile Du Nord French Immersion U  462.0    3.0  0.6230      0.7857
# 59             Chelsea Heights Elementary  425.0    3.0  0.5946      0.7750
# 191                             State_All    0.0    3.0  0.5461      0.6366
# 100             Groveland Park Elementary  476.0    3.0  0.5273      0.6923
# 121                    Jj Hill Montessori  493.0    3.0  0.4906      0.6000
# 47                Adams Magnet Elementary  410.0    3.0  0.4643      0.7692
# 184                     Mpls_District_All    0.0    3.0  0.4587      0.7578
# 136        Linwood Monroe Arts Plus Lower  510.0    3.0  0.4304      0.6400
# 91                  Crossroads Montessori  465.0    3.0  0.4194         NaN
# 94             Crossroads Science Program  466.0    3.0  0.3864         NaN
# 0                         Sp_District_All    0.0    3.0  0.3525      0.6891
# 97              Galtier Elementary School  467.0    3.0  0.3462         NaN
# 172              Saint Paul Music Academy  558.0    3.0  0.3441         NaN
# 103             Hamline Elementary School  482.0    3.0  0.3333         NaN
# 112        Hazel Park Preparatory Academy  489.0    3.0  0.3261         NaN
# 80             Farnsworth Aerospace Lower  458.0    3.0  0.3232         NaN
# 118              Highland Park Elementary  491.0    3.0  0.3134      0.7143
# 157      Phalen Lake Hmong Studies Magnet  541.0    3.0  0.2857         NaN
# 53         Battle Creek Elementary School  422.0    3.0  0.2769      0.1000
# 151       Nokomis Montessori North Campus  533.0    3.0  0.2600      0.4000
# 77             Eastern Heights Elementary  452.0    3.0  0.2439         NaN
# 154       Nokomis Montessori South Campus  534.0    3.0  0.2308      0.3000
# 65                   Como Park Elementary  431.0    3.0  0.2154         NaN
# 109          The Heights Community School  488.0    3.0  0.2097         NaN
# 166    Paul & Sheila Wellstone Elementary  552.0    3.0  0.2048         NaN
# 50   John A. Johnson Achievement Plus El.  415.0    3.0  0.2000         NaN
# 88           Frost Lake Elementary School  464.0    3.0  0.2000         NaN
# 133        Jackson Preparatory Elementary  500.0    3.0  0.1905         NaN
# 175     Obama Service Learning Elementary  578.0    3.0  0.1818         NaN
# 68               Daytons Bluff Elementary  433.0    3.0  0.1800         NaN
# 144  Mississippi Creative Arts Elementary  527.0    3.0  0.1720         NaN
# 56                 Benjamin E Mays Magnet  424.0    3.0  0.1695         NaN
# 163   Riverview West School Of Excellence  551.0    3.0  0.1525         NaN
# 82                Four Seasons Elementary  460.0    3.0  0.1250         NaN
# 74               Bruce F Vento Elementary  449.0    3.0  0.1216         NaN
# 62     Cherokee Heights Elementary School  428.0    3.0  0.1212         NaN
# 130             Highwood Hills Elementary  496.0    3.0  0.0541         NaN
# 141            Maxfield Elementary School  524.0    3.0  0.0455         NaN
# 178         American Indian Magnet School  579.0    3.0  0.0290         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 106       NaN         NaN     0.7692       0.8333        NaN        0.8889
# 138    0.5000         NaN     0.6364       0.8286        NaN        0.8200
# 160    0.5000      0.5000     0.5833       0.8333     0.4815        0.8431
# 124    0.5897      0.5769     0.6324       0.7794     0.5000        0.8043
# 71     0.4545      0.3846     0.6271       0.6444     0.3030        0.7887
# 169    0.5263         NaN     0.6341       0.6190     0.3636        0.7213
# 85     0.4848      0.6923     0.6522       0.6053     0.4286        0.6809
# 59     0.3824      0.5000     0.6364       0.5610     0.4063        0.7381
# 191    0.3847      0.3242     0.5163       0.5771     0.3555        0.6720
# 100    0.3793      0.1667     0.5714       0.5122     0.3462        0.6897
# 121    0.3929      0.2857     0.5200       0.4643     0.2381        0.6563
# 47     0.3276      0.0909     0.4390       0.4884     0.2051        0.6889
# 184    0.2752      0.2407     0.4318       0.4871     0.2408        0.7355
# 136    0.3333      0.2500     0.3429       0.5000     0.2642        0.7692
# 91        NaN         NaN     0.3889       0.4615     0.2632        0.6667
# 94        NaN      0.2917     0.3125       0.4286     0.3548        0.4615
# 0      0.2558      0.2270     0.3281       0.3768     0.2162        0.6019
# 97        NaN         NaN     0.2308       0.4615     0.1765           NaN
# 172       NaN      0.4091     0.3478       0.3404     0.3012        0.7000
# 103       NaN      0.2500     0.3913       0.2727     0.3000        0.4000
# 112       NaN      0.2917     0.1905       0.4400     0.2927           NaN
# 80        NaN      0.5000     0.3710       0.2432     0.2917        0.4074
# 118    0.2075      0.1429     0.3235       0.3030     0.1556        0.6364
# 157       NaN         NaN     0.2353       0.3404     0.2727        0.3333
# 53     0.3091      0.2692     0.2727       0.2813     0.2364        0.5000
# 151    0.2000         NaN     0.3103       0.1905     0.2727        0.2353
# 77        NaN      0.1538     0.1600       0.3750     0.2000        0.3636
# 154    0.2069         NaN     0.2273       0.2353     0.1500        0.3158
# 65        NaN      0.1500     0.1471       0.2903     0.2000        0.3000
# 109       NaN      0.1111     0.2000       0.2222     0.1333        0.4118
# 166       NaN      0.1000     0.1500       0.2558     0.1159        0.6429
# 50        NaN      0.1667     0.3000       0.1429     0.2174           NaN
# 88        NaN      0.2273     0.1892       0.2093     0.1875        0.2500
# 133       NaN         NaN     0.2273       0.1500     0.1667           NaN
# 175       NaN      0.1667     0.2353       0.1250     0.1786           NaN
# 68        NaN      0.1579     0.2333       0.1000     0.2195           NaN
# 144       NaN      0.1000     0.2000       0.1395     0.1728        0.1667
# 56        NaN      0.1818     0.1724       0.1667     0.1600           NaN
# 163       NaN      0.2000     0.1563       0.1481     0.1489        0.1667
# 82        NaN      0.1034     0.0789       0.1765     0.1017        0.2308
# 74        NaN      0.1250     0.1143       0.1282     0.1029           NaN
# 62        NaN         NaN     0.0588       0.1875     0.0769           NaN
# 130       NaN      0.0588     0.0952       0.0000     0.0667           NaN
# 141       NaN      0.0385     0.0556       0.0385     0.0278           NaN
# 178       NaN         NaN     0.0244       0.0357     0.0185        0.0667

# %%
Reading.query('Grade==4').sort_values(by=['Prof'], ascending=False)
# Out:
#                                    School    Num  Grade    Prof  White_Prof  \
# 107   Jie Ming Mandarin Immersion Academy  483.0    4.0  0.9643         NaN
# 139                    Horace Mann School  518.0    4.0  0.7541      0.8500
# 161           Randolph Heights Elementary  545.0    4.0  0.7391      0.8000
# 125             Capitol Hill Magnet/Rondo  494.0    4.0  0.7324      0.9245
# 170           St. Anthony Park Elementary  557.0    4.0  0.7059      0.7931
# 86    L'Etoile Du Nord French Immersion U  462.0    4.0  0.6230      0.8571
# 72     Expo For Excellence Elementary Sch  435.0    4.0  0.5619      0.7647
# 192                             State_All    0.0    4.0  0.5543      0.6534
# 122                    Jj Hill Montessori  493.0    4.0  0.5490      0.6923
# 60             Chelsea Heights Elementary  425.0    4.0  0.5070      0.7143
# 66                   Como Park Elementary  431.0    4.0  0.4667         NaN
# 101             Groveland Park Elementary  476.0    4.0  0.4444      0.6111
# 48                Adams Magnet Elementary  410.0    4.0  0.4405      0.7368
# 185                     Mpls_District_All    0.0    4.0  0.4398      0.7856
# 155       Nokomis Montessori South Campus  534.0    4.0  0.4359         NaN
# 119              Highland Park Elementary  491.0    4.0  0.4138      0.6316
# 92                  Crossroads Montessori  465.0    4.0  0.3704         NaN
# 1                         Sp_District_All    0.0    4.0  0.3463      0.7038
# 81             Farnsworth Aerospace Lower  458.0    4.0  0.3271         NaN
# 95             Crossroads Science Program  466.0    4.0  0.3137         NaN
# 137        Linwood Monroe Arts Plus Lower  510.0    4.0  0.2949      0.6400
# 54         Battle Creek Elementary School  422.0    4.0  0.2877         NaN
# 158      Phalen Lake Hmong Studies Magnet  541.0    4.0  0.2826         NaN
# 152       Nokomis Montessori North Campus  533.0    4.0  0.2667      0.6000
# 78             Eastern Heights Elementary  452.0    4.0  0.2553         NaN
# 173              Saint Paul Music Academy  558.0    4.0  0.2381         NaN
# 164   Riverview West School Of Excellence  551.0    4.0  0.2373         NaN
# 142            Maxfield Elementary School  524.0    4.0  0.2368         NaN
# 89           Frost Lake Elementary School  464.0    4.0  0.2250         NaN
# 167    Paul & Sheila Wellstone Elementary  552.0    4.0  0.2118         NaN
# 63     Cherokee Heights Elementary School  428.0    4.0  0.1935         NaN
# 75               Bruce F Vento Elementary  449.0    4.0  0.1831         NaN
# 104             Hamline Elementary School  482.0    4.0  0.1818         NaN
# 131             Highwood Hills Elementary  496.0    4.0  0.1750         NaN
# 145  Mississippi Creative Arts Elementary  527.0    4.0  0.1683         NaN
# 69               Daytons Bluff Elementary  433.0    4.0  0.1628         NaN
# 83                Four Seasons Elementary  460.0    4.0  0.1538      0.2500
# 113        Hazel Park Preparatory Academy  489.0    4.0  0.1509         NaN
# 176     Obama Service Learning Elementary  578.0    4.0  0.1481         NaN
# 110          The Heights Community School  488.0    4.0  0.1395         NaN
# 57                 Benjamin E Mays Magnet  424.0    4.0  0.1250         NaN
# 134        Jackson Preparatory Elementary  500.0    4.0  0.1091         NaN
# 98              Galtier Elementary School  467.0    4.0  0.0870         NaN
# 51   John A. Johnson Achievement Plus El.  415.0    4.0  0.0816         NaN
# 179         American Indian Magnet School  579.0    4.0  0.0606         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 107       NaN         NaN     0.9167       1.0000        NaN        0.9565
# 139    0.5714         NaN     0.8000       0.6923     0.4615        0.8333
# 161    0.6250         NaN     0.6923       0.8000     0.5000        0.8367
# 125    0.6180      0.6818     0.7391       0.7260     0.6102        0.8193
# 170    0.5185         NaN     0.7619       0.6512     0.3750        0.7826
# 86     0.3077      0.3333     0.6296       0.6176     0.3500        0.7561
# 72     0.3704      0.2069     0.5714       0.5510     0.2609        0.7966
# 192    0.3805      0.3072     0.5257       0.5846     0.3568        0.6860
# 122    0.4000      0.0909     0.5172       0.5909     0.2308        0.6579
# 60     0.3721      0.3333     0.2703       0.7647     0.4500        0.5806
# 66        NaN      0.4615     0.4091       0.5484     0.4098        0.7143
# 101    0.3611      0.3478     0.3824       0.5500     0.2424        0.7619
# 48     0.3538         NaN     0.4737       0.4130     0.3556        0.5385
# 185    0.2524      0.2181     0.4261       0.4551     0.2296        0.7315
# 155       NaN         NaN     0.3478       0.5625     0.3600        0.5714
# 119    0.3077      0.2083     0.3478       0.4571     0.2059        0.7083
# 92        NaN         NaN     0.2000       0.4706     0.3333           NaN
# 1      0.2547      0.1975     0.3293       0.3646     0.2267        0.5962
# 81        NaN      0.0000     0.3115       0.3478     0.2821        0.4483
# 95        NaN      0.3684     0.3226       0.3000     0.2500        0.4667
# 137    0.1321      0.1053     0.2979       0.2903     0.1071        0.7727
# 54        NaN      0.3000     0.3103       0.2727     0.2593        0.3684
# 158       NaN         NaN     0.2453       0.3333     0.2692        0.3571
# 152    0.1714         NaN     0.2632       0.2692     0.1379        0.5000
# 78        NaN         NaN     0.3200       0.1818     0.1944        0.4545
# 173       NaN      0.1500     0.2400       0.2364     0.2174        0.3846
# 164       NaN      0.5000     0.3000       0.1724     0.2326        0.2500
# 142       NaN      0.2222     0.2400       0.2308     0.2424           NaN
# 89        NaN      0.0769     0.1628       0.2973     0.2000        0.4000
# 167       NaN      0.1500     0.2051       0.2174     0.1867        0.4000
# 63        NaN         NaN     0.2667       0.1250     0.2000           NaN
# 75        NaN      0.1000     0.2308       0.1250     0.1774           NaN
# 104       NaN      0.0870     0.2273       0.1364     0.1471        0.3000
# 131       NaN      0.2083     0.0455       0.3333     0.1429           NaN
# 145       NaN      0.1739     0.1860       0.1552     0.1648        0.2000
# 69        NaN      0.1111     0.1304       0.2000     0.1471           NaN
# 83     0.1290      0.2143     0.1190       0.1944     0.1500        0.1667
# 113       NaN      0.0000     0.1613       0.1364     0.1458           NaN
# 176       NaN      0.1220     0.1481       0.1481     0.1556           NaN
# 110       NaN      0.0769     0.0909       0.1905     0.1000        0.2308
# 57        NaN      0.0732     0.0714       0.1786     0.1489           NaN
# 134       NaN      0.1765     0.1154       0.1034     0.0851           NaN
# 98        NaN      0.0909     0.1429          NaN     0.1111           NaN
# 51        NaN      0.1000     0.1071       0.0476     0.0638           NaN
# 179       NaN      0.0000     0.0000       0.1379     0.0741        0.0000

# %%
Reading.query('Grade==5').sort_values(by=['Prof'], ascending=False)
# Out:
#                                    School    Num  Grade    Prof  White_Prof  \
# 87    L'Etoile Du Nord French Immersion U  462.0    5.0  0.8625      0.9000
# 162           Randolph Heights Elementary  545.0    5.0  0.8507      0.9000
# 108   Jie Ming Mandarin Immersion Academy  483.0    5.0  0.8095         NaN
# 140                    Horace Mann School  518.0    5.0  0.8077      0.8824
# 126             Capitol Hill Magnet/Rondo  494.0    5.0  0.7095      0.9153
# 171           St. Anthony Park Elementary  557.0    5.0  0.6901      0.9512
# 153       Nokomis Montessori North Campus  533.0    5.0  0.6667      0.7692
# 102             Groveland Park Elementary  476.0    5.0  0.6625      0.7750
# 193                             State_All    0.0    5.0  0.6577      0.7492
# 73     Expo For Excellence Elementary Sch  435.0    5.0  0.6346      0.8246
# 61             Chelsea Heights Elementary  425.0    5.0  0.5867      0.6765
# 120              Highland Park Elementary  491.0    5.0  0.5556      0.9000
# 123                    Jj Hill Montessori  493.0    5.0  0.5510      0.7143
# 186                     Mpls_District_All    0.0    5.0  0.5335      0.8656
# 49                Adams Magnet Elementary  410.0    5.0  0.5258      0.7917
# 55         Battle Creek Elementary School  422.0    5.0  0.5077         NaN
# 31             Farnsworth Aerospace Upper  315.0    5.0  0.5000         NaN
# 156       Nokomis Montessori South Campus  534.0    5.0  0.4865         NaN
# 67                   Como Park Elementary  431.0    5.0  0.4861      0.6667
# 105             Hamline Elementary School  482.0    5.0  0.4773         NaN
# 2                         Sp_District_All    0.0    5.0  0.4658      0.7725
# 93                  Crossroads Montessori  465.0    5.0  0.4643         NaN
# 146  Mississippi Creative Arts Elementary  527.0    5.0  0.4430         NaN
# 132             Highwood Hills Elementary  496.0    5.0  0.4167         NaN
# 159      Phalen Lake Hmong Studies Magnet  541.0    5.0  0.4124         NaN
# 111          The Heights Community School  488.0    5.0  0.3857         NaN
# 174              Saint Paul Music Academy  558.0    5.0  0.3727         NaN
# 135        Jackson Preparatory Elementary  500.0    5.0  0.3725         NaN
# 147        Linwood Monroe Arts Plus Upper  528.0    5.0  0.3659      0.6875
# 168    Paul & Sheila Wellstone Elementary  552.0    5.0  0.3548         NaN
# 96             Crossroads Science Program  466.0    5.0  0.3529         NaN
# 76               Bruce F Vento Elementary  449.0    5.0  0.3494         NaN
# 79             Eastern Heights Elementary  452.0    5.0  0.3333         NaN
# 64     Cherokee Heights Elementary School  428.0    5.0  0.3333         NaN
# 90           Frost Lake Elementary School  464.0    5.0  0.3291         NaN
# 52   John A. Johnson Achievement Plus El.  415.0    5.0  0.3077         NaN
# 58                 Benjamin E Mays Magnet  424.0    5.0  0.2879         NaN
# 99              Galtier Elementary School  467.0    5.0  0.2727         NaN
# 143            Maxfield Elementary School  524.0    5.0  0.2381         NaN
# 70               Daytons Bluff Elementary  433.0    5.0  0.2041         NaN
# 114        Hazel Park Preparatory Academy  489.0    5.0  0.1887         NaN
# 180         American Indian Magnet School  579.0    5.0  0.1791         NaN
# 165   Riverview West School Of Excellence  551.0    5.0  0.1765         NaN
# 177     Obama Service Learning Elementary  578.0    5.0  0.1739         NaN
# 84                Four Seasons Elementary  460.0    5.0  0.1733         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 87     0.8250      0.9333     0.9259       0.8302     0.7500        0.9107
# 162    0.7778         NaN     0.8710       0.8333     0.6667        0.9348
# 108       NaN         NaN        NaN       0.7692        NaN        0.9286
# 140    0.6667      0.5000     0.7778       0.8485     0.5000        0.9000
# 126    0.5730      0.5000     0.6571       0.7564     0.5522        0.8395
# 171    0.3333      0.3077     0.5625       0.7949     0.3750        0.8511
# 153    0.6154         NaN     0.6667       0.6667     0.4444        0.8571
# 102    0.5500      0.4286     0.5610       0.7692     0.4444        0.8409
# 193    0.4919      0.4179     0.6263       0.6903     0.4741        0.7798
# 73     0.4043      0.2400     0.6066       0.6744     0.2857        0.8116
# 61     0.5122      0.5000     0.5116       0.6875     0.4324        0.7368
# 120    0.4231      0.3714     0.5000       0.6250     0.4000        0.8148
# 123    0.4286      0.2000     0.4815       0.6364     0.2727        0.7778
# 186    0.3370      0.3016     0.4944       0.5701     0.3251        0.8199
# 49     0.4384      0.2667     0.4348       0.6078     0.2553        0.7800
# 55        NaN      0.4211     0.4651       0.5909     0.4667        0.6000
# 31        NaN      0.4118     0.4444       0.5577     0.4819        0.5652
# 156       NaN         NaN     0.4500       0.5294     0.2778        0.6842
# 67     0.4386      0.4286     0.4412       0.5263     0.4182        0.7059
# 105       NaN      0.3200     0.4167       0.5500     0.3667        0.7143
# 2      0.3833      0.3072     0.4259       0.5066     0.3407        0.7223
# 93        NaN         NaN     0.2000       0.7692     0.2857        0.6429
# 146       NaN      0.4762     0.4286       0.4545     0.4412        0.4545
# 132       NaN      0.4737     0.3125       0.5000     0.4118           NaN
# 159       NaN         NaN     0.3409       0.4717     0.4024        0.4667
# 111       NaN      0.1111     0.2927       0.5172     0.4043        0.3478
# 174       NaN      0.3077     0.3556       0.3846     0.3627           NaN
# 135       NaN      0.2500     0.3077       0.4400     0.3111           NaN
# 147    0.2879      0.1481     0.2927       0.4390     0.2712        0.6087
# 168       NaN      0.3333     0.4630       0.2051     0.3117        0.5625
# 96        NaN      0.1154     0.3333       0.3750     0.2791           NaN
# 76        NaN      0.3846     0.3125       0.4000     0.3462           NaN
# 79        NaN         NaN     0.3462       0.3200     0.1795        0.8333
# 64        NaN         NaN     0.3846       0.2857     0.3478           NaN
# 90        NaN      0.2800     0.2564       0.4000     0.3485        0.2308
# 52        NaN      0.2941     0.2692       0.3462     0.3043           NaN
# 58        NaN      0.2667     0.2791       0.3043     0.2593        0.4167
# 99        NaN      0.4000        NaN       0.2308     0.1176           NaN
# 143       NaN      0.2188     0.2000       0.2593     0.2424           NaN
# 70        NaN      0.1154     0.1667       0.2632     0.1860           NaN
# 114       NaN      0.1538     0.2222       0.1538     0.1961           NaN
# 180       NaN      0.0000     0.1250       0.2286     0.1613           NaN
# 165       NaN      0.1538     0.1905       0.1667     0.1622        0.2143
# 177       NaN      0.1875     0.2174       0.1304     0.1818           NaN
# 84        NaN      0.1622     0.1290       0.2045     0.1475        0.2857

# %% [markdown]
# #### Math Data [Grade 3 to 5]

# %%
Math.query('Grade==3').sort_values(by=['Prof'], ascending=False)
# Out:
#                                    School    Num  Grade    Prof  White_Prof  \
# 106   Jie Ming Mandarin Immersion Academy  483.0    3.0  0.9032         NaN
# 138                    Horace Mann School  518.0    3.0  0.8421      0.9070
# 160           Randolph Heights Elementary  545.0    3.0  0.8333      0.9615
# 124             Capitol Hill Magnet/Rondo  494.0    3.0  0.8000      0.9298
# 169           St. Anthony Park Elementary  557.0    3.0  0.6627      0.7778
# 191                             State_All    0.0    3.0  0.6560      0.7612
# 71     Expo For Excellence Elementary Sch  435.0    3.0  0.6346      0.8000
# 85    L'Etoile Du Nord French Immersion U  462.0    3.0  0.6230      0.7857
# 59             Chelsea Heights Elementary  425.0    3.0  0.5946      0.7500
# 100             Groveland Park Elementary  476.0    3.0  0.5741      0.7692
# 47                Adams Magnet Elementary  410.0    3.0  0.5357      0.9231
# 184                     Mpls_District_All    0.0    3.0  0.5181      0.8195
# 103             Hamline Elementary School  482.0    3.0  0.4444         NaN
# 91                  Crossroads Montessori  465.0    3.0  0.4333         NaN
# 157      Phalen Lake Hmong Studies Magnet  541.0    3.0  0.4286         NaN
# 0                         Sp_District_All    0.0    3.0  0.3966      0.7251
# 136        Linwood Monroe Arts Plus Lower  510.0    3.0  0.3924      0.5600
# 94             Crossroads Science Program  466.0    3.0  0.3810         NaN
# 53         Battle Creek Elementary School  422.0    3.0  0.3788      0.3000
# 118              Highland Park Elementary  491.0    3.0  0.3731      0.7143
# 80             Farnsworth Aerospace Lower  458.0    3.0  0.3636         NaN
# 121                    Jj Hill Montessori  493.0    3.0  0.3519      0.4800
# 109          The Heights Community School  488.0    3.0  0.3492         NaN
# 97              Galtier Elementary School  467.0    3.0  0.3462         NaN
# 112        Hazel Park Preparatory Academy  489.0    3.0  0.3333         NaN
# 172              Saint Paul Music Academy  558.0    3.0  0.3118         NaN
# 65                   Como Park Elementary  431.0    3.0  0.2769         NaN
# 133        Jackson Preparatory Elementary  500.0    3.0  0.2683         NaN
# 151       Nokomis Montessori North Campus  533.0    3.0  0.2653      0.4000
# 56                 Benjamin E Mays Magnet  424.0    3.0  0.2586         NaN
# 175     Obama Service Learning Elementary  578.0    3.0  0.2581         NaN
# 74               Bruce F Vento Elementary  449.0    3.0  0.2466         NaN
# 154       Nokomis Montessori South Campus  534.0    3.0  0.2308      0.4000
# 144  Mississippi Creative Arts Elementary  527.0    3.0  0.2283         NaN
# 88           Frost Lake Elementary School  464.0    3.0  0.2250         NaN
# 166    Paul & Sheila Wellstone Elementary  552.0    3.0  0.2169         NaN
# 62     Cherokee Heights Elementary School  428.0    3.0  0.2059         NaN
# 68               Daytons Bluff Elementary  433.0    3.0  0.2041         NaN
# 141            Maxfield Elementary School  524.0    3.0  0.1818         NaN
# 77             Eastern Heights Elementary  452.0    3.0  0.1667         NaN
# 50   John A. Johnson Achievement Plus El.  415.0    3.0  0.1636         NaN
# 82                Four Seasons Elementary  460.0    3.0  0.1528         NaN
# 163   Riverview West School Of Excellence  551.0    3.0  0.1250         NaN
# 178         American Indian Magnet School  579.0    3.0  0.1159         NaN
# 130             Highwood Hills Elementary  496.0    3.0  0.1081         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 106       NaN         NaN     0.8462       0.9444        NaN        0.9259
# 138    0.6429         NaN     0.7727       0.8857        NaN        0.9000
# 160    0.5769      0.4167     0.7500       0.9048     0.5926        0.9608
# 124    0.7051      0.6538     0.8529       0.7463     0.6818        0.8571
# 169    0.5263         NaN     0.7073       0.6190     0.4091        0.7541
# 191    0.4680      0.3849     0.6796       0.6314     0.4518        0.7905
# 71     0.4091      0.3462     0.7288       0.5111     0.2424        0.8169
# 85     0.4848      0.6923     0.6957       0.5789     0.4286        0.6809
# 59     0.4118      0.5000     0.6667       0.5366     0.4688        0.6905
# 100    0.3929      0.1667     0.6923       0.5366     0.3200        0.7931
# 47     0.3621      0.0909     0.5610       0.5116     0.2308        0.8000
# 184    0.3329      0.2849     0.5326       0.5028     0.2980        0.7967
# 103       NaN      0.3333     0.4783       0.4091     0.4333        0.4667
# 91        NaN         NaN     0.4706       0.3846     0.2778        0.6667
# 157       NaN         NaN     0.4118       0.4468     0.4286        0.4286
# 0      0.3021      0.2486     0.4268       0.3664     0.2625        0.6425
# 136    0.3148      0.2500     0.4000       0.3864     0.2264        0.7308
# 94        NaN      0.2609     0.5333       0.2963     0.3667        0.4167
# 53     0.3929      0.4074     0.4412       0.3125     0.3750        0.4000
# 118    0.2830      0.2571     0.4118       0.3333     0.2222        0.6818
# 80        NaN      0.5000     0.4032       0.2973     0.3194        0.4815
# 121    0.2414      0.0667     0.3200       0.3793     0.0455        0.5625
# 109       NaN      0.2632     0.3714       0.3214     0.2609        0.5882
# 97        NaN         NaN     0.3077       0.3846     0.2353           NaN
# 112       NaN      0.2609     0.4500       0.2400     0.3250           NaN
# 172       NaN      0.4091     0.3696       0.2553     0.3012        0.4000
# 65        NaN      0.2000     0.3529       0.1935     0.2364        0.5000
# 133       NaN         NaN     0.3810       0.1500     0.2286           NaN
# 151    0.2059         NaN     0.3448       0.1500     0.2813        0.2353
# 56        NaN      0.2222     0.2000       0.3214     0.2245           NaN
# 175       NaN      0.1667     0.2500       0.2667     0.2692           NaN
# 74        NaN      0.2500     0.2857       0.2105     0.2537           NaN
# 154    0.1724         NaN     0.3182       0.1176     0.0500        0.4211
# 144       NaN      0.1579     0.3061       0.1395     0.2099        0.3636
# 88        NaN      0.3182     0.2432       0.2093     0.1875        0.3750
# 166       NaN      0.1000     0.2250       0.2093     0.1449        0.5714
# 62        NaN         NaN     0.2222       0.1875     0.2222           NaN
# 68        NaN      0.1579     0.2759       0.1000     0.2000           NaN
# 141       NaN      0.0769     0.2778       0.1154     0.1944           NaN
# 77        NaN      0.0714     0.1923       0.1250     0.1613        0.1818
# 50        NaN      0.1000     0.3500       0.0571     0.1739           NaN
# 82        NaN      0.1379     0.1842       0.1176     0.1186        0.3077
# 163       NaN      0.0714     0.1333       0.1154     0.1304        0.1000
# 178       NaN         NaN     0.1951       0.0000     0.0926        0.2000
# 130       NaN      0.0588     0.1429       0.0625     0.1000           NaN

# %%
Math.query('Grade==4').sort_values(by=['Prof'], ascending=False)
# Out:
#                                    School    Num  Grade    Prof  White_Prof  \
# 107   Jie Ming Mandarin Immersion Academy  483.0    4.0  1.0000         NaN
# 125             Capitol Hill Magnet/Rondo  494.0    4.0  0.8156      0.9623
# 139                    Horace Mann School  518.0    4.0  0.7869      0.9000
# 161           Randolph Heights Elementary  545.0    4.0  0.7826      0.8889
# 170           St. Anthony Park Elementary  557.0    4.0  0.7647      0.8448
# 72     Expo For Excellence Elementary Sch  435.0    4.0  0.7009      0.8824
# 192                             State_All    0.0    4.0  0.6387      0.7465
# 86    L'Etoile Du Nord French Immersion U  462.0    4.0  0.6000      0.8571
# 95             Crossroads Science Program  466.0    4.0  0.5882         NaN
# 101             Groveland Park Elementary  476.0    4.0  0.5370      0.7222
# 66                   Como Park Elementary  431.0    4.0  0.5067         NaN
# 60             Chelsea Heights Elementary  425.0    4.0  0.4930      0.7143
# 185                     Mpls_District_All    0.0    4.0  0.4820      0.8122
# 54         Battle Creek Elementary School  422.0    4.0  0.4521         NaN
# 119              Highland Park Elementary  491.0    4.0  0.4310      0.7895
# 48                Adams Magnet Elementary  410.0    4.0  0.4167      0.6842
# 122                    Jj Hill Montessori  493.0    4.0  0.4118      0.5185
# 173              Saint Paul Music Academy  558.0    4.0  0.4095         NaN
# 1                         Sp_District_All    0.0    4.0  0.3903      0.7227
# 158      Phalen Lake Hmong Studies Magnet  541.0    4.0  0.3696         NaN
# 131             Highwood Hills Elementary  496.0    4.0  0.3659         NaN
# 81             Farnsworth Aerospace Lower  458.0    4.0  0.3611         NaN
# 155       Nokomis Montessori South Campus  534.0    4.0  0.3590         NaN
# 152       Nokomis Montessori North Campus  533.0    4.0  0.3333      0.7000
# 78             Eastern Heights Elementary  452.0    4.0  0.2979         NaN
# 137        Linwood Monroe Arts Plus Lower  510.0    4.0  0.2692      0.6000
# 89           Frost Lake Elementary School  464.0    4.0  0.2625         NaN
# 92                  Crossroads Montessori  465.0    4.0  0.2593         NaN
# 104             Hamline Elementary School  482.0    4.0  0.2500         NaN
# 75               Bruce F Vento Elementary  449.0    4.0  0.2464         NaN
# 113        Hazel Park Preparatory Academy  489.0    4.0  0.2453         NaN
# 145  Mississippi Creative Arts Elementary  527.0    4.0  0.2157         NaN
# 69               Daytons Bluff Elementary  433.0    4.0  0.2093         NaN
# 110          The Heights Community School  488.0    4.0  0.2069         NaN
# 167    Paul & Sheila Wellstone Elementary  552.0    4.0  0.1905         NaN
# 57                 Benjamin E Mays Magnet  424.0    4.0  0.1852         NaN
# 83                Four Seasons Elementary  460.0    4.0  0.1667      0.3125
# 142            Maxfield Elementary School  524.0    4.0  0.1579         NaN
# 164   Riverview West School Of Excellence  551.0    4.0  0.1552         NaN
# 176     Obama Service Learning Elementary  578.0    4.0  0.1481         NaN
# 134        Jackson Preparatory Elementary  500.0    4.0  0.1273         NaN
# 51   John A. Johnson Achievement Plus El.  415.0    4.0  0.1200         NaN
# 98              Galtier Elementary School  467.0    4.0  0.0870         NaN
# 179         American Indian Magnet School  579.0    4.0  0.0758         NaN
# 63     Cherokee Heights Elementary School  428.0    4.0  0.0667         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 107       NaN         NaN     1.0000       1.0000        NaN        1.0000
# 125    0.7273      0.8636     0.8406       0.7917     0.7119        0.8902
# 139    0.5714         NaN     0.7429       0.8462     0.4615        0.8750
# 161    0.5833         NaN     0.7949       0.7667     0.3500        0.9592
# 170    0.5926         NaN     0.8095       0.7209     0.4375        0.8406
# 72     0.5357      0.4667     0.6964       0.7059     0.5000        0.8644
# 192    0.4492      0.3499     0.6530       0.6235     0.4323        0.7762
# 86     0.2400      0.2857     0.5385       0.6471     0.3500        0.7250
# 95        NaN      0.6316     0.6774       0.4500     0.5556        0.6667
# 101    0.4444      0.3913     0.5294       0.5500     0.3939        0.7619
# 66        NaN      0.3077     0.4545       0.5806     0.4426        0.7857
# 60     0.3488      0.3889     0.4595       0.5294     0.4000        0.6129
# 185    0.3032      0.2585     0.5102       0.4506     0.2705        0.7737
# 54        NaN      0.3000     0.5517       0.3864     0.4259        0.5263
# 119    0.2564      0.2083     0.4783       0.4000     0.2059        0.7500
# 48     0.3385         NaN     0.5000       0.3478     0.3111        0.5385
# 122    0.2917      0.1000     0.3667       0.4762     0.1667        0.4872
# 173       NaN      0.2500     0.3600       0.4545     0.4130        0.3846
# 1      0.3046      0.2259     0.3993       0.3804     0.2790        0.6229
# 158       NaN         NaN     0.4151       0.3077     0.3846        0.2857
# 131       NaN      0.4167     0.3636       0.3684     0.3333           NaN
# 81        NaN      0.2000     0.3934       0.3191     0.3544        0.3793
# 155       NaN         NaN     0.3043       0.4375     0.3200        0.4286
# 152    0.2286         NaN     0.2632       0.3846     0.2069        0.5625
# 78        NaN         NaN     0.4000       0.1818     0.2500        0.4545
# 137    0.1132      0.1579     0.2766       0.2581     0.1071        0.6818
# 89        NaN      0.0000     0.2791       0.2432     0.2286        0.5000
# 92        NaN         NaN     0.3000       0.2353     0.2857           NaN
# 104       NaN      0.1739     0.3636       0.1364     0.1765        0.5000
# 75        NaN      0.1111     0.2703       0.2188     0.2333           NaN
# 113       NaN      0.0417     0.3226       0.1364     0.2500           NaN
# 145       NaN      0.1304     0.2273       0.2069     0.2308        0.0909
# 69        NaN      0.1111     0.1739       0.2500     0.2059           NaN
# 110       NaN      0.0741     0.2000       0.2143     0.1311        0.3846
# 167       NaN      0.1053     0.2821       0.1111     0.1757        0.3000
# 57        NaN      0.1538     0.1111       0.2593     0.1778           NaN
# 83     0.1290      0.1786     0.0714       0.2778     0.1667        0.1667
# 142       NaN      0.1481     0.2000       0.0769     0.1515           NaN
# 164       NaN      0.2000     0.1333       0.1786     0.1429        0.1875
# 176       NaN      0.1220     0.1481       0.1481     0.1556           NaN
# 134       NaN      0.1176     0.2692       0.0000     0.0851           NaN
# 51        NaN      0.0500     0.1379       0.0952     0.1250           NaN
# 98        NaN      0.0909     0.0714          NaN     0.1111           NaN
# 179       NaN      0.0000     0.1081       0.0345     0.0926        0.0000
# 63        NaN         NaN     0.0667       0.0667     0.0400           NaN

# %%
Math.query('Grade==5').sort_values(by=['Prof'], ascending=False)
# Out:
#                                    School    Num  Grade    Prof  White_Prof  \
# 108   Jie Ming Mandarin Immersion Academy  483.0    5.0  0.8571         NaN
# 87    L'Etoile Du Nord French Immersion U  462.0    5.0  0.7125      0.8250
# 162           Randolph Heights Elementary  545.0    5.0  0.6418      0.7250
# 140                    Horace Mann School  518.0    5.0  0.5769      0.6667
# 171           St. Anthony Park Elementary  557.0    5.0  0.5634      0.7805
# 126             Capitol Hill Magnet/Rondo  494.0    5.0  0.5238      0.7458
# 193                             State_All    0.0    5.0  0.5204      0.6158
# 102             Groveland Park Elementary  476.0    5.0  0.5125      0.7000
# 73     Expo For Excellence Elementary Sch  435.0    5.0  0.4954      0.6230
# 61             Chelsea Heights Elementary  425.0    5.0  0.4933      0.5000
# 55         Battle Creek Elementary School  422.0    5.0  0.4848         NaN
# 67                   Como Park Elementary  431.0    5.0  0.4366      0.7857
# 186                     Mpls_District_All    0.0    5.0  0.4030      0.7466
# 31             Farnsworth Aerospace Upper  315.0    5.0  0.3458         NaN
# 159      Phalen Lake Hmong Studies Magnet  541.0    5.0  0.3367         NaN
# 153       Nokomis Montessori North Campus  533.0    5.0  0.3333      0.4615
# 174              Saint Paul Music Academy  558.0    5.0  0.3273         NaN
# 120              Highland Park Elementary  491.0    5.0  0.3194      0.7500
# 2                         Sp_District_All    0.0    5.0  0.3127      0.6074
# 146  Mississippi Creative Arts Elementary  527.0    5.0  0.3038         NaN
# 76               Bruce F Vento Elementary  449.0    5.0  0.2771         NaN
# 49                Adams Magnet Elementary  410.0    5.0  0.2653      0.5000
# 96             Crossroads Science Program  466.0    5.0  0.2549         NaN
# 147        Linwood Monroe Arts Plus Upper  528.0    5.0  0.2289      0.4375
# 64     Cherokee Heights Elementary School  428.0    5.0  0.2222         NaN
# 90           Frost Lake Elementary School  464.0    5.0  0.2179         NaN
# 111          The Heights Community School  488.0    5.0  0.2000         NaN
# 123                    Jj Hill Montessori  493.0    5.0  0.1837      0.4000
# 168    Paul & Sheila Wellstone Elementary  552.0    5.0  0.1789         NaN
# 79             Eastern Heights Elementary  452.0    5.0  0.1765         NaN
# 156       Nokomis Montessori South Campus  534.0    5.0  0.1622         NaN
# 135        Jackson Preparatory Elementary  500.0    5.0  0.1569         NaN
# 105             Hamline Elementary School  482.0    5.0  0.1556         NaN
# 93                  Crossroads Montessori  465.0    5.0  0.1429         NaN
# 132             Highwood Hills Elementary  496.0    5.0  0.1389         NaN
# 84                Four Seasons Elementary  460.0    5.0  0.1333         NaN
# 52   John A. Johnson Achievement Plus El.  415.0    5.0  0.1321         NaN
# 70               Daytons Bluff Elementary  433.0    5.0  0.1250         NaN
# 143            Maxfield Elementary School  524.0    5.0  0.0952         NaN
# 180         American Indian Magnet School  579.0    5.0  0.0746         NaN
# 177     Obama Service Learning Elementary  578.0    5.0  0.0652         NaN
# 58                 Benjamin E Mays Magnet  424.0    5.0  0.0635         NaN
# 165   Riverview West School Of Excellence  551.0    5.0  0.0612         NaN
# 114        Hazel Park Preparatory Academy  489.0    5.0  0.0377         NaN
# 99              Galtier Elementary School  467.0    5.0  0.0000         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 108       NaN         NaN        NaN       0.8462        NaN        0.9286
# 87     0.6000      0.7333     0.7407       0.6981     0.4583        0.8214
# 162    0.5185         NaN     0.6774       0.6111     0.5238        0.6957
# 140    0.4074      0.2000     0.6000       0.5455     0.2222        0.6833
# 171    0.2667      0.3077     0.5625       0.5641     0.3750        0.6596
# 126    0.3750      0.1613     0.5072       0.5385     0.3030        0.7037
# 193    0.3475      0.2580     0.5297       0.5107     0.3206        0.6532
# 102    0.3250      0.2381     0.4634       0.5641     0.3056        0.6818
# 73     0.3333      0.3077     0.4769       0.5227     0.2162        0.6389
# 61     0.4878      0.3750     0.4884       0.5000     0.3243        0.6579
# 55        NaN      0.3684     0.4651       0.5217     0.4348        0.6000
# 67     0.3509      0.2308     0.3529       0.5135     0.3704        0.6471
# 186    0.1979      0.1530     0.4108       0.3956     0.1812        0.7047
# 31        NaN      0.1667     0.4000       0.2885     0.3452        0.3478
# 159       NaN         NaN     0.3864       0.2963     0.3012        0.5333
# 153    0.2692         NaN     0.3333       0.3333     0.1667        0.4762
# 174       NaN      0.1538     0.3333       0.3231     0.3039           NaN
# 120    0.1538      0.1143     0.2750       0.3750     0.1111        0.6667
# 2      0.2332      0.1432     0.3153       0.3100     0.2070        0.5296
# 146       NaN      0.2381     0.3429       0.2727     0.2794        0.4545
# 76        NaN      0.2308     0.2708       0.2857     0.2692           NaN
# 49     0.1892      0.0000     0.2340       0.2941     0.1250        0.4000
# 96        NaN      0.2000     0.2500       0.2609     0.2045           NaN
# 147    0.1791      0.1481     0.2381       0.2195     0.1500        0.4348
# 64        NaN         NaN     0.3077       0.1429     0.2609           NaN
# 90        NaN      0.2000     0.2368       0.2000     0.2154        0.2308
# 111       NaN      0.0000     0.1707       0.2414     0.2128        0.1739
# 123    0.0345      0.0000     0.2222       0.1364     0.0000        0.3462
# 168       NaN      0.0714     0.2545       0.0750     0.1519        0.3125
# 79        NaN         NaN     0.2308       0.1200     0.1282        0.3333
# 156       NaN         NaN     0.1500       0.1765     0.0000        0.3158
# 135       NaN      0.0000     0.1923       0.1200     0.1111           NaN
# 105       NaN      0.1200     0.1600       0.1500     0.0968        0.2857
# 93        NaN         NaN     0.0667       0.2308     0.0714        0.2143
# 132       NaN      0.1053     0.1875       0.1000     0.1176           NaN
# 84        NaN      0.0811     0.1613       0.1136     0.1148        0.2143
# 52        NaN      0.1667     0.0769       0.1852     0.1489           NaN
# 70        NaN      0.0385     0.1379       0.1053     0.1190           NaN
# 143       NaN      0.0625     0.0667       0.1111     0.0909           NaN
# 180       NaN      0.0000     0.1250       0.0286     0.0806           NaN
# 177       NaN      0.0313     0.0870       0.0435     0.0682           NaN
# 58        NaN      0.0238     0.0714       0.0476     0.0588        0.0833
# 165       NaN      0.0833     0.1500       0.0000     0.0857        0.0000
# 114       NaN      0.0000     0.0370       0.0385     0.0392           NaN
# 99        NaN      0.0000        NaN       0.0000     0.0000           NaN

# %% [markdown]
# #### Science Data

# %%
Science.query('Grade=="5"').sort_values(by=['Prof'], ascending=False)
# Out:
#                                   School    Num Grade    Prof  White_Prof  \
# 42   Jie Ming Mandarin Immersion Academy  483.0     5  0.8571         NaN
# 60           Randolph Heights Elementary  545.0     5  0.6567      0.7500
# 52                    Horace Mann School  518.0     5  0.6410      0.7255
# 63           St. Anthony Park Elementary  557.0     5  0.6286      0.9250
# 48             Capitol Hill Magnet/Rondo  494.0     5  0.6216      0.9153
# 35   L'Etoile Du Nord French Immersion U  462.0     5  0.5875      0.7250
# 40             Groveland Park Elementary  476.0     5  0.5500      0.7000
# 71                             State_All    0.0     5  0.5490      0.6639
# 27            Chelsea Heights Elementary  425.0     5  0.5467      0.6471
# 31    Expo For Excellence Elementary Sch  435.0     5  0.5421      0.6885
# 25        Battle Creek Elementary School  422.0     5  0.4154         NaN
# 68                     Mpls_District_All    0.0     5  0.4083      0.7759
# 57       Nokomis Montessori North Campus  533.0     5  0.3684      0.6154
# 23               Adams Magnet Elementary  410.0     5  0.3402      0.5833
# 47                    Jj Hill Montessori  493.0     5  0.3261      0.6000
# 17            Farnsworth Aerospace Upper  315.0     5  0.3178         NaN
# 46              Highland Park Elementary  491.0     5  0.3056      0.6500
# 0                        Sp_District_All    0.0     5  0.2982      0.6559
# 58       Nokomis Montessori South Campus  534.0     5  0.2973         NaN
# 37                 Crossroads Montessori  465.0     5  0.2759         NaN
# 29                  Como Park Elementary  431.0     5  0.2394      0.5000
# 51        Jackson Preparatory Elementary  500.0     5  0.2157         NaN
# 41             Hamline Elementary School  482.0     5  0.2045         NaN
# 38            Crossroads Science Program  466.0     5  0.2041         NaN
# 33            Eastern Heights Elementary  452.0     5  0.2000         NaN
# 54  Mississippi Creative Arts Elementary  527.0     5  0.1899         NaN
# 24  John A. Johnson Achievement Plus El.  415.0     5  0.1852         NaN
# 62    Paul & Sheila Wellstone Elementary  552.0     5  0.1809         NaN
# 55        Linwood Monroe Arts Plus Upper  528.0     5  0.1807      0.4375
# 59      Phalen Lake Hmong Studies Magnet  541.0     5  0.1753         NaN
# 36          Frost Lake Elementary School  464.0     5  0.1646         NaN
# 28    Cherokee Heights Elementary School  428.0     5  0.1481         NaN
# 32              Bruce F Vento Elementary  449.0     5  0.1446         NaN
# 44        Hazel Park Preparatory Academy  489.0     5  0.1346         NaN
# 64              Saint Paul Music Academy  558.0     5  0.1182         NaN
# 50             Highwood Hills Elementary  496.0     5  0.1111         NaN
# 34               Four Seasons Elementary  460.0     5  0.1067         NaN
# 30              Daytons Bluff Elementary  433.0     5  0.1064         NaN
# 43          The Heights Community School  488.0     5  0.1014         NaN
# 26                Benjamin E Mays Magnet  424.0     5  0.0923         NaN
# 61   Riverview West School Of Excellence  551.0     5  0.0800         NaN
# 53            Maxfield Elementary School  524.0     5  0.0750         NaN
# 66         American Indian Magnet School  579.0     5  0.0441         NaN
# 65     Obama Service Learning Elementary  578.0     5  0.0435         NaN
# 39             Galtier Elementary School  467.0     5  0.0000         NaN
#
#     POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 42       NaN         NaN        NaN       0.8462        NaN        0.9286
# 60    0.5185         NaN     0.6452       0.6667     0.4286        0.7609
# 52    0.4815      0.2000     0.7333       0.5152     0.2222        0.7667
# 63    0.2333      0.0769     0.5625       0.6842     0.2609        0.8085
# 48    0.4270      0.2813     0.6143       0.6282     0.4179        0.7901
# 35    0.4500      0.7333     0.5556       0.6038     0.3750        0.6786
# 40    0.4000      0.2857     0.4878       0.6154     0.3333        0.7273
# 71    0.3406      0.2426     0.5626       0.5348     0.3422        0.6862
# 27    0.4634      0.5000     0.5116       0.5938     0.3514        0.7368
# 31    0.3478      0.2800     0.5156       0.5814     0.2286        0.6944
# 25       NaN      0.3158     0.3721       0.5000     0.4000        0.4500
# 68    0.1885      0.1437     0.4193       0.3980     0.1810        0.7172
# 57    0.2400         NaN     0.3810       0.3529     0.2222        0.5000
# 23    0.2603      0.2000     0.3043       0.3725     0.1064        0.5600
# 47    0.1154      0.0000     0.3077       0.3500     0.0000        0.5769
# 17       NaN      0.2778     0.3636       0.2692     0.3095        0.3478
# 46    0.1731      0.1143     0.2750       0.3438     0.1111        0.6296
# 0     0.2018      0.1397     0.2962       0.3002     0.1713        0.5565
# 58       NaN         NaN     0.3000       0.2941     0.2778        0.3158
# 37       NaN         NaN     0.2500       0.3077     0.1429        0.4000
# 29    0.1754      0.3077     0.2059       0.2703     0.2037        0.3529
# 51       NaN      0.1250     0.2308       0.2000     0.1333           NaN
# 41       NaN      0.1200     0.2500       0.1500     0.1333        0.3571
# 38       NaN      0.0800     0.2143       0.1905     0.1429           NaN
# 33       NaN         NaN     0.2692       0.1250     0.1316        0.4167
# 54       NaN      0.1429     0.2286       0.1591     0.1618        0.3636
# 24       NaN      0.1667     0.1852       0.1852     0.1667           NaN
# 62       NaN      0.1538     0.2545       0.0769     0.1410        0.3750
# 55    0.1194      0.0000     0.1429       0.2195     0.0833        0.4348
# 59       NaN         NaN     0.1818       0.1698     0.1829        0.1333
# 36       NaN      0.0833     0.1795       0.1500     0.1667        0.1538
# 28       NaN         NaN     0.2308       0.0714     0.1739           NaN
# 32       NaN      0.1154     0.1042       0.2000     0.1282           NaN
# 44       NaN      0.1667     0.1481       0.1200     0.1400           NaN
# 64       NaN      0.0385     0.1556       0.0923     0.1176           NaN
# 50       NaN      0.0526     0.0625       0.1500     0.1176           NaN
# 34       NaN      0.0811     0.0645       0.1364     0.0656        0.2857
# 30       NaN      0.0400     0.1071       0.1053     0.1220           NaN
# 43       NaN      0.0000     0.0976       0.1071     0.1087        0.0870
# 26       NaN      0.0682     0.1163       0.0455     0.0566        0.2500
# 61       NaN      0.0769     0.0952       0.0690     0.0833        0.0714
# 53       NaN      0.0000     0.0000       0.1200     0.0968           NaN
# 66       NaN      0.0000     0.0606       0.0286     0.0476           NaN
# 65       NaN      0.0313     0.0435       0.0435     0.0455           NaN
# 39       NaN      0.0000        NaN       0.0000     0.0000           NaN

# %% [markdown]
# ## Intermediate Schools<a name="int"></a>
#
# #### Enroll Data

# %%
Enroll.query('Num in (330,342,345,344,315,310,211,225,250,252,489,494,528,579)').sort_values(by=['School'])
# Out:
#       Num                               School  Tot_Enroll  Male%  White%  \
# 59  579.0        American Indian Magnet School       642.0  51.56    5.14
# 10  310.0                  Battle Creek Middle       750.0  53.20    6.13
# 42  494.0            Capitol Hill Magnet/Rondo      1254.0  53.03   38.28
# 2   211.0       Creative Arts Secondary School       439.0  36.90   21.41
# 11  315.0           Farnsworth Aerospace Upper       643.0  54.28    5.13
# 39  489.0       Hazel Park Preparatory Academy       588.0  51.87    5.27
# 12  330.0          Highland Park Middle School       804.0  51.12   40.42
# 6   225.0                 Humboldt High School      1187.0  51.73    6.15
# 49  528.0       Linwood Monroe Arts Plus Upper       472.0  45.55   29.03
# 13  342.0                 Murray Middle School       712.0  52.25   34.13
# 8   250.0        Open World Learning Secondary       452.0  52.88   55.31
# 14  344.0  Parkway Montessori/Community Middle       450.0  50.89   14.22
# 15  345.0                 Ramsey Middle School       588.0  52.72   24.32
# 9   252.0     Washington Tech Secondary Magnet      2083.0  53.77    4.70
#
#     Black%  Asian%   FRPL%    ELL%   SPED% Homeless%
# 59   17.29   26.79  81.93%  28.50%  18.85%     3.74%
# 10   34.67   38.93  77.87%  31.33%  15.73%     2.40%
# 42   22.65   24.96  41.87%  10.53%   5.50%     0.32%
# 2    33.49   18.22  66.74%  12.07%  16.86%     3.19%
# 11   18.35   60.19  76.36%  32.35%  13.22%     1.71%
# 39   42.86   31.12  87.41%  24.49%  13.61%     4.42%
# 12   19.28    4.48  46.64%  10.20%  10.70%     0.62%
# 6    27.30   44.65  84.50%  47.94%  16.43%     2.27%
# 49   32.20   19.28  62.92%  28.81%  20.97%     1.27%
# 13   25.56   19.52  57.02%  17.13%  14.19%     1.12%
# 8     9.07   12.17  32.52%   7.52%  17.04%     0.44%
# 14   24.22   42.67  76.22%  22.67%  21.33%     1.78%
# 15   45.41   13.61  64.63%  10.88%  10.20%     3.74%
# 9    23.96   55.88  86.75%  36.44%  14.26%     0.82%

# %% [markdown]
# #### Reading Data [Grade 6 to 8]

# %%
Reading.query('Grade==6').sort_values(by=['Prof'], ascending=False)
# Out:
#                                   School    Num  Grade    Prof  White_Prof  \
# 127            Capitol Hill Magnet/Rondo  494.0    6.0  0.7136      0.8816
# 20         Open World Learning Secondary  250.0    6.0  0.6563      0.8056
# 194                            State_All    0.0    6.0  0.6281      0.7206
# 35           Highland Park Middle School  330.0    6.0  0.5630      0.8515
# 187                    Mpls_District_All    0.0    6.0  0.4833      0.8116
# 38                  Murray Middle School  342.0    6.0  0.4777      0.7324
# 148       Linwood Monroe Arts Plus Upper  528.0    6.0  0.4507      0.7222
# 8         Creative Arts Secondary School  211.0    6.0  0.4022      0.5625
# 44                  Ramsey Middle School  345.0    6.0  0.3939      0.7800
# 3                        Sp_District_All    0.0    6.0  0.3847      0.7359
# 41   Parkway Montessori/Community Middle  344.0    6.0  0.2789      0.4737
# 32            Farnsworth Aerospace Upper  315.0    6.0  0.2784         NaN
# 24      Washington Tech Secondary Magnet  252.0    6.0  0.2690      0.4118
# 15                  Humboldt High School  225.0    6.0  0.2422      0.3846
# 181        American Indian Magnet School  579.0    6.0  0.2286         NaN
# 28                   Battle Creek Middle  310.0    6.0  0.2249         NaN
# 115       Hazel Park Preparatory Academy  489.0    6.0  0.1553         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 127    0.6204      0.5741     0.7258       0.6966     0.5392        0.8739
# 20     0.4643         NaN     0.6216       0.7037     0.2778        0.8043
# 194    0.4581      0.3805     0.5949       0.6626     0.4376        0.7502
# 35     0.3905      0.5172     0.5481       0.5778     0.2960        0.7931
# 187    0.3143      0.2714     0.4432       0.5241     0.2920        0.7757
# 38     0.3595      0.2157     0.3945       0.5565     0.4015        0.5977
# 148    0.3585      0.2826     0.3939       0.5000     0.2903        0.7551
# 8      0.3684      0.3704     0.2647       0.4828     0.3378        0.6667
# 44     0.2635      0.1310     0.3368       0.4466     0.1789        0.7467
# 3      0.3013      0.2708     0.3539       0.4189     0.2689        0.6507
# 41     0.2500      0.2121     0.3165       0.2353     0.2455        0.3784
# 32        NaN      0.2500     0.2347       0.3333     0.2429        0.4167
# 24     0.2609      0.2410     0.2544       0.2857     0.2545        0.3659
# 15     0.2261      0.3226     0.2206       0.2667     0.2252        0.3529
# 181       NaN      0.0000     0.2162       0.2424     0.2143        0.2857
# 28        NaN      0.2391     0.2162       0.2376     0.2115        0.2927
# 115       NaN      0.1481     0.0909       0.2292     0.1413        0.2727

# %%
Reading.query('Grade==7').sort_values(by=['Prof'], ascending=False)
# Out:
#                                   School    Num  Grade    Prof  White_Prof  \
# 21         Open World Learning Secondary  250.0    7.0  0.6571      0.7949
# 128            Capitol Hill Magnet/Rondo  494.0    7.0  0.6502      0.8358
# 195                            State_All    0.0    7.0  0.5749      0.6578
# 36           Highland Park Middle School  330.0    7.0  0.5573      0.8037
# 188                    Mpls_District_All    0.0    7.0  0.4662      0.8007
# 39                  Murray Middle School  342.0    7.0  0.4526      0.8072
# 149       Linwood Monroe Arts Plus Upper  528.0    7.0  0.4077      0.7568
# 4                        Sp_District_All    0.0    7.0  0.3716      0.7137
# 25      Washington Tech Secondary Magnet  252.0    7.0  0.3271      0.3750
# 45                  Ramsey Middle School  345.0    7.0  0.3230      0.7250
# 33            Farnsworth Aerospace Upper  315.0    7.0  0.2965         NaN
# 29                   Battle Creek Middle  310.0    7.0  0.2661      0.5714
# 42   Parkway Montessori/Community Middle  344.0    7.0  0.2603      0.3158
# 9         Creative Arts Secondary School  211.0    7.0  0.2500      0.4167
# 16                  Humboldt High School  225.0    7.0  0.2133         NaN
# 116       Hazel Park Preparatory Academy  489.0    7.0  0.2062         NaN
# 182        American Indian Magnet School  579.0    7.0  0.1857         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 21     0.4839         NaN     0.5714       0.7429     0.3810        0.7755
# 128    0.5588      0.4667     0.6036       0.7065     0.4900        0.8058
# 195    0.4138      0.3201     0.5349       0.6170     0.3804        0.6913
# 36     0.3871      0.3265     0.5362       0.5806     0.3000        0.7746
# 188    0.2755      0.2086     0.4358       0.4962     0.2369        0.7735
# 39     0.2550      0.2143     0.4000       0.5089     0.2500        0.7200
# 149    0.2688      0.2391     0.3651       0.4478     0.2414        0.7442
# 4      0.2890      0.2188     0.3336       0.4129     0.2640        0.6129
# 25     0.3246      0.2447     0.2830       0.3704     0.3069        0.4545
# 45     0.1901      0.1358     0.2556       0.4085     0.1927        0.5962
# 33        NaN      0.2667     0.3107       0.2754     0.2756        0.3556
# 29     0.2479      0.1910     0.1933       0.3333     0.2350        0.3958
# 42     0.2520      0.0811     0.1750       0.3636     0.2743        0.2121
# 9      0.2237      0.1818     0.2424       0.2545     0.2174        0.3684
# 16        NaN      0.1714     0.1728       0.2609     0.2016        0.2857
# 116       NaN      0.0714     0.2143       0.1951     0.1905        0.3077
# 182       NaN      0.1667     0.2432       0.1212     0.1818        0.2000

# %%
Reading.query('Grade==8').sort_values(by=['Prof'], ascending=False)
# Out:
#                                   School    Num  Grade    Prof  White_Prof  \
# 129            Capitol Hill Magnet/Rondo  494.0    8.0  0.6832      0.8831
# 22         Open World Learning Secondary  250.0    8.0  0.6061      0.6970
# 196                            State_All    0.0    8.0  0.5771      0.6544
# 37           Highland Park Middle School  330.0    8.0  0.5579      0.8235
# 150       Linwood Monroe Arts Plus Upper  528.0    8.0  0.4914      0.7561
# 189                    Mpls_District_All    0.0    8.0  0.4534      0.7420
# 40                  Murray Middle School  342.0    8.0  0.4516      0.7674
# 46                  Ramsey Middle School  345.0    8.0  0.4419      0.7333
# 10        Creative Arts Secondary School  211.0    8.0  0.3922      0.7273
# 5                        Sp_District_All    0.0    8.0  0.3918      0.7479
# 43   Parkway Montessori/Community Middle  344.0    8.0  0.3538      0.7500
# 117       Hazel Park Preparatory Academy  489.0    8.0  0.3023         NaN
# 183        American Indian Magnet School  579.0    8.0  0.3000         NaN
# 34            Farnsworth Aerospace Upper  315.0    8.0  0.2866         NaN
# 30                   Battle Creek Middle  310.0    8.0  0.2735      0.5000
# 26      Washington Tech Secondary Magnet  252.0    8.0  0.2469      0.6250
# 17                  Humboldt High School  225.0    8.0  0.2240         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 129    0.5600      0.4912     0.6667       0.7021     0.5455        0.7895
# 22     0.5152      0.1818     0.6000       0.6190     0.4348        0.6977
# 196    0.4221      0.3308     0.5209       0.6357     0.3820        0.6877
# 37     0.3643      0.2558     0.4444       0.6810     0.3448        0.7540
# 150    0.3467      0.2432     0.4894       0.4928     0.3000        0.7826
# 189    0.2975      0.2285     0.4060       0.5045     0.2778        0.7059
# 40     0.2443      0.2308     0.4828       0.4158     0.2417        0.7113
# 46     0.3386      0.2537     0.3958       0.5000     0.3143        0.6418
# 10     0.3000      0.3125     0.4091       0.3793     0.2813        0.5789
# 5      0.2987      0.2288     0.3644       0.4213     0.2780        0.6347
# 43     0.2818      0.1600     0.2500       0.4429     0.3000        0.5333
# 117       NaN      0.1290     0.2750       0.3261     0.2703        0.5000
# 183       NaN         NaN     0.2857       0.3182     0.3256           NaN
# 34        NaN      0.1429     0.2530       0.3210     0.2326        0.4857
# 30     0.2613      0.1928     0.2677       0.2804     0.2571        0.3220
# 26     0.2273      0.1724     0.2381       0.2564     0.2180        0.4857
# 17        NaN      0.1579     0.1778       0.2688     0.2152        0.2800

# %% [markdown]
# #### Math Data [Grade 6 to 8]

# %%
Math.query('Grade==6').sort_values(by=['Prof'], ascending=False)
# Out:
#                                   School    Num  Grade    Prof  White_Prof  \
# 127            Capitol Hill Magnet/Rondo  494.0    6.0  0.5399      0.8553
# 194                            State_All    0.0    6.0  0.5048      0.6068
# 20         Open World Learning Secondary  250.0    6.0  0.4531      0.6944
# 35           Highland Park Middle School  330.0    6.0  0.3941      0.7129
# 187                    Mpls_District_All    0.0    6.0  0.3695      0.7087
# 148       Linwood Monroe Arts Plus Upper  528.0    6.0  0.3688      0.6111
# 38                  Murray Middle School  342.0    6.0  0.3516      0.6667
# 3                        Sp_District_All    0.0    6.0  0.2463      0.6075
# 24      Washington Tech Secondary Magnet  252.0    6.0  0.2152      0.4375
# 44                  Ramsey Middle School  345.0    6.0  0.2150      0.5000
# 32            Farnsworth Aerospace Upper  315.0    6.0  0.1534         NaN
# 15                  Humboldt High School  225.0    6.0  0.1364      0.1538
# 41   Parkway Montessori/Community Middle  344.0    6.0  0.1096      0.2632
# 181        American Indian Magnet School  579.0    6.0  0.1000         NaN
# 8         Creative Arts Secondary School  211.0    6.0  0.0879      0.0625
# 115       Hazel Park Preparatory Academy  489.0    6.0  0.0693         NaN
# 28                   Battle Creek Middle  310.0    6.0  0.0683         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 127    0.3650      0.2963     0.6452       0.3933     0.2941        0.7658
# 194    0.3172      0.2258     0.5174       0.4917     0.2878        0.6437
# 20     0.1429         NaN     0.4054       0.5185     0.0556        0.6087
# 35     0.2024      0.2281     0.3881       0.4000     0.1360        0.6181
# 187    0.1921      0.1420     0.3753       0.3636     0.1691        0.6752
# 148    0.2857      0.1957     0.3636       0.3733     0.2391        0.6122
# 38     0.2157      0.1176     0.3394       0.3636     0.2370        0.5357
# 3      0.1615      0.1168     0.2522       0.2396     0.1409        0.4897
# 24     0.2033      0.1446     0.2249       0.2041     0.2065        0.2750
# 44     0.1200      0.0238     0.1856       0.2427     0.0645        0.4605
# 32        NaN      0.1111     0.1327       0.1795     0.1071        0.3333
# 15     0.1345      0.0606     0.1143       0.1613     0.1391        0.1176
# 41     0.0866      0.0303     0.1392       0.0746     0.0818        0.1944
# 181       NaN      0.0000     0.1622       0.0303     0.0714        0.2143
# 8      0.0933      0.0385     0.1212       0.0690     0.0822        0.1111
# 115       NaN      0.0769     0.0189       0.1250     0.0556        0.1818
# 28        NaN      0.0870     0.0743       0.0594     0.0625        0.0976

# %%
Math.query('Grade==7').sort_values(by=['Prof'], ascending=False)
# Out:
#                                   School    Num  Grade    Prof  White_Prof  \
# 128            Capitol Hill Magnet/Rondo  494.0    7.0  0.6010      0.8955
# 195                            State_All    0.0    7.0  0.5206      0.6164
# 21         Open World Learning Secondary  250.0    7.0  0.5000      0.6667
# 188                    Mpls_District_All    0.0    7.0  0.4025      0.7637
# 36           Highland Park Middle School  330.0    7.0  0.3808      0.6792
# 149       Linwood Monroe Arts Plus Upper  528.0    7.0  0.3252      0.5946
# 39                  Murray Middle School  342.0    7.0  0.3030      0.5854
# 25      Washington Tech Secondary Magnet  252.0    7.0  0.2906      0.3125
# 4                        Sp_District_All    0.0    7.0  0.2737      0.5846
# 33            Farnsworth Aerospace Upper  315.0    7.0  0.2176         NaN
# 29                   Battle Creek Middle  310.0    7.0  0.2048      0.1538
# 45                  Ramsey Middle School  345.0    7.0  0.1914      0.5250
# 42   Parkway Montessori/Community Middle  344.0    7.0  0.1862      0.2632
# 16                  Humboldt High School  225.0    7.0  0.1656         NaN
# 9         Creative Arts Secondary School  211.0    7.0  0.0795      0.1667
# 116       Hazel Park Preparatory Academy  489.0    7.0  0.0632         NaN
# 182        American Indian Magnet School  579.0    7.0  0.0429         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 128    0.4559      0.3500     0.5856       0.6196     0.4000        0.7961
# 195    0.3343      0.2282     0.5212       0.5199     0.2950        0.6554
# 21     0.2903         NaN     0.4571       0.5429     0.3333        0.5714
# 188    0.1972      0.1208     0.4071       0.3979     0.1585        0.7298
# 36     0.1753      0.1458     0.3358       0.4309     0.1008        0.6170
# 149    0.2093      0.2000     0.3443       0.3065     0.1605        0.6429
# 39     0.1477      0.1017     0.2712       0.3363     0.1203        0.5510
# 25     0.2895      0.1739     0.2642       0.3168     0.2609        0.4773
# 4      0.1995      0.1141     0.2555       0.2935     0.1724        0.5000
# 33        NaN      0.0667     0.2451       0.1765     0.2000        0.2667
# 29     0.2076      0.0899     0.1849       0.2231     0.1791        0.3125
# 45     0.0820      0.0732     0.1319       0.2676     0.0734        0.4340
# 42     0.1746      0.0278     0.1500       0.2308     0.1964        0.1515
# 16        NaN      0.0541     0.1625       0.1690     0.1628        0.1818
# 9      0.0658      0.0000     0.1212       0.0545     0.0580        0.1579
# 116       NaN      0.0000     0.0185       0.1220     0.0366        0.2308
# 182       NaN      0.0000     0.0811       0.0000     0.0364        0.0667

# %%
Math.query('Grade==8').sort_values(by=['Prof'], ascending=False)
# Out:
#                                   School    Num  Grade    Prof  White_Prof  \
# 129            Capitol Hill Magnet/Rondo  494.0    8.0  0.5764      0.7922
# 196                            State_All    0.0    8.0  0.5517      0.6365
# 22         Open World Learning Secondary  250.0    8.0  0.4143      0.5000
# 40                  Murray Middle School  342.0    8.0  0.4112      0.6941
# 189                    Mpls_District_All    0.0    8.0  0.4110      0.7044
# 37           Highland Park Middle School  330.0    8.0  0.4008      0.7000
# 46                  Ramsey Middle School  345.0    8.0  0.3547      0.6889
# 26      Washington Tech Secondary Magnet  252.0    8.0  0.3282      0.4706
# 5                        Sp_District_All    0.0    8.0  0.3274      0.6368
# 150       Linwood Monroe Arts Plus Upper  528.0    8.0  0.3217      0.5854
# 43   Parkway Montessori/Community Middle  344.0    8.0  0.2824      0.6500
# 30                   Battle Creek Middle  310.0    8.0  0.2383      0.4167
# 17                  Humboldt High School  225.0    8.0  0.2216         NaN
# 34            Farnsworth Aerospace Upper  315.0    8.0  0.2112         NaN
# 10        Creative Arts Secondary School  211.0    8.0  0.2000      0.5000
# 117       Hazel Park Preparatory Academy  489.0    8.0  0.1882         NaN
# 183        American Indian Magnet School  579.0    8.0  0.1200         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 129    0.4444      0.2931     0.5780       0.5745     0.4270        0.6930
# 196    0.3810      0.2615     0.5230       0.5816     0.3332        0.6752
# 22     0.3235      0.1818     0.4783       0.2917     0.2000        0.5333
# 40     0.2248      0.1923     0.4464       0.3725     0.1780        0.6979
# 189    0.2518      0.1706     0.3867       0.4373     0.2229        0.6825
# 37     0.1825      0.1951     0.3333       0.4737     0.1607        0.6160
# 46     0.2362      0.1618     0.3438       0.3684     0.2115        0.5735
# 26     0.3204      0.2184     0.2899       0.3694     0.3069        0.5000
# 5      0.2455      0.1573     0.3106       0.3454     0.2271        0.5381
# 150    0.1757      0.1111     0.2979       0.3382     0.1449        0.5870
# 43     0.2162      0.1600     0.2097       0.3478     0.2277        0.4667
# 30     0.2287      0.0964     0.2362       0.2407     0.2273        0.2712
# 17        NaN      0.1667     0.1728       0.2674     0.2292        0.1739
# 34        NaN      0.0345     0.1687       0.2564     0.1654        0.3824
# 10     0.1250      0.0588     0.3043       0.1111     0.1000        0.3500
# 117       NaN      0.0323     0.1538       0.2174     0.1918        0.1667
# 183       NaN         NaN     0.1071       0.1364     0.1395           NaN

# %% [markdown]
# #### Science Data

# %%
Science.query('Grade==8').sort_values(by=['Prof'], ascending=False)
# Out:
#                          School    Num Grade    Prof  White_Prof  POC_Prof  \
# 48  Highland Park Middle School  330.0     8  0.3712      0.6667    0.1579
# 49         Murray Middle School  342.0     8  0.3430      0.6047    0.1570
# 51         Ramsey Middle School  345.0     8  0.3353      0.7333    0.1953
#
#     Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 48      0.1538     0.3362       0.4071     0.1402        0.5738
# 49      0.1304     0.4159       0.2553     0.1364        0.5773
# 51      0.2029     0.3895       0.2692     0.1887        0.5672

# %% [markdown]
# ## High Schools: Grade Level <a name="high"></a>
#
# #### Enroll Data

# %%
Enroll.query('Num in (220,210,212,215,230,250,252,211,225)').sort_values(by=['School'])
# Out:
#      Num                            School  Tot_Enroll  Male%  White%  Black%  \
# 1  210.0               Central Senior High      1795.0  46.46   41.06   28.86
# 3  212.0             Como Park Senior High      1307.0  51.64   19.05   34.74
# 2  211.0    Creative Arts Secondary School       439.0  36.90   21.41   33.49
# 4  215.0               Harding Senior High      1908.0  51.78    6.08   21.07
# 5  220.0         Highland Park Senior High      1328.0  50.60   35.69   22.59
# 6  225.0              Humboldt High School      1187.0  51.73    6.15   27.30
# 7  230.0               Johnson Senior High      1295.0  56.99   10.12   22.93
# 8  250.0     Open World Learning Secondary       452.0  52.88   55.31    9.07
# 9  252.0  Washington Tech Secondary Magnet      2083.0  53.77    4.70   23.96
#
#    Asian%   FRPL%    ELL%   SPED% Homeless%
# 1   19.33  45.91%  10.92%  10.42%     1.45%
# 3   32.59  64.35%  36.80%  12.78%     1.68%
# 2   18.22  66.74%  12.07%  16.86%     3.19%
# 4   54.40  73.17%  33.75%  12.32%     1.47%
# 5   14.83  45.56%  15.44%   9.94%     0.38%
# 6   44.65  84.50%  47.94%  16.43%     2.27%
# 7   52.20  75.98%  24.09%  15.83%     1.08%
# 8   12.17  32.52%   7.52%  17.04%     0.44%
# 9   55.88  86.75%  36.44%  14.26%     0.82%

# %% [markdown]
# #### Reading Data

# %%
Reading.query('Grade==10').sort_values(by=['Prof'], ascending=False)
# Out:
#                                School    Num  Grade    Prof  White_Prof  \
# 7                 Central Senior High  210.0   10.0  0.6639      0.8667
# 14          Highland Park Senior High  220.0   10.0  0.6339      0.8296
# 23      Open World Learning Secondary  250.0   10.0  0.6176      0.7500
# 197                         State_All    0.0   10.0  0.6040      0.6712
# 19                Johnson Senior High  230.0   10.0  0.4613      0.6585
# 6                     Sp_District_All    0.0   10.0  0.4586      0.7739
# 11     Creative Arts Secondary School  211.0   10.0  0.4286         NaN
# 190                 Mpls_District_All    0.0   10.0  0.4187      0.7016
# 27   Washington Tech Secondary Magnet  252.0   10.0  0.4083      0.5333
# 13                Harding Senior High  215.0   10.0  0.4005      0.4545
# 12              Como Park Senior High  212.0   10.0  0.2915      0.7193
# 18               Humboldt High School  225.0   10.0  0.2197         NaN
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 7      0.4949      0.4167     0.6201       0.7065     0.4161        0.8364
# 14     0.5025      0.3770     0.5954       0.6748     0.4275        0.7778
# 23     0.4286         NaN     0.7000       0.5526     0.2222        0.7600
# 197    0.4460      0.3413     0.5560       0.6544     0.4095        0.6959
# 19     0.4297      0.2055     0.4333       0.4898     0.4135        0.6500
# 6      0.3704      0.2714     0.4244       0.4929     0.3416        0.6713
# 11        NaN      0.2727     0.3846       0.4545     0.3000        0.6000
# 190    0.2360      0.1768     0.3891       0.4569     0.2162        0.6480
# 27     0.4015      0.2963     0.3913       0.4297     0.3765        0.6471
# 13     0.3972      0.3231     0.3436       0.4615     0.3891        0.4314
# 12     0.1632      0.1548     0.2212       0.3507     0.1781        0.4554
# 18        NaN      0.1915     0.1948       0.2396     0.2201        0.2143

# %% [markdown]
# #### Math Data

# %%
Math.query('Grade==11').sort_values(by=['Prof'], ascending=False)
# Out:
#                                School    Num  Grade    Prof  White_Prof  \
# 7                 Central Senior High  210.0   11.0  0.4663      0.7692
# 14          Highland Park Senior High  220.0   11.0  0.4612      0.6782
# 197                         State_All    0.0   11.0  0.4502      0.5219
# 23      Open World Learning Secondary  250.0   11.0  0.3659      0.5882
# 27   Washington Tech Secondary Magnet  252.0   11.0  0.3252         NaN
# 6                     Sp_District_All    0.0   11.0  0.2735      0.5640
# 190                 Mpls_District_All    0.0   11.0  0.2715      0.6119
# 19                Johnson Senior High  230.0   11.0  0.2574      0.4231
# 11     Creative Arts Secondary School  211.0   11.0  0.2432         NaN
# 12              Como Park Senior High  212.0   11.0  0.2235      0.5455
# 13                Harding Senior High  215.0   11.0  0.2104      0.2273
# 18               Humboldt High School  225.0   11.0  0.0927      0.2500
#
#      POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 7      0.2920      0.1458     0.5579       0.3614     0.2234        0.7381
# 14     0.3418      0.3077     0.5250       0.4000     0.2931        0.6124
# 197    0.2802      0.1688     0.4441       0.4568     0.2366        0.5460
# 23     0.2083         NaN     0.3600       0.3750     0.1765        0.5000
# 27        NaN      0.0980     0.3043       0.3519     0.3255        0.3235
# 6      0.2190      0.1262     0.2925       0.2503     0.2011        0.4486
# 190    0.1111      0.0648     0.2713       0.2718     0.1007        0.5126
# 19     0.2398      0.1739     0.2948       0.1919     0.2407        0.3214
# 11        NaN      0.0000     0.2727       0.2308     0.0455        0.5333
# 12     0.1507      0.1224     0.2277       0.2179     0.1591        0.4043
# 13     0.2092      0.1290     0.2105       0.2102     0.1837        0.2745
# 18     0.0791      0.0185     0.1071       0.0746     0.0882        0.1333

# %% [markdown]
# #### Science Data

# %%
Science.query('Grade=="HS"').sort_values(by=['Prof'], ascending=False)
# Out:
#                               School    Num Grade    Prof  White_Prof  \
# 73                         State_All    0.0    HS  0.5435      0.6225
# 13     Open World Learning Secondary  250.0    HS  0.5273      0.8276
# 3                Central Senior High  210.0    HS  0.4960      0.7243
# 15  Washington Tech Secondary Magnet  252.0    HS  0.4703         NaN
# 8          Highland Park Senior High  220.0    HS  0.4507      0.7041
# 2                    Sp_District_All    0.0    HS  0.3540      0.6758
# 70                 Mpls_District_All    0.0    HS  0.3405      0.6620
# 6              Como Park Senior High  212.0    HS  0.3296      0.6667
# 5     Creative Arts Secondary School  211.0    HS  0.3158      0.4000
# 7                Harding Senior High  215.0    HS  0.2500      0.4118
# 11               Johnson Senior High  230.0    HS  0.2466      0.4750
# 10              Humboldt High School  225.0    HS  0.0902         NaN
#
#     POC_Prof  Black_Prof  Male_Prof  Female_Prof  FRPL_Prof  NonFRPL_Prof
# 73    0.3523      0.2431     0.5435       0.5436     0.3302        0.6401
# 13    0.1923         NaN     0.6000       0.4400     0.2083        0.7742
# 3     0.2784      0.1566     0.4833       0.5075     0.2715        0.6447
# 15       NaN      0.3947     0.5268       0.4000     0.4655        0.5000
# 8     0.3172      0.2879     0.4027       0.5037     0.2537        0.6267
# 2     0.2566      0.1769     0.3729       0.3344     0.2492        0.5404
# 70    0.1511      0.0918     0.3344       0.3480     0.1364        0.6145
# 6     0.2164      0.1667     0.3871       0.2674     0.2243        0.4861
# 5     0.2857      0.3333     0.2500       0.3636     0.3333        0.2857
# 7     0.2390      0.1591     0.2828       0.2114     0.2199        0.3247
# 11    0.2109      0.0882     0.2632       0.2292     0.2119        0.3833
# 10       NaN      0.0313     0.1587       0.0286     0.0917        0.0769

# %% [markdown]
# # Conclusion <a name="conclusion"></a>
#
# ### Quick Summary'
#
# * **Overall Proficiency:** Across all subjects, SPPS performs 20% points less than the state and a handful of schools perform better than the state.
# * **Gender Gap:** For mathematics and science, there seems to be no gender gap for both state and SPSS. For reading, gender gaps favors women consistently.
# * **Racial Gap:** For white students in SPPS, they perform better than the state average and their counterparts by around 5 percentage points across all subjects. For black students in SPPS, they perform 50% points less than their white counterparts, and roughly 5-10% points less than their state peers. For POC, they were similar to clack students in respect to performing lower than their state peer and below the overall state proficiency.
# * **Economic Gap:** For Non-FRPL students, SPPS performed as well as the state proficiency average for Mathematic and Science, though above average in Reading; though their state counterparts performed slightly better than them. In SPPS, FRPL students perform around 20% percentage points less than their Non-FRPL counterparts
# * **Demographic Analysis:** Over 85% of black students, and 80% of asian students have FRPL status. Though there is greater concentration of poverty in Saint Paul in comparison to the state, where 25% of the state Asian FRPL population is in Saint Paul. The economic proficiency gap in SPPS is greatest among white students; for other races, non-FRPL does not perform as well as their white counterparts
# * **Geographical Analysis:** By breaking down by racial representation, we can see where students live. White students, in representation reside in West of Saint Paul, and in the best performing schools. Black students live throughout Saint Paul, and greater concentration is associated with lower performance. Asian students reside on East Side and North End, and their performance varies between the schools. The ELL concentration is almost identical to the Asian population, but with additional representation of Hispanic (i.e South Saint Paul) and Somali immigrants (i.e Frogtown area). Lower performing schools seem to have a slightly more concentration of SPED students. For FRPL representation, the map balloons indicating the concentration of poverty in the city, there is a pattern of lower concentration of poverty equal better performance.
#
#
# ### Concluding Thoughts
#
# The SPPS face challenges, but is no different than most urban schools. There is a vast number of education reformers that have golden solution that will solve the education crisis, often there is a financial incentive involved. In my opinion, the solution to address the systemic challenges by incorporating commitment and participation of all respective stakeholders. Similar to politics, school administrators can use "poverty" and the dysfunctional state/federal regulations as a means to justify low-performance, and be complicit. Unlike politicians, school/district administrators and educators do not have much power to rapidly change the system. In fact, every single party will be blaming each other; i.e. the hexagon of blame. I created a simple flow chart below. When we blame others we outsource the problem to someone else, and everyone ends up feeling powerless.
#
# ![title](Graphs/Hex.jpg)
#
#
# This report is not an essay, and I have a narrow bandwidth in completing this, so emphasizing key stakeholder relationships and challenges will be excluded. These couple of diagrams will effectively describe what should be done, and follows the principles of industrial organization, thus generalizable to mosts institutions. The status quo on who has power in the education system is determined is below, where the red arrows indicate negative influence.
#
# ![title](Graphs/SEP1.jpg)
#
# Notice who are the real decision makers aka special interest groups, it's similar to the blame diagram, but it doesn't go back to the people because they don't have much influence. Here is what the school ecosystem should look like internally excluding public influence, assuming teachers are organized. Green arrows indicate indirect relationships, while black arrows indicate direct relationships via by design.
#
# ![title](Graphs/IIN.jpg)
#
# Notice that every direct relationship is two-way (excluded a few relationships), indicating they are supporting each other. In addition, the schools are working with each other instead of performing in silos. In the traditional model, all the green arrows would be removed, and management will be operating under a standard hierarchical framework. A competent leader may be able to build those direct two-way relationships. However, their impact is limited to their local region of influence, and the partnerships can be lost once leadership is displaced. Career administrators are often moving to different roles and districts, so there isn't much time commitment and incentive to build these relationships. Also notice that teachers made up the base of the diagram, and can have considerable influence on decision making process. The diagram above shows a more ideal relationship on how education policy should be implemented, the light green line indicate election/voting.
#
# ![title](Graphs/IEP.jpg)
#
# The schoolboard plays a direct role in improving our school system. They have an intentional relationship with the citizen/parents they represent, direct relationship with the school district itself, and could advocate to influence state/federal legislation. The diagram shows that the school board functions like a special interest group.
# The true strength of the schoolboard is from the citizens, and an effective schoolboard has the additional benefit of reducing the influence of special interest groups, and improving educational outcomes (invested citizens/parents will lead to improved relationships with students).
#
# Though it is important to note that building relationships with schools and staff has immediate impact right now, and can exist in a framework that lays down the foundations for institutional success.
#
# ### Recommended Steps
#
# **People**:
# As citizens, we need to assert the urgency of the problem, and place "gentle pressure" on our institutions to take action. We cannot wait for "superman" or more accurately a principal and/or superintendent to solve our problems, it requires a collaborative effort. Citizens and parents need to hold administrators accountable in taking the steps moving forward. Data plays an important role in creating transparency and accountability, which enables us to determine what works and what doesn't work.
#
# **Institution**:
#
# The schoolboard plays an integral role, especially in a large urban school district. The schoolboard serves as a liaison between the citizens, the school district, and, potentially, lawmakers. They should be receiving a competitive salary (current pay $10,800) because you need to run to get elected, and finally the financial burden will prevent potential boardmembers from running! Though the increase in salary, should also lead to greater board cohesion and expectation with respect to roles and duties. Maybe it should be run as a non-profit.
#
# **Data Internal Systems**:
#
# I recommend that SPPS REA department to implement a **cohort analysis**, i.e. specifying the progress of the same group of students and create more intentional Personal Learning Communities (PLC) to determine the following:
# * How did students change from coming to class? Was there enough instruction toward certain sub-strand?
# * Cohort analysis allows more **credible accountability** as the numbers are not influenced by the volatility of the competency of a certain grade level.
# * Are students adequately prepared academically transitioning to middle and high school?
# * How can similar school administrators collaborate in sharing best practices in determining what works and doesn't work.
#
# I can give more concrete recommendations, but I rather be hired as a consultant at this point of time and/or full salaried position.
#
#
# P.S. I may consider running for schoolboard depending on my self-confidence and if it is turned into a paid full-time position. If you are wondering why I did not run for schoolboard instead of city-council that is a good question.

# %% [markdown]
# ### Run Code  <a name="code"></a>

# %%
#Run Code
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
import requests # library to handle requests
import folium
import seaborn as sns
import scipy.stats as stats #used to get correlation coefficient

#load data
Enroll= pd.read_csv('Data/SPEnrollment.csv')
Math= pd.read_csv('Data/SPMath.csv')
Reading= pd.read_csv('Data/SPReading.csv')
Science= pd.read_csv('Data/SPScience.csv')
HL= pd.read_csv('Data/TCHomeless.csv')
Add= pd.read_csv('Data/AddSchool.csv')
School= pd.read_csv('Data/SchoolProf.csv')
Mpls= pd.read_csv('Data/MPLS_SchoolProf.csv')



def plot_Homeless():
    # generate a new map
    FG_map = folium.Map(location=[44.988326, -93.162926], zoom_start=12,tiles="OpenStreetMap")
    A=HL.query('Homeless_Count>3 and Num!=527')

    print('This map displays 2019 Homeless Student Count > 3 from October 1st,2019 Enrollment')
    for index, row in A.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Homeless_Count: {}<br> Homeless%: {}<br> Total Enrollment: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Homeless_Count'],row['Homeless%'],row['Tot_Enroll'] )
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Homeless_Count'],
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)

    return FG_map

def plot_School_White(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','White%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized White%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#Black
def plot_School_Black(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','Black%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Black%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#Asian
def plot_School_Asian(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','Asian%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Asian%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#ELL
def plot_School_ELL(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','ELL%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized English Language Learners (ELL%)'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#SPED
def plot_School_SPED(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','SPED%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized special needs students (SPED%)'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map


#FRPL
def plot_School_FRPL(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','FRPL%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= School[(School['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Free and Reduced Lunch (FRPL%)'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

# %%
def plot_MSchool_White(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','White%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= Mpls[(Mpls['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized White%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> White%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['White%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['White%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#Black
def plot_MSchool_Black(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','Black%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= Mpls[(Mpls['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Black%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Black%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Black%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Black%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#Asian
def plot_MSchool_Asian(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','Asian%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= Mpls[(Mpls['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Asian%'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> Asian%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['Asian%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['Asian%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#ELL
def plot_MSchool_ELL(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','ELL%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= Mpls[(Mpls['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized English Language Learners (ELL%)'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> ELL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['ELL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['ELL%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

#SPED
def plot_MSchool_SPED(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','SPED%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= Mpls[(Mpls['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized special needs students (SPED%)'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> SPED%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['SPED%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['SPED%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map


#FRPL
def plot_MSchool_FRPL(Subject='Math'):
    Index =['School','Latitude','Longitude', 'Total_Tested','Proficiency','Address','Subject','Ranking','FRPL%']

    FG_map = folium.Map(location=[44.958326, -93.122926], zoom_start=12,tiles="OpenStreetMap")
    
    B= Mpls[(Mpls['Subject'] == Subject)]
    B4=B.query('Ranking == 4')
    B3=B.query('Ranking == 3')
    B2=B.query('Ranking == 2')
    B1=B.query('Ranking == 1')
    
    print('This map displays 2019 {} Proficiency under normalized Free and Reduced Lunch (FRPL%)'.format(Subject))
    for index, row in B4.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#0000ff",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B3.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#007849",
                            popup=popup_text,
                            fill=True).add_to(FG_map)
    
    for index, row in B2.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#E37222",
                            popup=popup_text,
                            fill=True).add_to(FG_map)    
        
    for index, row in B1.iterrows(): 
        popup_text = "School: {}<br> Address: {}<br> Tested: {}<br> Proficiency: {}<br> FRPL%: {}"
        popup_text = popup_text.format(row["School"],row["Address"], row['Total_Tested'], row['Proficiency'], row['FRPL%'])
        folium.CircleMarker(location=(row["Latitude"],row["Longitude"]),
                            radius=row['FRPL%']/2,
                            color="#ff0000",
                            popup=popup_text,
                            fill=True).add_to(FG_map)  
    
    return FG_map

# %%
plot_MSchool_Asian()
# Out:
# This map displays 2019 Math Proficiency under normalized Asian%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
